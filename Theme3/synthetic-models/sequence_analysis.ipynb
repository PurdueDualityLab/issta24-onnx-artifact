# %%
import json
from difflib import SequenceMatcher
import itertools

# %%
def create_tokenizers(token_dict_1, token_dict_2):
    node_type_token_dict = {
        node_type: chr(i)
        for i, node_type in enumerate(
            set(
                token_dict_1.keys()
                | token_dict_2.keys()
            )
        )
    }

    token_node_type_dict = {token: node_type for node_type, token in node_type_token_dict.items()}
    return node_type_token_dict, token_node_type_dict

# %%
def tokenize_seqs(node_type_token_dict, seqs):
    def _tokenize(path) -> str:
        return "".join(list(map(lambda x: node_type_token_dict[x], path)))

    tokenized_seqs = [_tokenize(seq) for seq in seqs]
    return tokenized_seqs

# %%
def detokenize_seqs(token_node_type_dict, seqs):
    def _detokenize(tokenized_seq):
        return [token_node_type_dict[token] for token in tokenized_seq]

    detokenized_seqs = [_detokenize(seq) for seq in seqs]
    return detokenized_seqs

# %%
def recursive_submatching(seqs, seq_len):
    submatches = set(seqs)
    for i, j in itertools.combinations(seqs, 2):
        matcher = SequenceMatcher(None, i, j)
        matching_blocks = list(matcher.get_matching_blocks())
        for matching_block in matching_blocks:
            a, b, size = matching_block.a, matching_block.b, matching_block.size
            if matching_block.size > 3:
                match_1 = i[a : a + size]
                submatches.add(match_1)
                if i in submatches:
                    submatches.remove(i)
                if j in submatches:
                    submatches.remove(j)
    print(len(submatches))
    if seq_len - len(submatches) > 0:
        return recursive_submatching(set(submatches), len(submatches))
    return seqs

# %%
def get_unq_sequences(seqs):
    total_sequences = 0
    unique_sequences = set()
    for i, (_, sequences) in enumerate(seqs['results'].items()):
        total_sequences += len(sequences)
        unique_sequences |= set(sequences)

    unique_sequences_stripped = set()
    for seq in unique_sequences:
        new_seq = seq.strip(seqs['node_type_token_dict']['input'])
        new_seq = new_seq.strip(seqs['node_type_token_dict']['output'])
        if len(new_seq) > 2:
            unique_sequences_stripped.add(new_seq)

    unique_sequences_decoded = []
    for sequence in unique_sequences_stripped:
        decoded_sequence = [seqs['token_node_type_dict'][i] for i in sequence]
        unique_sequences_decoded.append(decoded_sequence)

    print(f"Total Sequences: {total_sequences:,}, Total Unique Sequences: {len(unique_sequences_stripped):,}, Total Paths Compared: {seqs['total_path_pairs_analyzed']:,}")
    return unique_sequences_stripped, unique_sequences_decoded, total_sequences

# %% [markdown]
# # PyTorch

# %%
with open('./onnx_parsing_results/torch_mismatch_seq_match_results.json', 'r') as f:
    mismatched_seq = json.load(f)

with open('./onnx_parsing_results/torch_correct_mismatch_seq_match_results.json', 'r') as f:
    mismatched_correct = json.load(f)

with open('./onnx_parsing_results/torch_test_mismatch_seq_match_results.json', 'r') as f:
    mismatched_test = json.load(f)

# %%
print("Mismatched Ops:", len(mismatched_seq['node_type_token_dict'].keys()))
print("Mismatched-Correct Ops:", len(mismatched_correct['node_type_token_dict'].keys()))
print("Mismatched-Test Ops:", len(mismatched_test['node_type_token_dict'].keys()))
# Out:
# Mismatched Ops: 58
# Mismatched-Correct Ops: 59
# Mismatched-Test Ops: 62

# %%
mismatched_seq['node_type_token_dict'].keys() - mismatched_correct['node_type_token_dict'].keys()
# Out:
# set()

# %%
mismatched_test['node_type_token_dict'].keys() - mismatched_correct['node_type_token_dict'].keys()
# Out:
# {'DepthToSpace', 'Flatten', 'Unsqueeze'}

# %% [markdown]
# ## Mismatched Sequences

# %%
(
    unique_mismatched_sequences,
    unique_mismatched_sequences_decoded,
    total_mismatched_sequences,
) = get_unq_sequences(mismatched_seq)
# Out:
# Total Sequences: 70,301, Total Unique Sequences: 980, Total Paths Compared: 213,258,432

# %%
len(recursive_submatching(unique_mismatched_sequences, len(unique_mismatched_sequences)))
# Out:
# 654
# 640
# 640
# 640

# %% [markdown]
# ## Correct-Mismatched Sequences

# %%
(
    unique_corr_mismatched_sequences,
    unique_corr_mismatched_sequences_decoded,
    total_corr_mismatched_sequences,
) = get_unq_sequences(mismatched_correct)
# Out:
# Total Sequences: 923,707, Total Unique Sequences: 4,243, Total Paths Compared: 2,358,066,840

# %%
len(recursive_submatching(unique_corr_mismatched_sequences, len(unique_corr_mismatched_sequences)))
# Out:
# 3105
# 2991
# 2989
# 2989
# 2989

# %% [markdown]
# ### Create New Tokenizers and Calculate Non-Overlapping

# %%
node_type_token_dict, token_node_type_dict = create_tokenizers(
    mismatched_correct["node_type_token_dict"], mismatched_seq["node_type_token_dict"]
)

# %%
mismatched_sequences = set(tokenize_seqs(node_type_token_dict, unique_mismatched_sequences_decoded))
mismatched_correct_sequences = set(tokenize_seqs(node_type_token_dict, unique_corr_mismatched_sequences_decoded))

# %% [markdown]
# #### Nonoverlapping

# %%
seqs = mismatched_sequences - mismatched_correct_sequences
len(seqs)
# Out:
# 176

# %%
detokenize_seqs(token_node_type_dict, seqs)
# Out:
# [['Shape', 'Slice', 'Concat', 'Reshape', 'Expand', 'Mul'],
#  ['Pad', 'AveragePool', 'ArgMin', 'Less', 'Cast', 'And'],
#  ['Resize', 'Abs', 'ReduceMax'],
#  ['ReduceMin', 'Cast', 'Where'],
#  ['MatMul', 'MatMul', 'Where'],
#  ['Mul', 'Softmax', 'MatMul'],
#  ['Cos', 'Mul', 'Mul', 'Max'],
#  ['Tan', 'Sub', 'Div'],
#  ['Ceil', 'Sin', 'Max'],
#  ['Clip', 'Clip', 'Mul'],
#  ['Ceil', 'Cast', 'ArgMax'],
#  ['Atan', 'Shape', 'Slice', 'Concat', 'Resize', 'Round'],
#  ['ReduceSum', 'Cast', 'ArgMin'],
#  ['Concat', 'ReduceMax', 'Reshape'],
#  ['Cast', 'Abs', 'Less'],
#  ['PRelu', 'Concat', 'Shape', 'Slice', 'Concat', 'Resize', 'ReduceSum'],
#  ['Where', 'Resize', 'Concat'],
#  ['ReduceSum', 'Resize', 'Concat'],
#  ['Cast', 'Pad', 'Mul'],
#  ['Mul', 'Mul', 'Clip', 'Cast'],
#  ['Cast', 'LeakyRelu', 'Tan'],
#  ['Sub', 'Sin', 'Div'],
#  ['Cast', 'Floor', 'Ceil'],
#  ['Reshape', 'Cast', 'MatMul'],
#  ['Greater', 'Where', 'Slice'],
#  ['Shape', 'Slice', 'Concat', 'Reshape', 'Cast', 'MatMul'],
#  ['Mul', 'Mul', 'Concat', 'Transpose'],
#  ['Mul', 'Mul', 'Concat', 'Neg'],
#  ['Div', 'Abs', 'Atan', 'Div'],
#  ['Conv', 'Squeeze', 'Greater'],
#  ['Shape', 'Slice', 'Concat', 'Reshape', 'Expand', 'MatMul'],
#  ['MatMul', 'Cast', 'Mul', 'Mul'],
#  ['Floor', 'Cast', 'Mul', 'Neg'],
#  ['Where', 'Shape', 'Slice', 'Concat', 'Resize', 'Concat'],
#  ['ReduceSum', 'MatMul', 'Max'],
#  ['Less', 'Where', 'Div', 'Erf', 'Add', 'Mul', 'Mul'],
#  ['MatMul', 'Mul', 'ReduceMax'],
#  ['Mul', 'Concat', 'Neg', 'Cast'],
#  ['Concat', 'Max', 'Mul', 'Mul'],
#  ['Cast', 'And', 'Cast', 'And', 'Where', 'Resize'],
#  ['Trilu', 'LeakyRelu', 'Sub'],
#  ['ReduceSum', 'Resize', 'Div'],
#  ['Add', 'Div', 'Greater'],
#  ['Cast', 'Mul', 'Trilu'],
#  ['Cos', 'Div', 'Erf', 'Add', 'Mul', 'Mul', 'Max'],
#  ['Shape', 'Slice', 'Concat', 'Resize', 'Concat', 'Squeeze'],
#  ['Atan', 'Softmax', 'Concat', 'Concat'],
#  ['ArgMax', 'Greater', 'Where', 'Slice'],
#  ['ReduceSum', 'Atan', 'PRelu'],
#  ['Shape', 'Slice', 'Concat', 'Reshape', 'Cast', 'MatMul', 'Div'],
#  ['Pad', 'ArgMax', 'Reshape'],
#  ['Abs', 'Concat', 'PRelu'],
#  ['Atan', 'Reshape', 'Expand'],
#  ['Mul', 'Mul', 'Greater', 'Where'],
#  ['Concat', 'MatMul', 'MatMul', 'Where'],
#  ['Div', 'Erf', 'Add', 'Mul', 'Mul', 'Concat', 'Transpose'],
#  ['Cast', 'Xor', 'Where', 'Concat', 'Clip'],
#  ['Atan', 'Sub', 'Mul'],
#  ['Cast', 'And', 'Cast', 'And', 'Where', 'Shape', 'Slice', 'Concat', 'Resize'],
#  ['LeakyRelu', 'Concat', 'Add', 'Concat'],
#  ['Concat', 'Neg', 'Concat', 'Concat'],
#  ['Neg', 'Where', 'MatMul'],
#  ['ReduceSum', 'Shape', 'Slice', 'Concat', 'Resize', 'Concat'],
#  ['Div', 'Erf', 'Add', 'Mul', 'Mul', 'Concat', 'Neg'],
#  ['ReduceSum', 'Shape', 'Slice', 'Concat', 'Resize', 'Div'],
#  ['Cos', 'Add', 'Div'],
#  ['Atan', 'Div', 'Cos'],
#  ['Ceil', 'Transpose', 'Conv'],
#  ['ReduceMax', 'Ceil', 'BatchNormalization'],
#  ['ArgMax', 'Greater', 'Where'],
#  ['Slice', 'Max', 'Shape', 'Slice', 'Concat', 'Resize'],
#  ['Reshape', 'Expand', 'Mul'],
#  ['Conv', 'ReduceMean', 'Concat'],
#  ['Squeeze', 'Mul', 'Slice'],
#  ['Neg', 'Concat', 'Concat', 'Resize'],
#  ['Add', 'ReduceSum', 'Shape', 'Slice', 'Concat'],
#  ['Neg', 'Concat', 'Concat', 'Shape', 'Slice', 'Concat', 'Resize'],
#  ['ReduceMean', 'Add', 'Sub'],
#  ['Atan', 'Cast', 'LeakyRelu'],
#  ['Sin', 'Expand', 'Concat', 'ReduceMax'],
#  ['Concat', 'Max', 'Div', 'Erf', 'Add', 'Mul', 'Mul'],
#  ['Max', 'MatMul', 'Div'],
#  ['Mul', 'Slice', 'Shape'],
#  ['Atan', 'Cast', 'Sigmoid'],
#  ['Div',
#   'Erf',
#   'Add',
#   'Mul',
#   'Mul',
#   'Clip',
#   'Cast',
#   'Shape',
#   'Slice',
#   'Concat'],
#  ['Tan', 'ReduceMean', 'Div'],
#  ['Round', 'Where', 'Resize'],
#  ['Ceil', 'Atan', 'Trilu'],
#  ['Round', 'Where', 'Shape', 'Slice', 'Concat', 'Resize'],
#  ['Concat', 'LeakyRelu', 'ReduceMean'],
#  ['Relu', 'Concat', 'Sigmoid'],
#  ['Cast', 'Cast', 'Sub', 'Neg'],
#  ['Floor', 'Cast', 'Mul'],
#  ['Reshape', 'Cast', 'MatMul', 'Div'],
#  ['Cos', 'Cast', 'Cast', 'Mul'],
#  ['Cast', 'Cast', 'Cast', 'Max'],
#  ['Shape', 'Slice', 'Concat', 'Resize', 'Abs', 'ReduceMax'],
#  ['Atan', 'Resize', 'Round'],
#  ['Where', 'Sin', 'Concat', 'LeakyRelu'],
#  ['Sub', 'ReduceSum', 'MatMul'],
#  ['Slice', 'Relu', 'Mul', 'Mul'],
#  ['Concat', 'Neg', 'Cast'],
#  ['Relu', 'Mul', 'Slice'],
#  ['Cast', 'Floor', 'Sin'],
#  ['Sub', 'ReduceSum', 'Shape', 'Slice', 'Concat'],
#  ['Min', 'Atan', 'Pad'],
#  ['Cast', 'ReduceMax', 'Sub', 'Mul'],
#  ['Cast', 'Sub', 'Mul'],
#  ['Concat', 'Neg', 'Cast', 'Concat'],
#  ['Div', 'Abs', 'Atan'],
#  ['Mul', 'Mul', 'Clip', 'Cast', 'Shape', 'Slice', 'Concat'],
#  ['Ceil', 'Max', 'Conv'],
#  ['PRelu', 'Concat', 'Resize', 'ReduceSum'],
#  ['Cast', 'Cast', 'Cast', 'Sub'],
#  ['Max', 'Concat', 'Round'],
#  ['Cast', 'Cast', 'Cast', 'Max', 'Cast'],
#  ['Cast', 'Concat', 'Cast', 'Div'],
#  ['Sub', 'Mul', 'Sigmoid'],
#  ['Cos', 'Relu', 'Concat'],
#  ['Slice', 'Max', 'Resize'],
#  ['Min', 'ArgMax', 'Cast'],
#  ['Mul', 'Concat', 'Transpose', 'ReduceMean'],
#  ['Atan', 'Softmax', 'Concat'],
#  ['LeakyRelu', 'Mul', 'MatMul'],
#  ['Div', 'Erf', 'Add', 'Mul', 'Mul', 'Clip', 'Tan'],
#  ['Ceil', 'ReduceMax', 'Concat'],
#  ['Concat', 'Concat', 'Cast', 'Sub'],
#  ['Concat', 'Ceil', 'Sub'],
#  ['Mul', 'Mul', 'Clip', 'Tan'],
#  ['Cast', 'Cast', 'Cast', 'Mul'],
#  ['Where', 'Concat', 'Reshape'],
#  ['Ceil', 'Mul', 'Softmax'],
#  ['Reshape', 'Conv', 'Reshape'],
#  ['Slice', 'Relu', 'Mul'],
#  ['Where', 'Concat', 'Shape', 'Slice', 'Concat', 'Reshape'],
#  ['Cast', 'Xor', 'Cast', 'And', 'Cast', 'And', 'Cast', 'Or'],
#  ['Abs', 'Concat', 'Shape', 'Slice', 'Concat'],
#  ['Expand', 'MatMul', 'MatMul'],
#  ['ReduceSum', 'Shape', 'Slice', 'Concat', 'Resize', 'Mul'],
#  ['Mul', 'Transpose', 'MatMul'],
#  ['Softmax', 'Max', 'Div'],
#  ['Shape', 'Gather', 'Equal', 'If', 'Cos'],
#  ['Cast', 'Abs', 'Sub'],
#  ['ReduceSum', 'Resize', 'Mul'],
#  ['Atan', 'PRelu', 'Min'],
#  ['Abs', 'Mul', 'Cast'],
#  ['Atan', 'Resize', 'Max'],
#  ['Atan', 'Shape', 'Slice', 'Concat', 'Resize', 'Max'],
#  ['Squeeze', 'Add', 'Sub'],
#  ['Abs', 'Concat', 'Min', 'MatMul'],
#  ['Slice', 'Concat', 'Neg', 'Cast'],
#  ['MatMul', 'Max', 'Pad'],
#  ['Div', 'Erf', 'Add', 'Mul', 'Mul', 'Greater', 'Where'],
#  ['ArgMin', 'Expand', 'Greater', 'Where'],
#  ['Mul', 'Softmax', 'Pad'],
#  ['Mul', 'Concat', 'Neg', 'Cast', 'Concat'],
#  ['Concat', 'Cast', 'Ceil'],
#  ['Atan', 'Shape', 'Slice', 'Concat', 'Reshape', 'Expand'],
#  ['Cast', 'Floor', 'LeakyRelu'],
#  ['ArgMin', 'Expand', 'Greater'],
#  ['Concat', 'MatMul', 'Add', 'ReduceMax'],
#  ['Concat', 'Resize', 'Pad', 'Div'],
#  ['Resize', 'Concat', 'Squeeze'],
#  ['Tan', 'Pad', 'Mul'],
#  ['Abs', 'Cast', 'Add', 'Cast'],
#  ['ReduceMin', 'Sigmoid', 'Relu'],
#  ['Div', 'Erf', 'Add', 'Mul', 'Mul', 'Clip', 'Cast'],
#  ['Sub', 'Mul', 'Sub'],
#  ['ReduceSum', 'MaxPool', 'Concat'],
#  ['PRelu', 'Greater', 'Cast', 'Or'],
#  ['Squeeze', 'Mul', 'Div'],
#  ['Ceil', 'Sin', 'Cast'],
#  ['Tan', 'Clip', 'Concat'],
#  ['MatMul', 'Neg', 'Concat'],
#  ['Pad', 'AveragePool', 'ArgMin', 'Less'],
#  ['Xor', 'Where', 'Concat']]

# %%
reduced_sequences = recursive_submatching(seqs, len(seqs))
# Out:
# 146
# 131
# 131

# %%
detokenize_seqs(token_node_type_dict, reduced_sequences)
# Out:
# [['Resize', 'Abs', 'ReduceMax'],
#  ['ReduceMin', 'Cast', 'Where'],
#  ['MatMul', 'MatMul', 'Where'],
#  ['Mul', 'Softmax', 'MatMul'],
#  ['Cos', 'Mul', 'Mul', 'Max'],
#  ['Tan', 'Sub', 'Div'],
#  ['Ceil', 'Sin', 'Max'],
#  ['Clip', 'Clip', 'Mul'],
#  ['Ceil', 'Cast', 'ArgMax'],
#  ['ReduceSum', 'Cast', 'ArgMin'],
#  ['Concat', 'ReduceMax', 'Reshape'],
#  ['Cast', 'Abs', 'Less'],
#  ['Where', 'Resize', 'Concat'],
#  ['ReduceSum', 'Resize', 'Concat'],
#  ['Cast', 'Pad', 'Mul'],
#  ['Mul', 'Mul', 'Clip', 'Cast'],
#  ['Cast', 'LeakyRelu', 'Tan'],
#  ['Sub', 'Sin', 'Div'],
#  ['Cast', 'Floor', 'Ceil'],
#  ['Reshape', 'Cast', 'MatMul'],
#  ['Greater', 'Where', 'Slice'],
#  ['Div', 'Abs', 'Atan', 'Div'],
#  ['Conv', 'Squeeze', 'Greater'],
#  ['MatMul', 'Cast', 'Mul', 'Mul'],
#  ['Floor', 'Cast', 'Mul', 'Neg'],
#  ['ReduceSum', 'MatMul', 'Max'],
#  ['MatMul', 'Mul', 'ReduceMax'],
#  ['Concat', 'Max', 'Mul', 'Mul'],
#  ['Trilu', 'LeakyRelu', 'Sub'],
#  ['ReduceSum', 'Resize', 'Div'],
#  ['Add', 'Div', 'Greater'],
#  ['Cast', 'Mul', 'Trilu'],
#  ['Atan', 'Softmax', 'Concat', 'Concat'],
#  ['ArgMax', 'Greater', 'Where', 'Slice'],
#  ['ReduceSum', 'Atan', 'PRelu'],
#  ['Pad', 'ArgMax', 'Reshape'],
#  ['Abs', 'Concat', 'PRelu'],
#  ['Atan', 'Reshape', 'Expand'],
#  ['Concat', 'MatMul', 'MatMul', 'Where'],
#  ['Cast', 'Xor', 'Where', 'Concat', 'Clip'],
#  ['Atan', 'Sub', 'Mul'],
#  ['LeakyRelu', 'Concat', 'Add', 'Concat'],
#  ['Concat', 'Neg', 'Concat', 'Concat'],
#  ['Neg', 'Where', 'MatMul'],
#  ['Cos', 'Add', 'Div'],
#  ['Atan', 'Div', 'Cos'],
#  ['Ceil', 'Transpose', 'Conv'],
#  ['ReduceMax', 'Ceil', 'BatchNormalization'],
#  ['ArgMax', 'Greater', 'Where'],
#  ['Reshape', 'Expand', 'Mul'],
#  ['Conv', 'ReduceMean', 'Concat'],
#  ['Squeeze', 'Mul', 'Slice'],
#  ['Neg', 'Concat', 'Concat', 'Resize'],
#  ['ReduceMean', 'Add', 'Sub'],
#  ['Atan', 'Cast', 'LeakyRelu'],
#  ['Sin', 'Expand', 'Concat', 'ReduceMax'],
#  ['Max', 'MatMul', 'Div'],
#  ['Mul', 'Slice', 'Shape'],
#  ['Atan', 'Cast', 'Sigmoid'],
#  ['Tan', 'ReduceMean', 'Div'],
#  ['Round', 'Where', 'Resize'],
#  ['Ceil', 'Atan', 'Trilu'],
#  ['Concat', 'LeakyRelu', 'ReduceMean'],
#  ['Relu', 'Concat', 'Sigmoid'],
#  ['Cast', 'Cast', 'Sub', 'Neg'],
#  ['Floor', 'Cast', 'Mul'],
#  ['Cos', 'Cast', 'Cast', 'Mul'],
#  ['Atan', 'Resize', 'Round'],
#  ['Where', 'Sin', 'Concat', 'LeakyRelu'],
#  ['Sub', 'ReduceSum', 'MatMul'],
#  ['Slice', 'Relu', 'Mul', 'Mul'],
#  ['Concat', 'Neg', 'Cast'],
#  ['Relu', 'Mul', 'Slice'],
#  ['Cast', 'Floor', 'Sin'],
#  ['Min', 'Atan', 'Pad'],
#  ['Cast', 'ReduceMax', 'Sub', 'Mul'],
#  ['Cast', 'Sub', 'Mul'],
#  ['Div', 'Abs', 'Atan'],
#  ['Ceil', 'Max', 'Conv'],
#  ['PRelu', 'Concat', 'Resize', 'ReduceSum'],
#  ['Cast', 'Cast', 'Cast', 'Sub'],
#  ['Max', 'Concat', 'Round'],
#  ['Cast', 'Concat', 'Cast', 'Div'],
#  ['Sub', 'Mul', 'Sigmoid'],
#  ['Cos', 'Relu', 'Concat'],
#  ['Slice', 'Max', 'Resize'],
#  ['Min', 'ArgMax', 'Cast'],
#  ['Mul', 'Concat', 'Transpose', 'ReduceMean'],
#  ['Atan', 'Softmax', 'Concat'],
#  ['LeakyRelu', 'Mul', 'MatMul'],
#  ['Ceil', 'ReduceMax', 'Concat'],
#  ['Concat', 'Concat', 'Cast', 'Sub'],
#  ['Concat', 'Ceil', 'Sub'],
#  ['Cast', 'Cast', 'Cast', 'Mul'],
#  ['Where', 'Concat', 'Reshape'],
#  ['Shape', 'Slice', 'Concat', 'Resize'],
#  ['Ceil', 'Mul', 'Softmax'],
#  ['Reshape', 'Conv', 'Reshape'],
#  ['Slice', 'Relu', 'Mul'],
#  ['Expand', 'MatMul', 'MatMul'],
#  ['Mul', 'Transpose', 'MatMul'],
#  ['Softmax', 'Max', 'Div'],
#  ['Shape', 'Gather', 'Equal', 'If', 'Cos'],
#  ['Cast', 'Abs', 'Sub'],
#  ['ReduceSum', 'Resize', 'Mul'],
#  ['Atan', 'PRelu', 'Min'],
#  ['Abs', 'Mul', 'Cast'],
#  ['Atan', 'Resize', 'Max'],
#  ['Squeeze', 'Add', 'Sub'],
#  ['Abs', 'Concat', 'Min', 'MatMul'],
#  ['Slice', 'Concat', 'Neg', 'Cast'],
#  ['MatMul', 'Max', 'Pad'],
#  ['ArgMin', 'Expand', 'Greater', 'Where'],
#  ['Mul', 'Softmax', 'Pad'],
#  ['Concat', 'Cast', 'Ceil'],
#  ['Cast', 'Floor', 'LeakyRelu'],
#  ['ArgMin', 'Expand', 'Greater'],
#  ['Concat', 'MatMul', 'Add', 'ReduceMax'],
#  ['Concat', 'Resize', 'Pad', 'Div'],
#  ['Resize', 'Concat', 'Squeeze'],
#  ['Tan', 'Pad', 'Mul'],
#  ['Abs', 'Cast', 'Add', 'Cast'],
#  ['ReduceMin', 'Sigmoid', 'Relu'],
#  ['Sub', 'Mul', 'Sub'],
#  ['ReduceSum', 'MaxPool', 'Concat'],
#  ['PRelu', 'Greater', 'Cast', 'Or'],
#  ['Squeeze', 'Mul', 'Div'],
#  ['Ceil', 'Sin', 'Cast'],
#  ['Tan', 'Clip', 'Concat'],
#  ['MatMul', 'Neg', 'Concat'],
#  ['Xor', 'Where', 'Concat']]

# %%
filtered = list(
    filter(
        lambda x: (len(x) > 2),
        detokenize_seqs(token_node_type_dict, reduced_sequences),
    )
)
len(filtered)
# Out:
# 131

# %%
filtered_ops = set()
for filt in filtered:
    filtered_ops = filtered_ops.union(filt)
filtered_ops
# Out:
# {'Abs',
#  'Add',
#  'ArgMax',
#  'ArgMin',
#  'Atan',
#  'BatchNormalization',
#  'Cast',
#  'Ceil',
#  'Clip',
#  'Concat',
#  'Conv',
#  'Cos',
#  'Div',
#  'Equal',
#  'Expand',
#  'Floor',
#  'Gather',
#  'Greater',
#  'If',
#  'LeakyRelu',
#  'Less',
#  'MatMul',
#  'Max',
#  'MaxPool',
#  'Min',
#  'Mul',
#  'Neg',
#  'Or',
#  'PRelu',
#  'Pad',
#  'ReduceMax',
#  'ReduceMean',
#  'ReduceMin',
#  'ReduceSum',
#  'Relu',
#  'Reshape',
#  'Resize',
#  'Round',
#  'Shape',
#  'Sigmoid',
#  'Sin',
#  'Slice',
#  'Softmax',
#  'Squeeze',
#  'Sub',
#  'Tan',
#  'Transpose',
#  'Trilu',
#  'Where',
#  'Xor'}

# %% [markdown]
# ### Find Unique Sequence Distribution by Pairs

# %%
tokenized_filtered = tokenize_seqs(mismatched_seq['node_type_token_dict'], filtered)

# %%
sequence_counts_by_pair = {}
for i, (pair, sequences) in enumerate(mismatched_seq['results'].items()):
    a, b = pair.split(",")
    unq_seq = set(sequences)
    unq_seq_stripped = set()
    for seq in unq_seq:
        new_seq = seq.strip(mismatched_seq['node_type_token_dict']['input'])
        new_seq = new_seq.strip(mismatched_seq['node_type_token_dict']['output'])
        if len(new_seq) > 2:
            unq_seq_stripped.add(new_seq)
    
    for filt_seq in tokenized_filtered:
        if filt_seq in unq_seq_stripped:
            if a not in sequence_counts_by_pair:
                sequence_counts_by_pair[a] = set([filt_seq])
            else:
                sequence_counts_by_pair[a] |= set([filt_seq])
            if b not in sequence_counts_by_pair:
                sequence_counts_by_pair[b] = set([filt_seq])
            else:
                sequence_counts_by_pair[b] |= set([filt_seq])
        else:
            if a not in sequence_counts_by_pair:
                sequence_counts_by_pair[a] = set()
            if b not in sequence_counts_by_pair:
                sequence_counts_by_pair[b] = set()
filtered_sorted_pairs = dict(sorted({key: len(val) for key, val in sequence_counts_by_pair.items()}.items(), key=lambda x: x[1], reverse=True))
filtered_sorted_pairs
# Out:
# {'0': 10,
#  '34': 10,
#  '14': 9,
#  '87': 8,
#  '92': 8,
#  '80': 7,
#  '97': 7,
#  '4': 6,
#  '25': 6,
#  '27': 6,
#  '29': 6,
#  '36': 6,
#  '65': 6,
#  '70': 6,
#  '88': 6,
#  '91': 6,
#  '9': 5,
#  '33': 5,
#  '35': 5,
#  '41': 5,
#  '51': 5,
#  '55': 5,
#  '62': 5,
#  '78': 5,
#  '81': 5,
#  '84': 5,
#  '86': 5,
#  '90': 5,
#  '93': 5,
#  '1': 4,
#  '10': 4,
#  '11': 4,
#  '17': 4,
#  '31': 4,
#  '47': 4,
#  '49': 4,
#  '50': 4,
#  '67': 4,
#  '68': 4,
#  '73': 4,
#  '75': 4,
#  '89': 4,
#  '99': 4,
#  '7': 3,
#  '8': 3,
#  '12': 3,
#  '20': 3,
#  '22': 3,
#  '23': 3,
#  '28': 3,
#  '46': 3,
#  '52': 3,
#  '53': 3,
#  '57': 3,
#  '59': 3,
#  '72': 3,
#  '76': 3,
#  '79': 3,
#  '82': 3,
#  '95': 3,
#  '3': 2,
#  '5': 2,
#  '16': 2,
#  '21': 2,
#  '26': 2,
#  '30': 2,
#  '37': 2,
#  '38': 2,
#  '39': 2,
#  '40': 2,
#  '42': 2,
#  '43': 2,
#  '44': 2,
#  '48': 2,
#  '54': 2,
#  '56': 2,
#  '60': 2,
#  '61': 2,
#  '63': 2,
#  '71': 2,
#  '74': 2,
#  '77': 2,
#  '96': 2,
#  '2': 1,
#  '13': 1,
#  '15': 1,
#  '19': 1,
#  '24': 1,
#  '58': 1,
#  '64': 1,
#  '66': 1,
#  '69': 1,
#  '83': 1,
#  '85': 1,
#  '94': 1,
#  '98': 1,
#  '6': 0,
#  '18': 0,
#  '32': 0,
#  '45': 0}

# %%
len(filtered_sorted_pairs)
# Out:
# 100

# %% [markdown]
# ## Mismatched-Test Sequences

# %%
(
    unique_test_mismatched_sequences,
    unique_test_mismatched_sequences_decoded,
    total_test_mismatched_sequences,
) = get_unq_sequences(mismatched_test)
# Out:
# Total Sequences: 1,116, Total Unique Sequences: 2, Total Paths Compared: 166,053,120

# %%
len(recursive_submatching(unique_test_mismatched_sequences, len(unique_test_mismatched_sequences)))
# Out:
# 2
# 2

# %% [markdown]
# ### Create New Tokenizers and Calculate Non-Overlapping

# %%
node_type_token_dict, token_node_type_dict = create_tokenizers(
    mismatched_test["node_type_token_dict"], mismatched_seq["node_type_token_dict"]
)

# %%
mismatched_sequences = set(tokenize_seqs(node_type_token_dict, unique_mismatched_sequences_decoded))
mismatched_test_sequences = set(tokenize_seqs(node_type_token_dict, unique_test_mismatched_sequences_decoded))

# %% [markdown]
# #### Nonoverlapping

# %%
seqs = mismatched_sequences - mismatched_test_sequences
len(seqs)
# Out:
# 979

# %%
reduced_sequences = recursive_submatching(seqs, len(seqs))
# Out:
# 659
# 636
# 636

# %%
detokenize_seqs(token_node_type_dict, reduced_sequences)
# Out:
# [['Max', 'Concat', 'Div'],
#  ['Where', 'Concat', 'Reshape'],
#  ['Min', 'ArgMax', 'Cast'],
#  ['Mul', 'Concat', 'Resize'],
#  ['MatMul', 'Add', 'Div'],
#  ['Cast', 'Max', 'Cast'],
#  ['Ceil', 'Concat', 'Softmax'],
#  ['Squeeze', 'Abs', 'Concat'],
#  ['Atan', 'Mul', 'Mul'],
#  ['MatMul', 'Mul', 'Concat'],
#  ['Cast', 'Concat', 'Cast', 'Div'],
#  ['Mul', 'Cast', 'Concat'],
#  ['Atan', 'Resize', 'Round'],
#  ['Cast', 'Add', 'Resize'],
#  ['Ceil', 'Relu', 'Concat'],
#  ['Mul', 'Concat', 'Concat'],
#  ['Concat', 'Pad', 'AveragePool'],
#  ['ArgMax', 'Greater', 'Where', 'Slice'],
#  ['Softmax', 'MatMul', 'Add'],
#  ['Cast', 'Mul', 'Trilu'],
#  ['Concat', 'Cast', 'Sub'],
#  ['ReduceMean', 'Trilu', 'Trilu'],
#  ['Mul', 'Mul', 'Where'],
#  ['Mul', 'Concat', 'Transpose'],
#  ['Softmax', 'Reshape', 'Concat'],
#  ['Cast', 'MatMul', 'Div'],
#  ['Resize', 'Abs', 'ReduceMax'],
#  ['Concat', 'Resize', 'Concat'],
#  ['Mul', 'Mul', 'Max'],
#  ['Resize', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Add'],
#  ['Relu', 'Mul', 'Slice'],
#  ['Ceil', 'Cast', 'ArgMax'],
#  ['Mul', 'Max', 'Where'],
#  ['Trilu', 'LeakyRelu', 'Sub'],
#  ['Mul', 'Softmax', 'Pad'],
#  ['Ceil', 'Max', 'Conv'],
#  ['Pad', 'Expand', 'Resize'],
#  ['Sigmoid', 'Shape', 'Slice', 'Concat'],
#  ['Cast', 'Abs', 'Less'],
#  ['ReduceSum', 'Resize', 'Mul'],
#  ['Atan', 'Greater', 'Cast'],
#  ['MatMul', 'Add', 'Softmax'],
#  ['Sub', 'Greater', 'Cast'],
#  ['Concat', 'Div', 'Sub'],
#  ['Concat', 'Cast', 'Cast', 'Or'],
#  ['Trilu', 'Trilu', 'Slice'],
#  ['LeakyRelu', 'Mul', 'MatMul'],
#  ['Cast', 'And', 'Cast', 'Or'],
#  ['Cast', 'Sub', 'Min'],
#  ['Resize', 'Ceil', 'Div'],
#  ['Concat', 'Sigmoid', 'Max'],
#  ['Resize', 'Conv', 'Pad'],
#  ['Add', 'Div', 'Greater'],
#  ['ReduceSum', 'Cast', 'Expand'],
#  ['Mul', 'Tan', 'Cast'],
#  ['Concat', 'Div', 'Concat'],
#  ['Resize', 'Resize', 'Shape'],
#  ['Cast', 'Cast', 'Mul'],
#  ['Concat', 'Resize', 'Ceil'],
#  ['Sin', 'Concat', 'Round'],
#  ['PRelu', 'Concat', 'Round'],
#  ['LeakyRelu', 'Concat', 'Add', 'Concat'],
#  ['Add', 'ReduceSum', 'Div'],
#  ['Cast', 'LeakyRelu', 'Tan'],
#  ['Mul', 'Max', 'Conv'],
#  ['Atan', 'Resize', 'Max'],
#  ['Cast', 'ArgMin', 'Expand'],
#  ['Cast', 'Sub', 'Cast'],
#  ['Concat', 'Where', 'Concat'],
#  ['Resize', 'Resize', 'Concat'],
#  ['ArgMin', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Cast', 'Sub'],
#  ['Sin', 'Expand', 'Concat'],
#  ['Clip', 'Reshape', 'Expand'],
#  ['Tan', 'Concat', 'Squeeze'],
#  ['Cast', 'Cast', 'Clip'],
#  ['PRelu', 'Cast', 'Cast'],
#  ['Mul', 'Mul', 'Sin'],
#  ['Where', 'Sin', 'Concat'],
#  ['Mul', 'Concat', 'Sigmoid'],
#  ['ReduceMax', 'Mul', 'Mul'],
#  ['Cast', 'Slice', 'Cast'],
#  ['Abs', 'Sub', 'LeakyRelu'],
#  ['Cast', 'Concat', 'Slice'],
#  ['Resize', 'Sin', 'Tan'],
#  ['Mul', 'Add', 'Concat'],
#  ['Pad', 'Resize', 'Concat'],
#  ['Where', 'Resize', 'Concat'],
#  ['Tan', 'Clip', 'Concat'],
#  ['Add', 'Cast', 'Cast'],
#  ['Cast', 'Cast', 'Transpose'],
#  ['Sub', 'MatMul', 'Add'],
#  ['Greater', 'Where', 'Slice'],
#  ['Sin', 'Cast', 'Cast'],
#  ['Less', 'Cast', 'Or', 'Cast'],
#  ['ArgMin', 'Greater', 'Where'],
#  ['Resize', 'Cast', 'Concat'],
#  ['Concat', 'Cast', 'Cast'],
#  ['Concat', 'Reshape', 'Floor'],
#  ['Cast', 'Xor', 'Cast'],
#  ['Concat', 'ArgMin', 'Min'],
#  ['ArgMin', 'Greater', 'Cast'],
#  ['Concat', 'Slice', 'Concat'],
#  ['Sin', 'Mul', 'Mul'],
#  ['Less', 'Where', 'Mul', 'Mul'],
#  ['Concat', 'MatMul', 'Add', 'ReduceMax'],
#  ['Atan', 'Abs', 'Concat'],
#  ['Pad', 'Concat', 'Div'],
#  ['Trilu', 'Cast', 'Cast'],
#  ['Ceil', 'Where', 'Concat'],
#  ['Ceil', 'Cast', 'Neg'],
#  ['ReduceSum', 'Resize', 'Resize'],
#  ['Ceil', 'Mul', 'Softmax'],
#  ['Mul', 'Mul', 'Softmax'],
#  ['Squeeze', 'Mul', 'Slice'],
#  ['Sin', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Concat', 'Sub'],
#  ['Pad', 'Mul', 'Mul'],
#  ['Greater', 'Cast', 'Where'],
#  ['Ceil', 'Sin', 'Max'],
#  ['Neg', 'Concat', 'Concat'],
#  ['Mul', 'Mul', 'Concat'],
#  ['Pad', 'Resize', 'Mul'],
#  ['MatMul', 'Max', 'Pad'],
#  ['Slice', 'Max', 'Resize'],
#  ['ReduceSum', 'MatMul', 'Max'],
#  ['Concat', 'Resize', 'Relu'],
#  ['Div', 'Concat', 'Neg'],
#  ['MatMul', 'LeakyRelu', 'Concat'],
#  ['Pad', 'AveragePool', 'Resize', 'MaxPool'],
#  ['Concat', 'ReduceMax', 'Add'],
#  ['Trilu', 'Trilu', 'Concat'],
#  ['Where', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'Cast'],
#  ['Concat', 'Resize', 'Transpose'],
#  ['ReduceMax', 'Add', 'Resize'],
#  ['Cast', 'Concat', 'Greater'],
#  ['ReduceMin', 'Cast', 'Where'],
#  ['Clip', 'Mul', 'Mul'],
#  ['Concat', 'LeakyRelu', 'ReduceMean'],
#  ['Transpose', 'Pad', 'AveragePool'],
#  ['Conv', 'Pad', 'AveragePool'],
#  ['Sub', 'Cast', 'Expand'],
#  ['MatMul', 'Add', 'Max'],
#  ['Ceil', 'Reshape', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Sub'],
#  ['Add', 'Add', 'Concat'],
#  ['Mul', 'Mul', 'Less'],
#  ['Floor', 'Cast', 'Cast', 'And'],
#  ['Cast', 'And', 'Cast', 'And', 'Where'],
#  ['Reshape', 'Cast', 'Cast'],
#  ['Atan', 'Softmax', 'Concat'],
#  ['MatMul', 'Add', 'Resize'],
#  ['Ceil', 'Atan', 'Trilu'],
#  ['MatMul', 'Add', 'ReduceSum'],
#  ['Add', 'Concat', 'Div'],
#  ['Xor', 'Where', 'Concat'],
#  ['Concat', 'MatMul', 'MatMul', 'Where'],
#  ['Atan', 'Cast', 'Sigmoid'],
#  ['Resize', 'Concat', 'Squeeze'],
#  ['Reshape', 'Expand', 'Pad'],
#  ['Trilu', 'Cast', 'Slice'],
#  ['ReduceSum', 'Sin', 'Cast'],
#  ['Concat', 'Neg', 'MatMul'],
#  ['Concat', 'Concat', 'Neg'],
#  ['Squeeze', 'Mul', 'Mul'],
#  ['Gemm', 'Mul', 'Mul'],
#  ['Cast', 'MatMul', 'Cast'],
#  ['ReduceMax', 'MatMul', 'Add'],
#  ['Reshape', 'MatMul', 'Add'],
#  ['Cast', 'Or', 'Cast', 'And'],
#  ['Relu', 'Concat', 'Slice'],
#  ['Tan', 'ReduceMean', 'Div'],
#  ['Mul', 'Shape', 'Slice', 'Concat'],
#  ['Resize', 'Concat', 'Cos'],
#  ['Cast', 'Mul', 'Mul'],
#  ['Atan', 'Div', 'Cos'],
#  ['Cast', 'Expand', 'ReduceMax'],
#  ['Abs', 'Concat', 'Min', 'MatMul'],
#  ['Neg', 'Concat', 'Conv'],
#  ['Mul', 'Mul', 'Tan'],
#  ['Concat', 'Concat', 'Concat'],
#  ['Add', 'Div', 'Add'],
#  ['Concat', 'Softmax', 'Div'],
#  ['Where', 'Less', 'Cast'],
#  ['Cast', 'Div', 'LeakyRelu'],
#  ['Mul', 'Cast', 'Slice'],
#  ['LeakyRelu', 'Resize', 'MatMul'],
#  ['Concat', 'Concat', 'Relu'],
#  ['Pad', 'Concat', 'Pad'],
#  ['LeakyRelu', 'Cast', 'Cast'],
#  ['Squeeze', 'Less', 'Cast'],
#  ['Concat', 'Mul', 'Div'],
#  ['Pad', 'AveragePool', 'Ceil'],
#  ['PRelu', 'Concat', 'Clip'],
#  ['Cast', 'Expand', 'Neg'],
#  ['Abs', 'Concat', 'Floor'],
#  ['Round', 'Where', 'Resize'],
#  ['Add', 'Less', 'Cast'],
#  ['Cast', 'And', 'Cast'],
#  ['MatMul', 'Add', 'Min', 'Concat'],
#  ['Pad', 'AveragePool', 'Concat'],
#  ['Sigmoid', 'Cast', 'Cast'],
#  ['Concat', 'Neg', 'Cast'],
#  ['Max', 'Concat', 'PRelu'],
#  ['Where', 'Sin', 'Concat', 'LeakyRelu'],
#  ['MatMul', 'Add', 'Min'],
#  ['MatMul', 'Cast', 'Mul'],
#  ['Resize', 'Cast', 'Add'],
#  ['Cast', 'Cast', 'Max'],
#  ['Relu', 'PRelu', 'PRelu'],
#  ['Cast', 'Cast', 'Floor'],
#  ['Where', 'Where', 'Shape'],
#  ['Cos', 'Concat', 'Concat'],
#  ['Slice', 'Cast', 'Cast'],
#  ['Greater', 'Cast', 'Or', 'Where'],
#  ['Add', 'Concat', 'PRelu'],
#  ['ReduceMin', 'Trilu', 'Trilu'],
#  ['Concat', 'ReduceMax', 'Concat'],
#  ['Concat', 'Resize', 'Sub'],
#  ['Mul', 'Mul', 'Min'],
#  ['Expand', 'Concat', 'Mul'],
#  ['Resize', 'Pad', 'AveragePool'],
#  ['Cast', 'Concat', 'Mul'],
#  ['Add', 'MatMul', 'Cast'],
#  ['PRelu', 'Concat', 'Resize', 'ReduceSum'],
#  ['Mul', 'Mul', 'Ceil'],
#  ['PRelu', 'Greater', 'Cast'],
#  ['Concat', 'Resize', 'MatMul'],
#  ['Min', 'Concat', 'Relu'],
#  ['ReduceSum', 'Cast', 'ArgMin'],
#  ['Cast', 'Sub', 'Mul'],
#  ['Add', 'Concat', 'MatMul', 'Add'],
#  ['Max', 'Concat', 'Concat'],
#  ['Concat', 'Mul', 'Mul'],
#  ['Atan', 'Sub', 'Mul'],
#  ['Sigmoid', 'Concat', 'Relu'],
#  ['Floor', 'Cast', 'Mul', 'Neg'],
#  ['Max', 'Concat', 'Reshape'],
#  ['Cast', 'Floor', 'Sin'],
#  ['Concat', 'Concat', 'Concat', 'Pad'],
#  ['Relu', 'Cast', 'Max'],
#  ['LeakyRelu', 'Min', 'Concat'],
#  ['Pad', 'AveragePool', 'ArgMin'],
#  ['Min', 'Atan', 'Pad'],
#  ['Ceil', 'Concat', 'Div'],
#  ['ReduceSum', 'Transpose', 'Trilu'],
#  ['Concat', 'Concat', 'ArgMin'],
#  ['Add', 'MatMul', 'Add'],
#  ['Sin', 'MatMul', 'Add'],
#  ['Cast', 'Cast', 'Xor'],
#  ['Atan', 'PRelu', 'Min'],
#  ['Concat', 'Max', 'Div'],
#  ['Atan', 'Reshape', 'MatMul'],
#  ['Greater', 'Cast', 'And'],
#  ['Ceil', 'Transpose', 'Conv'],
#  ['ReduceMean', 'Concat', 'LeakyRelu'],
#  ['Mul', 'Transpose', 'MatMul'],
#  ['ArgMax', 'Where', 'Slice'],
#  ['Relu', 'Concat', 'Concat'],
#  ['MatMul', 'Add', 'ReduceMin'],
#  ['Cast', 'Less', 'Cast'],
#  ['Slice', 'MatMul', 'Add'],
#  ['ReduceSum', 'Resize', 'Div'],
#  ['MatMul', 'Add', 'Squeeze'],
#  ['Greater', 'Cast', 'Xor'],
#  ['Max', 'Mul', 'Mul'],
#  ['Concat', 'Concat', 'Cast'],
#  ['Cast', 'Concat', 'Cast'],
#  ['Concat', 'Neg', 'MatMul', 'Add'],
#  ['MatMul', 'Add', 'MatMul'],
#  ['Conv', 'MatMul', 'Concat'],
#  ['Trilu', 'Max', 'Concat'],
#  ['Mul', 'MatMul', 'Add'],
#  ['Min', 'Concat', 'Cast'],
#  ['MatMul', 'Add', 'Mul', 'Mul'],
#  ['Cast', 'Pad', 'Resize'],
#  ['Cast', 'Atan', 'Div'],
#  ['MatMul', 'Add', 'Greater'],
#  ['Max', 'Concat', 'Relu'],
#  ['Cast', 'Cast', 'Concat'],
#  ['Expand', 'Concat', 'MatMul'],
#  ['Sin', 'Expand', 'Concat', 'ReduceMax'],
#  ['Mul', 'Max', 'Concat'],
#  ['Concat', 'Slice', 'Add'],
#  ['Mul', 'Pad', 'Shape'],
#  ['MatMul', 'Cast', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Sub'],
#  ['Pad', 'AveragePool', 'Tan'],
#  ['MatMul', 'Add', 'Sin'],
#  ['Pad', 'AveragePool', 'ReduceSum'],
#  ['Cast', 'Pad', 'Mul'],
#  ['Min', 'Concat', 'Min'],
#  ['Atan', 'Cast', 'Cast', 'Div'],
#  ['Reshape', 'Expand', 'Resize'],
#  ['Conv', 'ReduceMean', 'Concat'],
#  ['PRelu', 'Greater', 'Cast', 'Or'],
#  ['Min', 'Mul', 'Mul'],
#  ['Mul', 'Mul', 'Abs'],
#  ['MatMul', 'Cast', 'Div'],
#  ['Neg', 'Concat', 'Concat', 'Resize'],
#  ['ReduceMean', 'Greater', 'Cast'],
#  ['Relu', 'Squeeze', 'Concat'],
#  ['Cast', 'ReduceMax', 'Sub'],
#  ['MatMul', 'Mul', 'Mul'],
#  ['ReduceSum', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'Shape'],
#  ['ReduceMax', 'Ceil', 'BatchNormalization'],
#  ['MatMul', 'Mul', 'ReduceMax'],
#  ['Ceil', 'Mul', 'Mul'],
#  ['Less', 'Cast', 'And'],
#  ['Concat', 'LeakyRelu', 'Resize'],
#  ['Concat', 'Mul', 'Mul', 'Concat'],
#  ['Concat', 'Neg', 'Concat', 'Concat'],
#  ['ReduceMean', 'Add', 'Sub'],
#  ['Cast', 'Expand', 'Pad'],
#  ['ReduceMax', 'Trilu', 'Concat'],
#  ['Tan', 'Sub', 'Div'],
#  ['ReduceSum', 'Atan', 'PRelu'],
#  ['Slice', 'Concat', 'Reshape'],
#  ['MatMul', 'Add', 'Mul'],
#  ['MatMul', 'Add', 'ReduceMax'],
#  ['Mul', 'Mul', 'ReduceMin'],
#  ['Sigmoid', 'MatMul', 'Add'],
#  ['Concat', 'Div', 'Div'],
#  ['Expand', 'MatMul', 'Add'],
#  ['Round', 'Concat', 'Mul'],
#  ['MatMul', 'Concat', 'ReduceMax'],
#  ['Cast', 'Greater', 'Cast'],
#  ['ArgMin', 'Expand', 'Greater', 'Where'],
#  ['Squeeze', 'Add', 'Sub'],
#  ['Add', 'Mul', 'Mul'],
#  ['Cast', 'Floor', 'Ceil'],
#  ['Tan', 'MatMul', 'Add'],
#  ['ReduceSum', 'Concat', 'Add'],
#  ['Less', 'Cast', 'Where'],
#  ['Round', 'Concat', 'Neg'],
#  ['ReduceSum', 'Pad', 'AveragePool'],
#  ['Concat', 'Reshape', 'Expand'],
#  ['Mul', 'Mul', 'Add'],
#  ['Ceil', 'Concat', 'Sin'],
#  ['Concat', 'MatMul', 'MatMul'],
#  ['Concat', 'ReduceMin', 'Resize'],
#  ['Div', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Atan'],
#  ['Min', 'Concat', 'MatMul'],
#  ['Mul', 'Mul', 'Sigmoid'],
#  ['Slice', 'Pad', 'Concat'],
#  ['Sub', 'Sin', 'Div'],
#  ['Sub', 'Mul', 'Sigmoid'],
#  ['ArgMax', 'Cast', 'Cast'],
#  ['Where', 'Min', 'Concat'],
#  ['Shape', 'Gather', 'Equal', 'If'],
#  ['MatMul', 'Add', 'MatMul', 'Add'],
#  ['Cast', 'MatMul', 'Add'],
#  ['Mul', 'Softmax', 'MatMul'],
#  ['MatMul', 'Reshape', 'Concat'],
#  ['MatMul', 'Trilu', 'Trilu'],
#  ['Concat', 'Trilu', 'Cast'],
#  ['Pad', 'AveragePool', 'Resize'],
#  ['Reshape', 'Expand', 'MatMul'],
#  ['Cast', 'Cast', 'Min'],
#  ['Min', 'Concat', 'Concat'],
#  ['ReduceMean', 'MatMul', 'Add'],
#  ['ReduceMax', 'Pad', 'AveragePool'],
#  ['Pad', 'Mul', 'Div'],
#  ['Concat', 'Resize', 'Pad'],
#  ['Max', 'MatMul', 'Div'],
#  ['Concat', 'Sigmoid', 'Concat'],
#  ['LeakyRelu', 'Concat', 'Add'],
#  ['ArgMax', 'Reshape', 'Concat'],
#  ['Concat', 'ReduceMax', 'Reshape'],
#  ['ArgMax', 'Cast', 'Cast', 'Expand'],
#  ['Abs', 'Cast', 'Add'],
#  ['Pad', 'AveragePool', 'Round'],
#  ['Mul', 'Mul', 'Div'],
#  ['Relu', 'Mul', 'Mul'],
#  ['Concat', 'Softmax', 'Concat'],
#  ['Sin', 'Cast', 'Expand'],
#  ['Softmax', 'Concat', 'Concat'],
#  ['Sub', 'ReduceMean', 'Concat'],
#  ['Neg', 'ReduceMean', 'Concat'],
#  ['Atan', 'Resize', 'Pad'],
#  ['Cos', 'Cast', 'Cast', 'Mul'],
#  ['Concat', 'Concat', 'Resize'],
#  ['Cast', 'LeakyRelu', 'Concat'],
#  ['Expand', 'Greater', 'Cast'],
#  ['Tan', 'Concat', 'Mul'],
#  ['Cast', 'Or', 'Cast', 'Xor', 'Where'],
#  ['Pad', 'AveragePool', 'Conv'],
#  ['MatMul', 'MatMul', 'Where'],
#  ['Cast', 'Cast', 'Sub', 'Neg'],
#  ['ReduceSum', 'MatMul', 'Add'],
#  ['ReduceMean', 'Mul', 'Mul'],
#  ['Min', 'Max', 'Concat'],
#  ['Cast', 'Expand', 'Transpose'],
#  ['Mul', 'Mul', 'Round'],
#  ['Ceil', 'ReduceMax', 'Concat'],
#  ['Reshape', 'Expand', 'Trilu'],
#  ['Pad', 'AveragePool', 'Pad'],
#  ['Concat', 'MatMul', 'Mul'],
#  ['Div', 'Abs', 'Atan'],
#  ['Concat', 'Ceil', 'Sub'],
#  ['Cast', 'Or', 'Cast'],
#  ['ReduceMin', 'Sigmoid', 'Relu'],
#  ['Mul', 'Concat', 'Neg'],
#  ['Abs', 'Add', 'Cast'],
#  ['Cast', 'MatMul', 'Max'],
#  ['Expand', 'MatMul', 'MatMul'],
#  ['MatMul', 'Cast', 'Cast'],
#  ['Max', 'Concat', 'Tan'],
#  ['Cast', 'Cast', 'Sub'],
#  ['Concat', 'Concat', 'MatMul'],
#  ['ReduceSum', 'Mul', 'Mul'],
#  ['Floor', 'Cast', 'Mul'],
#  ['Pad', 'MatMul', 'Add'],
#  ['Concat', 'Add', 'Concat'],
#  ['Where', 'Concat', 'Clip'],
#  ['ReduceMin', 'Less', 'Cast', 'Xor'],
#  ['Concat', 'Concat', 'Floor'],
#  ['Resize', 'Concat', 'Sub'],
#  ['Pad', 'AveragePool', 'Div'],
#  ['Resize', 'MatMul', 'Add'],
#  ['Reshape', 'Concat', 'Max'],
#  ['MatMul', 'Max', 'Concat'],
#  ['Slice', 'Relu', 'Mul', 'Mul'],
#  ['MatMul', 'Cast', 'Mul', 'Mul'],
#  ['Concat', 'MatMul', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Concat'],
#  ['Min', 'Concat', 'Clip'],
#  ['Atan', 'Cast', 'LeakyRelu'],
#  ['Atan', 'Cast', 'Cast', 'Cast'],
#  ['Cast', 'And', 'Where'],
#  ['Cast', 'Cast', 'Or'],
#  ['Cast', 'Abs', 'Sub'],
#  ['Concat', 'Clip', 'Cast'],
#  ['Reshape', 'Expand', 'Concat'],
#  ['Cast', 'Cast', 'Abs'],
#  ['Pad', 'ArgMax', 'Reshape'],
#  ['Concat', 'Cast', 'Div'],
#  ['ReduceSum', 'Ceil', 'Concat'],
#  ['Mul', 'Slice', 'Shape'],
#  ['Cos', 'Concat', 'ReduceMax'],
#  ['Mul', 'Cast', 'Cast'],
#  ['MaxPool', 'Pad', 'AveragePool'],
#  ['Tan', 'Cast', 'Cast'],
#  ['Concat', 'Resize', 'Resize'],
#  ['Cast', 'Shape', 'Slice', 'Concat'],
#  ['Cast', 'Expand', 'Reshape'],
#  ['Expand', 'Pad', 'Pad'],
#  ['Concat', 'Concat', 'Ceil'],
#  ['Mul', 'Concat', 'Transpose', 'ReduceMean'],
#  ['Pad', 'Pad', 'AveragePool'],
#  ['ReduceSum', 'MatMul', 'Div'],
#  ['BatchNormalization', 'Pad', 'AveragePool'],
#  ['Concat', 'MatMul', 'Add', 'MatMul'],
#  ['Div', 'Abs', 'Atan', 'Div'],
#  ['Cast', 'Neg', 'Cast'],
#  ['Concat', 'Slice', 'Concat', 'Pad'],
#  ['Concat', 'Ceil', 'Mul'],
#  ['Softmax', 'Mul', 'Mul'],
#  ['Neg', 'Where', 'MatMul'],
#  ['Concat', 'Reshape', 'Softmax'],
#  ['Resize', 'Pad', 'Expand'],
#  ['Cast', 'Floor', 'LeakyRelu'],
#  ['MatMul', 'Add', 'Shape'],
#  ['Cast', 'Cast', 'Less'],
#  ['Cast', 'Expand', 'Concat'],
#  ['ReduceSum', 'MaxPool', 'Concat'],
#  ['ReduceMax', 'Resize', 'Concat'],
#  ['Cast', 'Cast', 'Cast'],
#  ['Resize', 'Pad', 'Div'],
#  ['Cast', 'Cast', 'Expand'],
#  ['Reshape', 'Cast', 'MatMul'],
#  ['Sub', 'Greater', 'Cast', 'Or'],
#  ['Reshape', 'Expand', 'Mul'],
#  ['MatMul', 'Neg', 'Concat'],
#  ['PRelu', 'Mul', 'Mul'],
#  ['Mul', 'Div', 'Ceil'],
#  ['Resize', 'Concat', 'Round'],
#  ['MaxPool', 'Shape', 'Slice', 'Concat'],
#  ['Concat', 'ReduceMin', 'Concat'],
#  ['Abs', 'Greater', 'Cast'],
#  ['Conv', 'Pad', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Or'],
#  ['ArgMin', 'Expand', 'Greater'],
#  ['Mul', 'Mul', 'Greater'],
#  ['Cast', 'Where', 'Concat'],
#  ['MatMul', 'Add', 'Ceil'],
#  ['Cast', 'Xor', 'Where'],
#  ['Abs', 'MatMul', 'Add'],
#  ['Squeeze', 'Less', 'Cast', 'Or'],
#  ['Round', 'Concat', 'ReduceSum'],
#  ['Sin', 'Concat', 'PRelu'],
#  ['Ceil', 'Concat', 'Concat'],
#  ['Where', 'Mul', 'Mul'],
#  ['Cast', 'Xor', 'Where', 'Min'],
#  ['Reshape', 'Conv', 'Reshape'],
#  ['ReduceMax', 'Pad', 'Shape'],
#  ['MatMul', 'Add', 'Cast'],
#  ['Abs', 'Mul', 'Cast'],
#  ['PRelu', 'Concat', 'Resize'],
#  ['Cos', 'Cast', 'Cast'],
#  ['Concat', 'Transpose', 'ReduceMean'],
#  ['MatMul', 'Add', 'Slice'],
#  ['Relu', 'Concat', 'Sigmoid'],
#  ['Cast', 'Reshape', 'MatMul'],
#  ['Sub', 'ReduceSum', 'MatMul'],
#  ['Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'PRelu'],
#  ['ReduceMax', 'ReduceMean', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Mul'],
#  ['Concat', 'Concat', 'Div'],
#  ['Concat', 'Cast', 'Ceil'],
#  ['Concat', 'Resize', 'Conv'],
#  ['Pad', 'Max', 'Concat'],
#  ['Cast', 'Floor', 'Cast'],
#  ['Concat', 'Clip', 'Concat'],
#  ['Mul', 'Mul', 'Clip'],
#  ['Squeeze', 'Mul', 'Div'],
#  ['ReduceSum', 'Resize', 'Concat'],
#  ['ArgMax', 'Greater', 'Where'],
#  ['Cast', 'Concat', 'Less'],
#  ['ArgMin', 'Expand', 'Cast'],
#  ['Less', 'Cast', 'Or'],
#  ['Relu', 'Mul', 'Mul', 'Mul'],
#  ['Cos', 'Mul', 'Mul'],
#  ['Mul', 'Mul', 'MatMul'],
#  ['Floor', 'Cast', 'Concat'],
#  ['Floor', 'Cast', 'Cast'],
#  ['Concat', 'Relu', 'Concat'],
#  ['Slice', 'Concat', 'Neg', 'Cast'],
#  ['Pad', 'AveragePool', 'BatchNormalization'],
#  ['Concat', 'Concat', 'Softmax'],
#  ['Pad', 'Div', 'Max'],
#  ['Expand', 'Resize', 'Conv'],
#  ['Where', 'MatMul', 'Add'],
#  ['ReduceMean', 'Trilu', 'Concat'],
#  ['Pad', 'Expand', 'Conv'],
#  ['Slice', 'Concat', 'Neg'],
#  ['Expand', 'Greater', 'Cast', 'And'],
#  ['Tan', 'Pad', 'Mul'],
#  ['Clip', 'Clip', 'Mul'],
#  ['Resize', 'Pad', 'Conv'],
#  ['Where', 'Concat', 'PRelu'],
#  ['Sub', 'Cast', 'Sub'],
#  ['Floor', 'Cast', 'Abs'],
#  ['Add', 'Concat', 'Concat'],
#  ['Pad', 'Div', 'Resize'],
#  ['Concat', 'Resize', 'ReduceSum'],
#  ['ReduceMin', 'MatMul', 'Concat'],
#  ['Reshape', 'MatMul', 'Concat'],
#  ['Max', 'Concat', 'Round'],
#  ['Reshape', 'Concat', 'Concat'],
#  ['Round', 'Shape', 'Slice', 'Concat'],
#  ['Abs', 'Cast', 'Concat'],
#  ['Sigmoid', 'Concat', 'Concat'],
#  ['Greater', 'Cast', 'Or'],
#  ['Cast', 'Or', 'Where'],
#  ['Add', 'Cast', 'Concat'],
#  ['Sigmoid', 'Mul', 'Mul'],
#  ['Cast', 'Add', 'Cast'],
#  ['MatMul', 'Mul', 'Mul', 'Min'],
#  ['Abs', 'Concat', 'PRelu'],
#  ['Add', 'Floor', 'Concat'],
#  ['Cast', 'Or', 'Where', 'Round'],
#  ['Add', 'Concat', 'MatMul'],
#  ['Pad', 'ReduceSum', 'Concat'],
#  ['ReduceMean', 'Concat', 'Cast'],
#  ['Cast', 'Expand', 'MatMul'],
#  ['Mul', 'Mul', 'Mul'],
#  ['Concat', 'Max', 'Mul', 'Mul'],
#  ['Pad', 'Concat', 'ReduceMax'],
#  ['Concat', 'Min', 'MatMul'],
#  ['Conv', 'Pad', 'Pad'],
#  ['Cast', 'Concat', 'Max'],
#  ['Floor', 'MatMul', 'Add'],
#  ['PRelu', 'Concat', 'Add'],
#  ['Div', 'Concat', 'Min'],
#  ['LeakyRelu', 'Mul', 'Mul'],
#  ['Concat', 'Neg', 'Concat'],
#  ['Abs', 'Cast', 'Add', 'Cast'],
#  ['Sub', 'Concat', 'ReduceMean'],
#  ['Cast', 'Expand', 'ReduceSum'],
#  ['Add', 'Min', 'Concat'],
#  ['Cast', 'Cast', 'And'],
#  ['Cast', 'Expand', 'Cast'],
#  ['ReduceMean', 'Mul', 'Concat'],
#  ['ReduceMean', 'Ceil', 'Concat'],
#  ['Cast', 'Cast', 'Div'],
#  ['Cast', 'Expand', 'Add'],
#  ['Sub', 'Mul', 'Sub'],
#  ['Neg', 'Cast', 'Sub'],
#  ['Concat', 'Reshape', 'Concat'],
#  ['Atan', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Abs'],
#  ['Cast', 'Cast', 'Or', 'Cast'],
#  ['Cos', 'Relu', 'Concat'],
#  ['MatMul', 'Add', 'Relu'],
#  ['Atan', 'Softmax', 'Concat', 'Concat'],
#  ['Cast', 'Mul', 'Min'],
#  ['Conv', 'Squeeze', 'Greater'],
#  ['Squeeze', 'Pad', 'AveragePool'],
#  ['Softmax', 'Max', 'Div'],
#  ['Ceil', 'Cast', 'Sub'],
#  ['Concat', 'MatMul', 'Add'],
#  ['Expand', 'Concat', 'ReduceMax'],
#  ['Slice', 'Relu', 'Mul'],
#  ['PRelu', 'LeakyRelu', 'Mul'],
#  ['Concat', 'Resize', 'Min'],
#  ['Max', 'Div', 'Shape'],
#  ['Cast', 'Slice', 'Mul'],
#  ['Concat', 'Concat', 'Pad'],
#  ['Cos', 'Mul', 'Mul', 'Max'],
#  ['Cast', 'ReduceMax', 'Sub', 'Mul'],
#  ['Ceil', 'Sin', 'Cast'],
#  ['Less', 'Cast', 'Xor'],
#  ['ReduceMax', 'Add', 'Sub'],
#  ['Sub', 'Concat', 'Concat'],
#  ['Mul', 'Mul', 'Sub'],
#  ['Cast', 'Cast', 'Mul', 'Mul'],
#  ['ReduceSum', 'Concat', 'Resize'],
#  ['MatMul', 'Concat', 'MatMul'],
#  ['Cos', 'Add', 'Div'],
#  ['Expand', 'Pad', 'AveragePool'],
#  ['Pad', 'Conv', 'Pad'],
#  ['LeakyRelu', 'Concat', 'Cast'],
#  ['Atan', 'Reshape', 'Expand'],
#  ['Cos', 'Cast', 'Expand'],
#  ['Cast', 'Cast', 'Neg'],
#  ['Cast', 'Cast', 'ReduceSum'],
#  ['Concat', 'Max', 'Concat'],
#  ['Pad', 'Concat', 'ReduceMax', 'Concat'],
#  ['Softmax', 'Concat', 'LeakyRelu'],
#  ['Min', 'Concat', 'ArgMin']]

# %%
list(
    filter(
        lambda x: (len(x) > 2) and ("input" not in x) and ("output" not in x),
        detokenize_seqs(token_node_type_dict, reduced_sequences),
    )
)
# Out:
# [['Max', 'Concat', 'Div'],
#  ['Where', 'Concat', 'Reshape'],
#  ['Min', 'ArgMax', 'Cast'],
#  ['Mul', 'Concat', 'Resize'],
#  ['MatMul', 'Add', 'Div'],
#  ['Cast', 'Max', 'Cast'],
#  ['Ceil', 'Concat', 'Softmax'],
#  ['Squeeze', 'Abs', 'Concat'],
#  ['Atan', 'Mul', 'Mul'],
#  ['MatMul', 'Mul', 'Concat'],
#  ['Cast', 'Concat', 'Cast', 'Div'],
#  ['Mul', 'Cast', 'Concat'],
#  ['Atan', 'Resize', 'Round'],
#  ['Cast', 'Add', 'Resize'],
#  ['Ceil', 'Relu', 'Concat'],
#  ['Mul', 'Concat', 'Concat'],
#  ['Concat', 'Pad', 'AveragePool'],
#  ['ArgMax', 'Greater', 'Where', 'Slice'],
#  ['Softmax', 'MatMul', 'Add'],
#  ['Cast', 'Mul', 'Trilu'],
#  ['Concat', 'Cast', 'Sub'],
#  ['ReduceMean', 'Trilu', 'Trilu'],
#  ['Mul', 'Mul', 'Where'],
#  ['Mul', 'Concat', 'Transpose'],
#  ['Softmax', 'Reshape', 'Concat'],
#  ['Cast', 'MatMul', 'Div'],
#  ['Resize', 'Abs', 'ReduceMax'],
#  ['Concat', 'Resize', 'Concat'],
#  ['Mul', 'Mul', 'Max'],
#  ['Resize', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Add'],
#  ['Relu', 'Mul', 'Slice'],
#  ['Ceil', 'Cast', 'ArgMax'],
#  ['Mul', 'Max', 'Where'],
#  ['Trilu', 'LeakyRelu', 'Sub'],
#  ['Mul', 'Softmax', 'Pad'],
#  ['Ceil', 'Max', 'Conv'],
#  ['Pad', 'Expand', 'Resize'],
#  ['Sigmoid', 'Shape', 'Slice', 'Concat'],
#  ['Cast', 'Abs', 'Less'],
#  ['ReduceSum', 'Resize', 'Mul'],
#  ['Atan', 'Greater', 'Cast'],
#  ['MatMul', 'Add', 'Softmax'],
#  ['Sub', 'Greater', 'Cast'],
#  ['Concat', 'Div', 'Sub'],
#  ['Concat', 'Cast', 'Cast', 'Or'],
#  ['Trilu', 'Trilu', 'Slice'],
#  ['LeakyRelu', 'Mul', 'MatMul'],
#  ['Cast', 'And', 'Cast', 'Or'],
#  ['Cast', 'Sub', 'Min'],
#  ['Resize', 'Ceil', 'Div'],
#  ['Concat', 'Sigmoid', 'Max'],
#  ['Resize', 'Conv', 'Pad'],
#  ['Add', 'Div', 'Greater'],
#  ['ReduceSum', 'Cast', 'Expand'],
#  ['Mul', 'Tan', 'Cast'],
#  ['Concat', 'Div', 'Concat'],
#  ['Resize', 'Resize', 'Shape'],
#  ['Cast', 'Cast', 'Mul'],
#  ['Concat', 'Resize', 'Ceil'],
#  ['Sin', 'Concat', 'Round'],
#  ['PRelu', 'Concat', 'Round'],
#  ['LeakyRelu', 'Concat', 'Add', 'Concat'],
#  ['Add', 'ReduceSum', 'Div'],
#  ['Cast', 'LeakyRelu', 'Tan'],
#  ['Mul', 'Max', 'Conv'],
#  ['Atan', 'Resize', 'Max'],
#  ['Cast', 'ArgMin', 'Expand'],
#  ['Cast', 'Sub', 'Cast'],
#  ['Concat', 'Where', 'Concat'],
#  ['Resize', 'Resize', 'Concat'],
#  ['ArgMin', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Cast', 'Sub'],
#  ['Sin', 'Expand', 'Concat'],
#  ['Clip', 'Reshape', 'Expand'],
#  ['Tan', 'Concat', 'Squeeze'],
#  ['Cast', 'Cast', 'Clip'],
#  ['PRelu', 'Cast', 'Cast'],
#  ['Mul', 'Mul', 'Sin'],
#  ['Where', 'Sin', 'Concat'],
#  ['Mul', 'Concat', 'Sigmoid'],
#  ['ReduceMax', 'Mul', 'Mul'],
#  ['Cast', 'Slice', 'Cast'],
#  ['Abs', 'Sub', 'LeakyRelu'],
#  ['Cast', 'Concat', 'Slice'],
#  ['Resize', 'Sin', 'Tan'],
#  ['Mul', 'Add', 'Concat'],
#  ['Pad', 'Resize', 'Concat'],
#  ['Where', 'Resize', 'Concat'],
#  ['Tan', 'Clip', 'Concat'],
#  ['Add', 'Cast', 'Cast'],
#  ['Cast', 'Cast', 'Transpose'],
#  ['Sub', 'MatMul', 'Add'],
#  ['Greater', 'Where', 'Slice'],
#  ['Sin', 'Cast', 'Cast'],
#  ['Less', 'Cast', 'Or', 'Cast'],
#  ['ArgMin', 'Greater', 'Where'],
#  ['Resize', 'Cast', 'Concat'],
#  ['Concat', 'Cast', 'Cast'],
#  ['Concat', 'Reshape', 'Floor'],
#  ['Cast', 'Xor', 'Cast'],
#  ['Concat', 'ArgMin', 'Min'],
#  ['ArgMin', 'Greater', 'Cast'],
#  ['Concat', 'Slice', 'Concat'],
#  ['Sin', 'Mul', 'Mul'],
#  ['Less', 'Where', 'Mul', 'Mul'],
#  ['Concat', 'MatMul', 'Add', 'ReduceMax'],
#  ['Atan', 'Abs', 'Concat'],
#  ['Pad', 'Concat', 'Div'],
#  ['Trilu', 'Cast', 'Cast'],
#  ['Ceil', 'Where', 'Concat'],
#  ['Ceil', 'Cast', 'Neg'],
#  ['ReduceSum', 'Resize', 'Resize'],
#  ['Ceil', 'Mul', 'Softmax'],
#  ['Mul', 'Mul', 'Softmax'],
#  ['Squeeze', 'Mul', 'Slice'],
#  ['Sin', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Concat', 'Sub'],
#  ['Pad', 'Mul', 'Mul'],
#  ['Greater', 'Cast', 'Where'],
#  ['Ceil', 'Sin', 'Max'],
#  ['Neg', 'Concat', 'Concat'],
#  ['Mul', 'Mul', 'Concat'],
#  ['Pad', 'Resize', 'Mul'],
#  ['MatMul', 'Max', 'Pad'],
#  ['Slice', 'Max', 'Resize'],
#  ['ReduceSum', 'MatMul', 'Max'],
#  ['Concat', 'Resize', 'Relu'],
#  ['Div', 'Concat', 'Neg'],
#  ['MatMul', 'LeakyRelu', 'Concat'],
#  ['Pad', 'AveragePool', 'Resize', 'MaxPool'],
#  ['Concat', 'ReduceMax', 'Add'],
#  ['Trilu', 'Trilu', 'Concat'],
#  ['Where', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'Cast'],
#  ['Concat', 'Resize', 'Transpose'],
#  ['ReduceMax', 'Add', 'Resize'],
#  ['Cast', 'Concat', 'Greater'],
#  ['ReduceMin', 'Cast', 'Where'],
#  ['Clip', 'Mul', 'Mul'],
#  ['Concat', 'LeakyRelu', 'ReduceMean'],
#  ['Transpose', 'Pad', 'AveragePool'],
#  ['Conv', 'Pad', 'AveragePool'],
#  ['Sub', 'Cast', 'Expand'],
#  ['MatMul', 'Add', 'Max'],
#  ['Ceil', 'Reshape', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Sub'],
#  ['Add', 'Add', 'Concat'],
#  ['Mul', 'Mul', 'Less'],
#  ['Floor', 'Cast', 'Cast', 'And'],
#  ['Cast', 'And', 'Cast', 'And', 'Where'],
#  ['Reshape', 'Cast', 'Cast'],
#  ['Atan', 'Softmax', 'Concat'],
#  ['MatMul', 'Add', 'Resize'],
#  ['Ceil', 'Atan', 'Trilu'],
#  ['MatMul', 'Add', 'ReduceSum'],
#  ['Add', 'Concat', 'Div'],
#  ['Xor', 'Where', 'Concat'],
#  ['Concat', 'MatMul', 'MatMul', 'Where'],
#  ['Atan', 'Cast', 'Sigmoid'],
#  ['Resize', 'Concat', 'Squeeze'],
#  ['Reshape', 'Expand', 'Pad'],
#  ['Trilu', 'Cast', 'Slice'],
#  ['ReduceSum', 'Sin', 'Cast'],
#  ['Concat', 'Neg', 'MatMul'],
#  ['Concat', 'Concat', 'Neg'],
#  ['Squeeze', 'Mul', 'Mul'],
#  ['Gemm', 'Mul', 'Mul'],
#  ['Cast', 'MatMul', 'Cast'],
#  ['ReduceMax', 'MatMul', 'Add'],
#  ['Reshape', 'MatMul', 'Add'],
#  ['Cast', 'Or', 'Cast', 'And'],
#  ['Relu', 'Concat', 'Slice'],
#  ['Tan', 'ReduceMean', 'Div'],
#  ['Mul', 'Shape', 'Slice', 'Concat'],
#  ['Resize', 'Concat', 'Cos'],
#  ['Cast', 'Mul', 'Mul'],
#  ['Atan', 'Div', 'Cos'],
#  ['Cast', 'Expand', 'ReduceMax'],
#  ['Abs', 'Concat', 'Min', 'MatMul'],
#  ['Neg', 'Concat', 'Conv'],
#  ['Mul', 'Mul', 'Tan'],
#  ['Concat', 'Concat', 'Concat'],
#  ['Add', 'Div', 'Add'],
#  ['Concat', 'Softmax', 'Div'],
#  ['Where', 'Less', 'Cast'],
#  ['Cast', 'Div', 'LeakyRelu'],
#  ['Mul', 'Cast', 'Slice'],
#  ['LeakyRelu', 'Resize', 'MatMul'],
#  ['Concat', 'Concat', 'Relu'],
#  ['Pad', 'Concat', 'Pad'],
#  ['LeakyRelu', 'Cast', 'Cast'],
#  ['Squeeze', 'Less', 'Cast'],
#  ['Concat', 'Mul', 'Div'],
#  ['Pad', 'AveragePool', 'Ceil'],
#  ['PRelu', 'Concat', 'Clip'],
#  ['Cast', 'Expand', 'Neg'],
#  ['Abs', 'Concat', 'Floor'],
#  ['Round', 'Where', 'Resize'],
#  ['Add', 'Less', 'Cast'],
#  ['Cast', 'And', 'Cast'],
#  ['MatMul', 'Add', 'Min', 'Concat'],
#  ['Pad', 'AveragePool', 'Concat'],
#  ['Sigmoid', 'Cast', 'Cast'],
#  ['Concat', 'Neg', 'Cast'],
#  ['Max', 'Concat', 'PRelu'],
#  ['Where', 'Sin', 'Concat', 'LeakyRelu'],
#  ['MatMul', 'Add', 'Min'],
#  ['MatMul', 'Cast', 'Mul'],
#  ['Resize', 'Cast', 'Add'],
#  ['Cast', 'Cast', 'Max'],
#  ['Relu', 'PRelu', 'PRelu'],
#  ['Cast', 'Cast', 'Floor'],
#  ['Where', 'Where', 'Shape'],
#  ['Cos', 'Concat', 'Concat'],
#  ['Slice', 'Cast', 'Cast'],
#  ['Greater', 'Cast', 'Or', 'Where'],
#  ['Add', 'Concat', 'PRelu'],
#  ['ReduceMin', 'Trilu', 'Trilu'],
#  ['Concat', 'ReduceMax', 'Concat'],
#  ['Concat', 'Resize', 'Sub'],
#  ['Mul', 'Mul', 'Min'],
#  ['Expand', 'Concat', 'Mul'],
#  ['Resize', 'Pad', 'AveragePool'],
#  ['Cast', 'Concat', 'Mul'],
#  ['Add', 'MatMul', 'Cast'],
#  ['PRelu', 'Concat', 'Resize', 'ReduceSum'],
#  ['Mul', 'Mul', 'Ceil'],
#  ['PRelu', 'Greater', 'Cast'],
#  ['Concat', 'Resize', 'MatMul'],
#  ['Min', 'Concat', 'Relu'],
#  ['ReduceSum', 'Cast', 'ArgMin'],
#  ['Cast', 'Sub', 'Mul'],
#  ['Add', 'Concat', 'MatMul', 'Add'],
#  ['Max', 'Concat', 'Concat'],
#  ['Concat', 'Mul', 'Mul'],
#  ['Atan', 'Sub', 'Mul'],
#  ['Sigmoid', 'Concat', 'Relu'],
#  ['Floor', 'Cast', 'Mul', 'Neg'],
#  ['Max', 'Concat', 'Reshape'],
#  ['Cast', 'Floor', 'Sin'],
#  ['Concat', 'Concat', 'Concat', 'Pad'],
#  ['Relu', 'Cast', 'Max'],
#  ['LeakyRelu', 'Min', 'Concat'],
#  ['Pad', 'AveragePool', 'ArgMin'],
#  ['Min', 'Atan', 'Pad'],
#  ['Ceil', 'Concat', 'Div'],
#  ['ReduceSum', 'Transpose', 'Trilu'],
#  ['Concat', 'Concat', 'ArgMin'],
#  ['Add', 'MatMul', 'Add'],
#  ['Sin', 'MatMul', 'Add'],
#  ['Cast', 'Cast', 'Xor'],
#  ['Atan', 'PRelu', 'Min'],
#  ['Concat', 'Max', 'Div'],
#  ['Atan', 'Reshape', 'MatMul'],
#  ['Greater', 'Cast', 'And'],
#  ['Ceil', 'Transpose', 'Conv'],
#  ['ReduceMean', 'Concat', 'LeakyRelu'],
#  ['Mul', 'Transpose', 'MatMul'],
#  ['ArgMax', 'Where', 'Slice'],
#  ['Relu', 'Concat', 'Concat'],
#  ['MatMul', 'Add', 'ReduceMin'],
#  ['Cast', 'Less', 'Cast'],
#  ['Slice', 'MatMul', 'Add'],
#  ['ReduceSum', 'Resize', 'Div'],
#  ['MatMul', 'Add', 'Squeeze'],
#  ['Greater', 'Cast', 'Xor'],
#  ['Max', 'Mul', 'Mul'],
#  ['Concat', 'Concat', 'Cast'],
#  ['Cast', 'Concat', 'Cast'],
#  ['Concat', 'Neg', 'MatMul', 'Add'],
#  ['MatMul', 'Add', 'MatMul'],
#  ['Conv', 'MatMul', 'Concat'],
#  ['Trilu', 'Max', 'Concat'],
#  ['Mul', 'MatMul', 'Add'],
#  ['Min', 'Concat', 'Cast'],
#  ['MatMul', 'Add', 'Mul', 'Mul'],
#  ['Cast', 'Pad', 'Resize'],
#  ['Cast', 'Atan', 'Div'],
#  ['MatMul', 'Add', 'Greater'],
#  ['Max', 'Concat', 'Relu'],
#  ['Cast', 'Cast', 'Concat'],
#  ['Expand', 'Concat', 'MatMul'],
#  ['Sin', 'Expand', 'Concat', 'ReduceMax'],
#  ['Mul', 'Max', 'Concat'],
#  ['Concat', 'Slice', 'Add'],
#  ['Mul', 'Pad', 'Shape'],
#  ['MatMul', 'Cast', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Sub'],
#  ['Pad', 'AveragePool', 'Tan'],
#  ['MatMul', 'Add', 'Sin'],
#  ['Pad', 'AveragePool', 'ReduceSum'],
#  ['Cast', 'Pad', 'Mul'],
#  ['Min', 'Concat', 'Min'],
#  ['Atan', 'Cast', 'Cast', 'Div'],
#  ['Reshape', 'Expand', 'Resize'],
#  ['Conv', 'ReduceMean', 'Concat'],
#  ['PRelu', 'Greater', 'Cast', 'Or'],
#  ['Min', 'Mul', 'Mul'],
#  ['Mul', 'Mul', 'Abs'],
#  ['MatMul', 'Cast', 'Div'],
#  ['Neg', 'Concat', 'Concat', 'Resize'],
#  ['ReduceMean', 'Greater', 'Cast'],
#  ['Relu', 'Squeeze', 'Concat'],
#  ['Cast', 'ReduceMax', 'Sub'],
#  ['MatMul', 'Mul', 'Mul'],
#  ['ReduceSum', 'Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'Shape'],
#  ['ReduceMax', 'Ceil', 'BatchNormalization'],
#  ['MatMul', 'Mul', 'ReduceMax'],
#  ['Ceil', 'Mul', 'Mul'],
#  ['Less', 'Cast', 'And'],
#  ['Concat', 'LeakyRelu', 'Resize'],
#  ['Concat', 'Mul', 'Mul', 'Concat'],
#  ['Concat', 'Neg', 'Concat', 'Concat'],
#  ['ReduceMean', 'Add', 'Sub'],
#  ['Cast', 'Expand', 'Pad'],
#  ['ReduceMax', 'Trilu', 'Concat'],
#  ['Tan', 'Sub', 'Div'],
#  ['ReduceSum', 'Atan', 'PRelu'],
#  ['Slice', 'Concat', 'Reshape'],
#  ['MatMul', 'Add', 'Mul'],
#  ['MatMul', 'Add', 'ReduceMax'],
#  ['Mul', 'Mul', 'ReduceMin'],
#  ['Sigmoid', 'MatMul', 'Add'],
#  ['Concat', 'Div', 'Div'],
#  ['Expand', 'MatMul', 'Add'],
#  ['Round', 'Concat', 'Mul'],
#  ['MatMul', 'Concat', 'ReduceMax'],
#  ['Cast', 'Greater', 'Cast'],
#  ['ArgMin', 'Expand', 'Greater', 'Where'],
#  ['Squeeze', 'Add', 'Sub'],
#  ['Add', 'Mul', 'Mul'],
#  ['Cast', 'Floor', 'Ceil'],
#  ['Tan', 'MatMul', 'Add'],
#  ['ReduceSum', 'Concat', 'Add'],
#  ['Less', 'Cast', 'Where'],
#  ['Round', 'Concat', 'Neg'],
#  ['ReduceSum', 'Pad', 'AveragePool'],
#  ['Concat', 'Reshape', 'Expand'],
#  ['Mul', 'Mul', 'Add'],
#  ['Ceil', 'Concat', 'Sin'],
#  ['Concat', 'MatMul', 'MatMul'],
#  ['Concat', 'ReduceMin', 'Resize'],
#  ['Div', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Atan'],
#  ['Min', 'Concat', 'MatMul'],
#  ['Mul', 'Mul', 'Sigmoid'],
#  ['Slice', 'Pad', 'Concat'],
#  ['Sub', 'Sin', 'Div'],
#  ['Sub', 'Mul', 'Sigmoid'],
#  ['ArgMax', 'Cast', 'Cast'],
#  ['Where', 'Min', 'Concat'],
#  ['Shape', 'Gather', 'Equal', 'If'],
#  ['MatMul', 'Add', 'MatMul', 'Add'],
#  ['Cast', 'MatMul', 'Add'],
#  ['Mul', 'Softmax', 'MatMul'],
#  ['MatMul', 'Reshape', 'Concat'],
#  ['MatMul', 'Trilu', 'Trilu'],
#  ['Concat', 'Trilu', 'Cast'],
#  ['Pad', 'AveragePool', 'Resize'],
#  ['Reshape', 'Expand', 'MatMul'],
#  ['Cast', 'Cast', 'Min'],
#  ['Min', 'Concat', 'Concat'],
#  ['ReduceMean', 'MatMul', 'Add'],
#  ['ReduceMax', 'Pad', 'AveragePool'],
#  ['Pad', 'Mul', 'Div'],
#  ['Concat', 'Resize', 'Pad'],
#  ['Max', 'MatMul', 'Div'],
#  ['Concat', 'Sigmoid', 'Concat'],
#  ['LeakyRelu', 'Concat', 'Add'],
#  ['ArgMax', 'Reshape', 'Concat'],
#  ['Concat', 'ReduceMax', 'Reshape'],
#  ['ArgMax', 'Cast', 'Cast', 'Expand'],
#  ['Abs', 'Cast', 'Add'],
#  ['Pad', 'AveragePool', 'Round'],
#  ['Mul', 'Mul', 'Div'],
#  ['Relu', 'Mul', 'Mul'],
#  ['Concat', 'Softmax', 'Concat'],
#  ['Sin', 'Cast', 'Expand'],
#  ['Softmax', 'Concat', 'Concat'],
#  ['Sub', 'ReduceMean', 'Concat'],
#  ['Neg', 'ReduceMean', 'Concat'],
#  ['Atan', 'Resize', 'Pad'],
#  ['Cos', 'Cast', 'Cast', 'Mul'],
#  ['Concat', 'Concat', 'Resize'],
#  ['Cast', 'LeakyRelu', 'Concat'],
#  ['Expand', 'Greater', 'Cast'],
#  ['Tan', 'Concat', 'Mul'],
#  ['Cast', 'Or', 'Cast', 'Xor', 'Where'],
#  ['Pad', 'AveragePool', 'Conv'],
#  ['MatMul', 'MatMul', 'Where'],
#  ['Cast', 'Cast', 'Sub', 'Neg'],
#  ['ReduceSum', 'MatMul', 'Add'],
#  ['ReduceMean', 'Mul', 'Mul'],
#  ['Min', 'Max', 'Concat'],
#  ['Cast', 'Expand', 'Transpose'],
#  ['Mul', 'Mul', 'Round'],
#  ['Ceil', 'ReduceMax', 'Concat'],
#  ['Reshape', 'Expand', 'Trilu'],
#  ['Pad', 'AveragePool', 'Pad'],
#  ['Concat', 'MatMul', 'Mul'],
#  ['Div', 'Abs', 'Atan'],
#  ['Concat', 'Ceil', 'Sub'],
#  ['Cast', 'Or', 'Cast'],
#  ['ReduceMin', 'Sigmoid', 'Relu'],
#  ['Mul', 'Concat', 'Neg'],
#  ['Abs', 'Add', 'Cast'],
#  ['Cast', 'MatMul', 'Max'],
#  ['Expand', 'MatMul', 'MatMul'],
#  ['MatMul', 'Cast', 'Cast'],
#  ['Max', 'Concat', 'Tan'],
#  ['Cast', 'Cast', 'Sub'],
#  ['Concat', 'Concat', 'MatMul'],
#  ['ReduceSum', 'Mul', 'Mul'],
#  ['Floor', 'Cast', 'Mul'],
#  ['Pad', 'MatMul', 'Add'],
#  ['Concat', 'Add', 'Concat'],
#  ['Where', 'Concat', 'Clip'],
#  ['ReduceMin', 'Less', 'Cast', 'Xor'],
#  ['Concat', 'Concat', 'Floor'],
#  ['Resize', 'Concat', 'Sub'],
#  ['Pad', 'AveragePool', 'Div'],
#  ['Resize', 'MatMul', 'Add'],
#  ['Reshape', 'Concat', 'Max'],
#  ['MatMul', 'Max', 'Concat'],
#  ['Slice', 'Relu', 'Mul', 'Mul'],
#  ['MatMul', 'Cast', 'Mul', 'Mul'],
#  ['Concat', 'MatMul', 'Mul', 'Mul'],
#  ['MatMul', 'Add', 'Concat'],
#  ['Min', 'Concat', 'Clip'],
#  ['Atan', 'Cast', 'LeakyRelu'],
#  ['Atan', 'Cast', 'Cast', 'Cast'],
#  ['Cast', 'And', 'Where'],
#  ['Cast', 'Cast', 'Or'],
#  ['Cast', 'Abs', 'Sub'],
#  ['Concat', 'Clip', 'Cast'],
#  ['Reshape', 'Expand', 'Concat'],
#  ['Cast', 'Cast', 'Abs'],
#  ['Pad', 'ArgMax', 'Reshape'],
#  ['Concat', 'Cast', 'Div'],
#  ['ReduceSum', 'Ceil', 'Concat'],
#  ['Mul', 'Slice', 'Shape'],
#  ['Cos', 'Concat', 'ReduceMax'],
#  ['Mul', 'Cast', 'Cast'],
#  ['MaxPool', 'Pad', 'AveragePool'],
#  ['Tan', 'Cast', 'Cast'],
#  ['Concat', 'Resize', 'Resize'],
#  ['Cast', 'Shape', 'Slice', 'Concat'],
#  ['Cast', 'Expand', 'Reshape'],
#  ['Expand', 'Pad', 'Pad'],
#  ['Concat', 'Concat', 'Ceil'],
#  ['Mul', 'Concat', 'Transpose', 'ReduceMean'],
#  ['Pad', 'Pad', 'AveragePool'],
#  ['ReduceSum', 'MatMul', 'Div'],
#  ['BatchNormalization', 'Pad', 'AveragePool'],
#  ['Concat', 'MatMul', 'Add', 'MatMul'],
#  ['Div', 'Abs', 'Atan', 'Div'],
#  ['Cast', 'Neg', 'Cast'],
#  ['Concat', 'Slice', 'Concat', 'Pad'],
#  ['Concat', 'Ceil', 'Mul'],
#  ['Softmax', 'Mul', 'Mul'],
#  ['Neg', 'Where', 'MatMul'],
#  ['Concat', 'Reshape', 'Softmax'],
#  ['Resize', 'Pad', 'Expand'],
#  ['Cast', 'Floor', 'LeakyRelu'],
#  ['MatMul', 'Add', 'Shape'],
#  ['Cast', 'Cast', 'Less'],
#  ['Cast', 'Expand', 'Concat'],
#  ['ReduceSum', 'MaxPool', 'Concat'],
#  ['ReduceMax', 'Resize', 'Concat'],
#  ['Cast', 'Cast', 'Cast'],
#  ['Resize', 'Pad', 'Div'],
#  ['Cast', 'Cast', 'Expand'],
#  ['Reshape', 'Cast', 'MatMul'],
#  ['Sub', 'Greater', 'Cast', 'Or'],
#  ['Reshape', 'Expand', 'Mul'],
#  ['MatMul', 'Neg', 'Concat'],
#  ['PRelu', 'Mul', 'Mul'],
#  ['Mul', 'Div', 'Ceil'],
#  ['Resize', 'Concat', 'Round'],
#  ['MaxPool', 'Shape', 'Slice', 'Concat'],
#  ['Concat', 'ReduceMin', 'Concat'],
#  ['Abs', 'Greater', 'Cast'],
#  ['Conv', 'Pad', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Or'],
#  ['ArgMin', 'Expand', 'Greater'],
#  ['Mul', 'Mul', 'Greater'],
#  ['Cast', 'Where', 'Concat'],
#  ['MatMul', 'Add', 'Ceil'],
#  ['Cast', 'Xor', 'Where'],
#  ['Abs', 'MatMul', 'Add'],
#  ['Squeeze', 'Less', 'Cast', 'Or'],
#  ['Round', 'Concat', 'ReduceSum'],
#  ['Sin', 'Concat', 'PRelu'],
#  ['Ceil', 'Concat', 'Concat'],
#  ['Where', 'Mul', 'Mul'],
#  ['Cast', 'Xor', 'Where', 'Min'],
#  ['Reshape', 'Conv', 'Reshape'],
#  ['ReduceMax', 'Pad', 'Shape'],
#  ['MatMul', 'Add', 'Cast'],
#  ['Abs', 'Mul', 'Cast'],
#  ['PRelu', 'Concat', 'Resize'],
#  ['Cos', 'Cast', 'Cast'],
#  ['Concat', 'Transpose', 'ReduceMean'],
#  ['MatMul', 'Add', 'Slice'],
#  ['Relu', 'Concat', 'Sigmoid'],
#  ['Cast', 'Reshape', 'MatMul'],
#  ['Sub', 'ReduceSum', 'MatMul'],
#  ['Shape', 'Slice', 'Concat'],
#  ['Mul', 'Mul', 'PRelu'],
#  ['ReduceMax', 'ReduceMean', 'Concat'],
#  ['Cast', 'Cast', 'Cast', 'Mul'],
#  ['Concat', 'Concat', 'Div'],
#  ['Concat', 'Cast', 'Ceil'],
#  ['Concat', 'Resize', 'Conv'],
#  ['Pad', 'Max', 'Concat'],
#  ['Cast', 'Floor', 'Cast'],
#  ['Concat', 'Clip', 'Concat'],
#  ['Mul', 'Mul', 'Clip'],
#  ['Squeeze', 'Mul', 'Div'],
#  ['ReduceSum', 'Resize', 'Concat'],
#  ['ArgMax', 'Greater', 'Where'],
#  ['Cast', 'Concat', 'Less'],
#  ['ArgMin', 'Expand', 'Cast'],
#  ['Less', 'Cast', 'Or'],
#  ['Relu', 'Mul', 'Mul', 'Mul'],
#  ['Cos', 'Mul', 'Mul'],
#  ['Mul', 'Mul', 'MatMul'],
#  ['Floor', 'Cast', 'Concat'],
#  ['Floor', 'Cast', 'Cast'],
#  ['Concat', 'Relu', 'Concat'],
#  ['Slice', 'Concat', 'Neg', 'Cast'],
#  ['Pad', 'AveragePool', 'BatchNormalization'],
#  ['Concat', 'Concat', 'Softmax'],
#  ['Pad', 'Div', 'Max'],
#  ['Expand', 'Resize', 'Conv'],
#  ['Where', 'MatMul', 'Add'],
#  ['ReduceMean', 'Trilu', 'Concat'],
#  ['Pad', 'Expand', 'Conv'],
#  ['Slice', 'Concat', 'Neg'],
#  ['Expand', 'Greater', 'Cast', 'And'],
#  ['Tan', 'Pad', 'Mul'],
#  ['Clip', 'Clip', 'Mul'],
#  ['Resize', 'Pad', 'Conv'],
#  ['Where', 'Concat', 'PRelu'],
#  ['Sub', 'Cast', 'Sub'],
#  ['Floor', 'Cast', 'Abs'],
#  ['Add', 'Concat', 'Concat'],
#  ['Pad', 'Div', 'Resize'],
#  ['Concat', 'Resize', 'ReduceSum'],
#  ['ReduceMin', 'MatMul', 'Concat'],
#  ['Reshape', 'MatMul', 'Concat'],
#  ['Max', 'Concat', 'Round'],
#  ['Reshape', 'Concat', 'Concat'],
#  ['Round', 'Shape', 'Slice', 'Concat'],
#  ['Abs', 'Cast', 'Concat'],
#  ['Sigmoid', 'Concat', 'Concat'],
#  ['Greater', 'Cast', 'Or'],
#  ['Cast', 'Or', 'Where'],
#  ['Add', 'Cast', 'Concat'],
#  ['Sigmoid', 'Mul', 'Mul'],
#  ['Cast', 'Add', 'Cast'],
#  ['MatMul', 'Mul', 'Mul', 'Min'],
#  ['Abs', 'Concat', 'PRelu'],
#  ['Add', 'Floor', 'Concat'],
#  ['Cast', 'Or', 'Where', 'Round'],
#  ['Add', 'Concat', 'MatMul'],
#  ['Pad', 'ReduceSum', 'Concat'],
#  ['ReduceMean', 'Concat', 'Cast'],
#  ['Cast', 'Expand', 'MatMul'],
#  ['Mul', 'Mul', 'Mul'],
#  ['Concat', 'Max', 'Mul', 'Mul'],
#  ['Pad', 'Concat', 'ReduceMax'],
#  ['Concat', 'Min', 'MatMul'],
#  ['Conv', 'Pad', 'Pad'],
#  ['Cast', 'Concat', 'Max'],
#  ['Floor', 'MatMul', 'Add'],
#  ['PRelu', 'Concat', 'Add'],
#  ['Div', 'Concat', 'Min'],
#  ['LeakyRelu', 'Mul', 'Mul'],
#  ['Concat', 'Neg', 'Concat'],
#  ['Abs', 'Cast', 'Add', 'Cast'],
#  ['Sub', 'Concat', 'ReduceMean'],
#  ['Cast', 'Expand', 'ReduceSum'],
#  ['Add', 'Min', 'Concat'],
#  ['Cast', 'Cast', 'And'],
#  ['Cast', 'Expand', 'Cast'],
#  ['ReduceMean', 'Mul', 'Concat'],
#  ['ReduceMean', 'Ceil', 'Concat'],
#  ['Cast', 'Cast', 'Div'],
#  ['Cast', 'Expand', 'Add'],
#  ['Sub', 'Mul', 'Sub'],
#  ['Neg', 'Cast', 'Sub'],
#  ['Concat', 'Reshape', 'Concat'],
#  ['Atan', 'Cast', 'Cast'],
#  ['Concat', 'Concat', 'Abs'],
#  ['Cast', 'Cast', 'Or', 'Cast'],
#  ['Cos', 'Relu', 'Concat'],
#  ['MatMul', 'Add', 'Relu'],
#  ['Atan', 'Softmax', 'Concat', 'Concat'],
#  ['Cast', 'Mul', 'Min'],
#  ['Conv', 'Squeeze', 'Greater'],
#  ['Squeeze', 'Pad', 'AveragePool'],
#  ['Softmax', 'Max', 'Div'],
#  ['Ceil', 'Cast', 'Sub'],
#  ['Concat', 'MatMul', 'Add'],
#  ['Expand', 'Concat', 'ReduceMax'],
#  ['Slice', 'Relu', 'Mul'],
#  ['PRelu', 'LeakyRelu', 'Mul'],
#  ['Concat', 'Resize', 'Min'],
#  ['Max', 'Div', 'Shape'],
#  ['Cast', 'Slice', 'Mul'],
#  ['Concat', 'Concat', 'Pad'],
#  ['Cos', 'Mul', 'Mul', 'Max'],
#  ['Cast', 'ReduceMax', 'Sub', 'Mul'],
#  ['Ceil', 'Sin', 'Cast'],
#  ['Less', 'Cast', 'Xor'],
#  ['ReduceMax', 'Add', 'Sub'],
#  ['Sub', 'Concat', 'Concat'],
#  ['Mul', 'Mul', 'Sub'],
#  ['Cast', 'Cast', 'Mul', 'Mul'],
#  ['ReduceSum', 'Concat', 'Resize'],
#  ['MatMul', 'Concat', 'MatMul'],
#  ['Cos', 'Add', 'Div'],
#  ['Expand', 'Pad', 'AveragePool'],
#  ['Pad', 'Conv', 'Pad'],
#  ['LeakyRelu', 'Concat', 'Cast'],
#  ['Atan', 'Reshape', 'Expand'],
#  ['Cos', 'Cast', 'Expand'],
#  ['Cast', 'Cast', 'Neg'],
#  ['Cast', 'Cast', 'ReduceSum'],
#  ['Concat', 'Max', 'Concat'],
#  ['Pad', 'Concat', 'ReduceMax', 'Concat'],
#  ['Softmax', 'Concat', 'LeakyRelu'],
#  ['Min', 'Concat', 'ArgMin']]

# %% [markdown]
# # tf2onnx

# %%
with open('./onnx_parsing_results/tf2onnx_mismatch_seq_match_results.json', 'r') as f:
    mismatched_seq = json.load(f)
with open('./onnx_parsing_results/tf2onnx_correct_mismatch_seq_match_results.json', 'r') as f:
    mismatched_correct = json.load(f)
with open('./onnx_parsing_results/tf2onnx_test_mismatch_seq_match_results.json', 'r') as f:
    mismatched_test = json.load(f)

# %%
print("Mismatched Ops:", len(mismatched_seq['node_type_token_dict'].keys()))
print("Mismatched-Correct Ops:", len(mismatched_correct['node_type_token_dict'].keys()))
print("Mismatched-Test Ops:", len(mismatched_test['node_type_token_dict'].keys()))
# Out:
# Mismatched Ops: 54
# Mismatched-Correct Ops: 54
# Mismatched-Test Ops: 65

# %% [markdown]
# ## Mismatched Sequences

# %%
(
    unique_mismatched_sequences,
    unique_mismatched_sequences_decoded,
    total_mismatched_sequences,
) = get_unq_sequences(mismatched_seq)
# Out:
# Total Sequences: 156,218, Total Unique Sequences: 2,155, Total Paths Compared: 135,239,592

# %%
len(recursive_submatching(unique_mismatched_sequences, len(unique_mismatched_sequences)))
# Out:
# 1265
# 1144
# 1118
# 1115
# 1115
# 1115

# %% [markdown]
# ## Correct-Mismatched Sequences

# %%
(
    unique_corr_mismatched_sequences,
    unique_corr_mismatched_sequences_decoded,
    total_corr_mismatched_sequences,
) = get_unq_sequences(mismatched_correct)
# Out:
# Total Sequences: 57,890, Total Unique Sequences: 1,050, Total Paths Compared: 80,075,700

# %%
len(recursive_submatching(unique_corr_mismatched_sequences, len(unique_corr_mismatched_sequences)))
# Out:
# 605
# 526
# 507
# 507
# 507

# %% [markdown]
# ### Create New Tokenizers and Calculate Non-Overlapping

# %%
node_type_token_dict, token_node_type_dict = create_tokenizers(
    mismatched_correct["node_type_token_dict"], mismatched_seq["node_type_token_dict"]
)

# %%
mismatched_sequences = set(tokenize_seqs(node_type_token_dict, unique_mismatched_sequences_decoded))
mismatched_correct_sequences = set(tokenize_seqs(node_type_token_dict, unique_corr_mismatched_sequences_decoded))

# %% [markdown]
# #### Nonoverlapping

# %%
seqs = mismatched_sequences - mismatched_correct_sequences
len(seqs)
# Out:
# 1527

# %%
reduced_sequences = recursive_submatching(seqs, len(seqs))
# Out:
# 1032
# 901
# 871
# 868
# 865
# 865

# %%
detokenize_seqs(token_node_type_dict, reduced_sequences)
# Out:
# [['Mul', 'Add', 'ReduceMean'],
#  ['Round', 'Reshape', 'ConvTranspose'],
#  ['Atan', 'MatMul', 'Concat', 'Floor'],
#  ['And', 'And', 'Not'],
#  ['ReverseSequence', 'Squeeze', 'Unsqueeze'],
#  ['Transpose', 'Conv', 'Conv', 'Transpose'],
#  ['ReduceSum', 'Mul', 'Add', 'Concat'],
#  ['ReduceMean', 'Reshape', 'Conv', 'Conv'],
#  ['Conv', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceSum'],
#  ['Conv', 'Relu', 'Min'],
#  ['Mul', 'ReverseSequence', 'Reshape', 'ReverseSequence'],
#  ['Add', 'Mul', 'MatMul'],
#  ['LeakyRelu', 'Mul', 'Mul'],
#  ['Conv', 'Reshape', 'Unsqueeze'],
#  ['Transpose', 'Conv', 'ConvTranspose'],
#  ['Conv', 'Conv', 'LeakyRelu'],
#  ['Conv', 'Squeeze', 'Transpose'],
#  ['Min', 'Max', 'Tan'],
#  ['Mul', 'Abs', 'Max'],
#  ['Round', 'Concat', 'Concat'],
#  ['Cast', 'Mul', 'Add', 'Atan'],
#  ['Div', 'Min', 'Max'],
#  ['Reshape', 'Mul', 'Mul'],
#  ['ConvTranspose', 'Max', 'Conv'],
#  ['LeakyRelu', 'Min', 'Max', 'Mul'],
#  ['Max', 'MatMul', 'Concat'],
#  ['Transpose', 'Min', 'Reshape'],
#  ['Gather', 'Transpose', 'Conv'],
#  ['Add', 'Concat', 'Neg'],
#  ['Concat', 'Sigmoid', 'MatMul'],
#  ['Reshape', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Concat', 'Concat', 'Mul'],
#  ['Tan', 'Concat', 'Max'],
#  ['Reshape', 'Conv', 'ReduceMean', 'Reshape'],
#  ['Conv', 'Transpose', 'BatchNormalization', 'Transpose'],
#  ['Gather', 'Mul', 'Mul'],
#  ['Sigmoid', 'Atan', 'Min', 'Max'],
#  ['Reshape', 'Conv', 'Transpose', 'BatchNormalization'],
#  ['Slice', 'Max', 'Round'],
#  ['Mul', 'Add', 'Cast'],
#  ['Conv', 'Reshape', 'ReduceSum'],
#  ['Reshape', 'Concat', 'Softmax'],
#  ['Mul', 'Mul', 'LeakyRelu'],
#  ['Cos', 'Concat', 'Concat'],
#  ['Neg', 'Mul', 'Add'],
#  ['Reshape', 'Mul', 'Softmax'],
#  ['Add', 'Mul', 'Add', 'Div'],
#  ['Conv', 'Conv', 'Mul'],
#  ['Reshape', 'Slice', 'Transpose', 'Conv'],
#  ['Reshape', 'Conv', 'Transpose', 'Round'],
#  ['Conv', 'Conv', 'Transpose', 'Floor'],
#  ['MatMul', 'Concat', 'Sub'],
#  ['Reshape', 'MatMul', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'Cast', 'Concat'],
#  ['Min', 'Max', 'Squeeze'],
#  ['Reshape', 'SpaceToDepth', 'Transpose'],
#  ['Reshape', 'Conv', 'Softmax', 'Transpose'],
#  ['MatMul', 'Reshape', 'Transpose'],
#  ['Add', 'Round', 'LeakyRelu'],
#  ['Mul', 'Add', 'Mul', 'Add'],
#  ['Min', 'Min', 'Cast'],
#  ['Reshape', 'Squeeze', 'Concat'],
#  ['Cast', 'Add', 'Min'],
#  ['ReduceMean', 'Transpose', 'ConvTranspose'],
#  ['Reshape', 'Conv', 'ReduceMax'],
#  ['Max', 'Concat', 'Max'],
#  ['ReduceMax', 'Concat', 'Reshape'],
#  ['Max', 'Concat', 'Mul', 'Add'],
#  ['MatMul', 'Reshape', 'Concat'],
#  ['Conv', 'Transpose', 'Conv', 'Transpose'],
#  ['Tan', 'Transpose', 'Conv'],
#  ['Sigmoid', 'Reshape', 'MatMul', 'Reshape'],
#  ['Min', 'Max', 'Gather', 'Mul'],
#  ['Transpose', 'Mul', 'Add', 'Concat'],
#  ['Atan', 'Concat', 'Reshape'],
#  ['Concat', 'Concat', 'Sub'],
#  ['Conv', 'ConvTranspose', 'ConvTranspose', 'Reshape'],
#  ['Concat', 'Sub', 'Ceil'],
#  ['Softmax', 'Reshape', 'Conv', 'Reshape'],
#  ['MatMul', 'Concat', 'Floor'],
#  ['ReduceSum', 'Concat', 'Div'],
#  ['ReverseSequence', 'Transpose', 'Mul', 'Add'],
#  ['Conv', 'Reshape', 'Floor'],
#  ['Floor', 'Concat', 'Reshape', 'Conv'],
#  ['Transpose', 'Cos', 'Transpose'],
#  ['Conv', 'Reshape', 'Conv', 'SpaceToDepth', 'Transpose'],
#  ['Atan', 'Concat', 'Tan'],
#  ['Conv', 'Cast', 'Transpose'],
#  ['Transpose', 'ConvTranspose', 'Concat'],
#  ['Transpose', 'Conv', 'Neg'],
#  ['Reshape', 'Tan', 'Reshape'],
#  ['Reshape', 'Conv', 'Add', 'Transpose'],
#  ['Conv', 'Conv', 'DepthToSpace'],
#  ['Abs', 'Reshape', 'Conv'],
#  ['Max', 'Conv', 'Transpose'],
#  ['Reshape', 'Conv', 'Neg', 'Reshape'],
#  ['Slice', 'Concat', 'Softmax'],
#  ['Mul', 'Concat', 'Sigmoid'],
#  ['Unsqueeze', 'Transpose', 'ConvTranspose'],
#  ['ReduceProd', 'Mul', 'Mul'],
#  ['Transpose', 'Concat', 'Conv'],
#  ['Max', 'Tan', 'Div'],
#  ['Mul', 'Add', 'Max', 'Softmax'],
#  ['LeakyRelu', 'Concat', 'Concat'],
#  ['Min', 'Max', 'Gather', 'Sub'],
#  ['Min', 'MatMul', 'Concat'],
#  ['Reshape', 'Conv', 'Conv', 'Squeeze'],
#  ['Transpose', 'DepthToSpace', 'Conv'],
#  ['Ceil', 'Concat', 'Relu'],
#  ['Atan', 'Reshape', 'Conv', 'Reshape'],
#  ['Cos', 'Mul', 'Add'],
#  ['Reshape', 'Conv', 'LeakyRelu'],
#  ['Min', 'Max', 'ReduceMin'],
#  ['Conv', 'Transpose', 'BatchNormalization'],
#  ['Reshape', 'Concat', 'ReduceSum'],
#  ['Gather', 'Reshape', 'ConvTranspose'],
#  ['Mul', 'Add', 'Transpose', 'ConvTranspose'],
#  ['Conv', 'Conv', 'SpaceToDepth'],
#  ['Reshape', 'Conv', 'Sigmoid', 'Reshape'],
#  ['Transpose', 'Conv', 'Conv', 'ConvTranspose'],
#  ['Slice', 'Round', 'ReduceMax'],
#  ['Conv', 'Neg', 'Reshape', 'Conv'],
#  ['And', 'And', 'Not', 'And'],
#  ['Concat', 'Concat', 'Mul', 'Add'],
#  ['Transpose', 'Round', 'Concat'],
#  ['Transpose', 'Conv', 'Transpose', 'Reshape'],
#  ['Conv', 'Shape', 'Gather', 'Slice'],
#  ['Concat', 'Slice', 'Concat'],
#  ['Concat', 'Concat', 'Slice', 'Concat'],
#  ['Conv', 'ReduceProd', 'Reshape'],
#  ['Transpose', 'Conv', 'Conv', 'Relu'],
#  ['Atan', 'Concat', 'Sigmoid'],
#  ['Sigmoid', 'Sigmoid', 'Add'],
#  ['Concat', 'Concat', 'Min', 'Max'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMean'],
#  ['ReduceMax', 'Reshape', 'Conv'],
#  ['Concat', 'Slice', 'ReduceMin'],
#  ['Abs', 'Min', 'Max', 'Gather'],
#  ['MatMul', 'Concat', 'ReduceMin'],
#  ['MatMul', 'Concat', 'Concat'],
#  ['Slice', 'Min', 'Max'],
#  ['Transpose', 'Max', 'Concat'],
#  ['Conv', 'Sub', 'ConvTranspose'],
#  ['Conv', 'LeakyRelu', 'Conv'],
#  ['LeakyRelu', 'Concat', 'Slice'],
#  ['Add', 'Concat', 'Div'],
#  ['Concat', 'Atan', 'Concat'],
#  ['Max', 'Add', 'Mul'],
#  ['Reshape', 'ReverseSequence', 'Reshape', 'Conv'],
#  ['Conv', 'ConvTranspose', 'Reshape', 'Reshape'],
#  ['Gather', 'Reshape', 'Transpose', 'Conv'],
#  ['Sub', 'ArgMax', 'Cast'],
#  ['Floor', 'Cast', 'Max'],
#  ['Div', 'Min', 'Max', 'Concat'],
#  ['Reshape', 'ConvTranspose', 'ConvTranspose', 'Reshape'],
#  ['Unsqueeze', 'Reshape', 'Conv'],
#  ['Concat', 'Min', 'Abs'],
#  ['Transpose', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Ceil', 'Concat', 'Transpose'],
#  ['SpaceToDepth', 'Conv', 'Reshape'],
#  ['Conv', 'Conv', 'Sub'],
#  ['Transpose', 'Reshape', 'MatMul', 'Reshape'],
#  ['Neg', 'Reshape', 'Conv', 'LeakyRelu'],
#  ['Conv', 'Conv', 'Sub', 'Reshape'],
#  ['Conv', 'DepthToSpace', 'LeakyRelu'],
#  ['Reshape', 'Conv', 'Reshape', 'Cos'],
#  ['Conv', 'Conv', 'Reshape', 'Atan'],
#  ['Reshape', 'Round', 'Mul'],
#  ['Reshape', 'Conv', 'Sub', 'Reshape'],
#  ['ReduceMax', 'Concat', 'LeakyRelu'],
#  ['Conv', 'Add', 'Transpose'],
#  ['Concat', 'Mul', 'Add', 'Concat'],
#  ['LRN', 'Transpose', 'Reshape'],
#  ['Erf', 'Add', 'Mul', 'Min'],
#  ['Atan', 'Mul', 'Add'],
#  ['Reshape', 'Mul', 'Transpose'],
#  ['Transpose', 'Conv', 'Abs'],
#  ['Min', 'Transpose', 'LRN', 'Transpose'],
#  ['Mul', 'Mul', 'Concat', 'Concat'],
#  ['Softmax', 'Concat', 'Concat'],
#  ['Reshape', 'Mul', 'Reshape', 'Conv'],
#  ['ReduceMin', 'Atan', 'Concat'],
#  ['Mul', 'Min', 'Concat'],
#  ['Softmax', 'Concat', 'Mul'],
#  ['Concat', 'Concat', 'Cos'],
#  ['Reshape', 'Transpose', 'Reshape', 'Slice'],
#  ['Conv', 'Transpose', 'Cos'],
#  ['Min', 'Max', 'Gather', 'ArgMax'],
#  ['Reshape', 'Sub', 'Min'],
#  ['Sub', 'Slice', 'Transpose'],
#  ['Mul', 'Mul', 'ReduceProd'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMax'],
#  ['Cast', 'Add', 'Max'],
#  ['Concat', 'Div', 'Sigmoid'],
#  ['Sigmoid', 'Atan', 'Mul'],
#  ['ReduceProd', 'Transpose', 'Conv'],
#  ['ReduceSum', 'ReduceMean', 'Concat'],
#  ['ConvTranspose', 'SpaceToDepth', 'Transpose'],
#  ['Mul', 'Mul', 'Sub'],
#  ['Abs', 'Transpose', 'ConvTranspose'],
#  ['ConvTranspose', 'Relu', 'Transpose'],
#  ['ReduceSum', 'Min', 'Max', 'Gather'],
#  ['Min', 'Min', 'LeakyRelu'],
#  ['Ceil', 'Concat', 'Transpose', 'Concat'],
#  ['Neg', 'Mul', 'Mul'],
#  ['Unsqueeze', 'Min', 'Max'],
#  ['ReduceMin', 'Reshape', 'Conv', 'Reshape'],
#  ['ConvTranspose', 'Reshape', 'Gather'],
#  ['Slice', 'Concat', 'Mul', 'Add'],
#  ['DepthToSpace', 'LeakyRelu', 'Reshape'],
#  ['Round', 'Concat', 'Reshape'],
#  ['Slice', 'Reshape', 'MatMul'],
#  ['ReduceMean', 'Transpose', 'Conv'],
#  ['Squeeze', 'Mul', 'Add', 'Reshape'],
#  ['LeakyRelu', 'Concat', 'ReduceProd'],
#  ['Concat', 'ReduceMin', 'Transpose'],
#  ['Transpose', 'SpaceToDepth', 'Reshape'],
#  ['Floor', 'Concat', 'Tan'],
#  ['Concat', 'Concat', 'Slice'],
#  ['Conv', 'ReduceMin', 'Transpose'],
#  ['Sub', 'Reshape', 'Conv'],
#  ['ReduceMin', 'Reshape', 'Conv', 'Relu'],
#  ['ReduceMin', 'Transpose', 'Atan', 'Tan'],
#  ['Conv', 'LeakyRelu', 'Reshape'],
#  ['Mul', 'Transpose', 'Mul'],
#  ['ReduceProd', 'Transpose', 'ConvTranspose'],
#  ['Neg', 'Relu', 'Min'],
#  ['Conv', 'Reshape', 'Tan'],
#  ['MatMul', 'Concat', 'MatMul'],
#  ['Reshape', 'Conv', 'Transpose', 'Cos'],
#  ['GlobalAveragePool', 'Squeeze', 'Expand'],
#  ['Conv', 'Conv', 'Transpose', 'ReduceSum'],
#  ['Tan', 'Reshape', 'ConvTranspose'],
#  ['Add', 'Concat', 'Sigmoid'],
#  ['LeakyRelu', 'Concat', 'ReduceMean'],
#  ['Mul', 'MatMul', 'Min'],
#  ['Reshape', 'DepthToSpace', 'Reshape'],
#  ['Cos', 'Mul', 'Mul'],
#  ['Erf', 'Add', 'Mul', 'Unsqueeze'],
#  ['Cast', 'Min', 'Max', 'Reshape'],
#  ['LeakyRelu', 'Concat', 'MatMul'],
#  ['Or', 'Cast', 'Mul', 'Add'],
#  ['ReduceMax', 'Reshape', 'Conv', 'Conv'],
#  ['ReverseSequence', 'Transpose', 'Round'],
#  ['ReduceSum', 'ReduceMax', 'Concat'],
#  ['Conv', 'Transpose', 'Transpose'],
#  ['Min', 'Max', 'Gather', 'Relu'],
#  ['Conv', 'Conv', 'ReduceMin'],
#  ['Concat', 'Mul', 'Transpose', 'Mul'],
#  ['Cos', 'Reshape', 'ConvTranspose'],
#  ['ReduceMax', 'Min', 'Max', 'Gather'],
#  ['Neg', 'Reshape', 'Conv', 'Transpose'],
#  ['Concat', 'Concat', 'MatMul'],
#  ['Cast', 'Max', 'Mul'],
#  ['Add', 'Sub', 'Cos'],
#  ['Concat', 'MatMul', 'Sub'],
#  ['Sub', 'Concat', 'Slice'],
#  ['Transpose', 'Conv', 'Cast'],
#  ['Mul', 'Mul', 'Add', 'Mul'],
#  ['Conv', 'ArgMax', 'Transpose'],
#  ['Reshape', 'DepthToSpace', 'Transpose', 'Reshape'],
#  ['Mul', 'Add', 'Transpose', 'Mul', 'Add'],
#  ['Transpose', 'DepthToSpace', 'Conv', 'Transpose'],
#  ['Reshape', 'Concat', 'Mul', 'Reshape'],
#  ['Round', 'Mul', 'Add'],
#  ['Min', 'Max', 'Gather', 'Unsqueeze'],
#  ['ReduceProd', 'Max', 'Concat'],
#  ['Transpose', 'Mul', 'Concat'],
#  ['Conv', 'Transpose', 'Floor'],
#  ['ReduceMax', 'Mul', 'Add'],
#  ['Concat', 'Softmax', 'Abs'],
#  ['Mul', 'Reshape', 'Sub'],
#  ['Conv', 'Reshape', 'Mul', 'Reshape'],
#  ['MatMul', 'ReduceMean', 'Concat'],
#  ['Max', 'Concat', 'Tan'],
#  ['Softmax', 'Min', 'Max'],
#  ['Relu', 'Concat', 'Max'],
#  ['ReverseSequence', 'Squeeze', 'Div'],
#  ['Transpose', 'Transpose', 'Conv', 'Transpose'],
#  ['Tan', 'Reshape', 'Conv', 'Conv'],
#  ['Conv', 'ReduceMean', 'Reshape'],
#  ['Unsqueeze', 'Transpose', 'Conv'],
#  ['Reshape', 'ConvTranspose', 'Conv', 'Conv'],
#  ['Min', 'Max', 'Add'],
#  ['Concat', 'Concat', 'Cast'],
#  ['Floor', 'Reshape', 'Conv', 'Transpose'],
#  ['Concat', 'LRN', 'Transpose'],
#  ['Min', 'Reshape', 'Transpose', 'Conv'],
#  ['Reshape', 'Conv', 'Max'],
#  ['Reshape', 'Concat', 'Conv', 'Conv'],
#  ['Cast', 'Gather', 'Min', 'Max'],
#  ['Div', 'Concat', 'Concat'],
#  ['Min', 'Reshape', 'Concat', 'Reshape'],
#  ['MatMul', 'Reshape', 'Squeeze'],
#  ['Relu', 'Reshape', 'MatMul', 'Reshape'],
#  ['Floor', 'Transpose', 'Conv'],
#  ['Min', 'Max', 'Transpose', 'Conv'],
#  ['Reshape', 'MatMul', 'Reshape', 'Reshape'],
#  ['Squeeze', 'Reshape', 'Conv'],
#  ['Conv', 'Reshape', 'Cos'],
#  ['MatMul', 'Add', 'Min'],
#  ['Mul', 'Add', 'Atan'],
#  ['Conv', 'Transpose', 'ReverseSequence', 'Transpose'],
#  ['Mul', 'Reshape', 'Reshape'],
#  ['Conv', 'LeakyRelu', 'Transpose'],
#  ['MatMul', 'Transpose', 'ReverseSequence', 'Transpose'],
#  ['Min', 'Max', 'Gather', 'Softmax'],
#  ['Neg', 'Max', 'Min'],
#  ['Conv', 'Conv', 'Mul', 'Reshape'],
#  ['Reshape', 'ReduceSum', 'Reshape'],
#  ['Conv', 'Conv', 'Concat', 'Conv'],
#  ['Conv', 'Mul', 'Transpose', 'Mul'],
#  ['Mul', 'Mul', 'Mul', 'Min'],
#  ['Mul', 'Add', 'Max'],
#  ['Max', 'Transpose', 'Reshape'],
#  ['Conv', 'DepthToSpace', 'Reshape'],
#  ['Min', 'Max', 'Tan', 'Sub'],
#  ['ReduceSum', 'Reshape', 'Conv'],
#  ['Concat', 'Cos', 'Max'],
#  ['ReverseSequence', 'ReduceMin', 'Transpose'],
#  ['ReduceMax', 'Concat', 'Sigmoid'],
#  ['Reshape', 'Conv', 'Conv', 'Abs'],
#  ['ConvTranspose', 'Transpose', 'ConvTranspose'],
#  ['Transpose', 'Conv', 'Transpose', 'Round'],
#  ['Mul', 'Concat', 'Round'],
#  ['Atan', 'Cast', 'Cast'],
#  ['Conv', 'Conv', 'Concat'],
#  ['Transpose', 'LRN', 'Reshape'],
#  ['Reshape', 'Conv', 'Reshape', 'Ceil'],
#  ['Sigmoid', 'Concat', 'Div'],
#  ['LeakyRelu', 'ReduceProd', 'Transpose'],
#  ['Transpose', 'Mul', 'Reshape'],
#  ['Concat', 'ReduceMean', 'Sigmoid'],
#  ['Transpose', 'Conv', 'Conv', 'Conv'],
#  ['Softmax', 'Abs', 'Softmax'],
#  ['Reshape', 'Transpose', 'Conv', 'Reshape'],
#  ['Transpose', 'Conv', 'LRN', 'Transpose'],
#  ['Max', 'Max', 'ReduceMin'],
#  ['Reshape', 'Conv', 'Sub', 'Transpose'],
#  ['Reshape', 'Conv', 'Conv', 'Sub'],
#  ['Sub', 'Min', 'Max'],
#  ['Min', 'Max', 'Gather', 'Tan'],
#  ['Transpose', 'Cast', 'Transpose'],
#  ['ReduceMax', 'Transpose', 'DepthToSpace'],
#  ['Concat', 'Concat', 'Concat'],
#  ['Tan', 'Round', 'Floor'],
#  ['Abs', 'Concat', 'Mul'],
#  ['Mul', 'Add', 'ReduceProd', 'Min'],
#  ['Floor', 'Transpose', 'ConvTranspose'],
#  ['Add', 'Mul', 'Ceil'],
#  ['LeakyRelu', 'Transpose', 'Reshape'],
#  ['Transpose', 'Conv', 'ReduceMax', 'Reshape'],
#  ['Mul', 'Add', 'Sigmoid'],
#  ['Ceil', 'Cast', 'Min'],
#  ['Transpose', 'Conv', 'ReduceMax', 'Transpose'],
#  ['Max', 'Concat', 'Mul'],
#  ['Min', 'Round', 'Reshape'],
#  ['Concat', 'Conv', 'Conv'],
#  ['Mul', 'Mul', 'ArgMax'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceMax'],
#  ['Reshape', 'MatMul', 'Reshape', 'MatMul'],
#  ['Reshape', 'Tan', 'Unsqueeze'],
#  ['Conv', 'Abs', 'Transpose'],
#  ['Cast', 'Cast', 'Reshape'],
#  ['Atan', 'Mul', 'Mul', 'Reshape'],
#  ['Transpose', 'DepthToSpace', 'Transpose', 'Conv'],
#  ['ReverseSequence', 'Transpose', 'Min'],
#  ['Conv', 'LRN', 'Conv'],
#  ['Gather', 'Min', 'Max'],
#  ['Concat', 'Neg', 'ReduceMean'],
#  ['Tan', 'Reshape', 'Conv'],
#  ['Concat', 'ReduceSum', 'Concat'],
#  ['Sigmoid', 'Unsqueeze', 'Reshape'],
#  ['Transpose', 'ConvTranspose', 'Reshape'],
#  ['Max', 'Round', 'Neg'],
#  ['Transpose', 'Conv', 'Min', 'Transpose'],
#  ['MatMul', 'ReduceMean', 'Mul'],
#  ['Reshape', 'Conv', 'Mul', 'Transpose'],
#  ['Concat', 'Concat', 'Max'],
#  ['DepthToSpace', 'Slice', 'Reshape'],
#  ['Greater', 'Cast', 'Mul', 'Add'],
#  ['Min', 'Max', 'Abs', 'Mul'],
#  ['Squeeze', 'Min', 'Concat'],
#  ['Transpose', 'Conv', 'Mul', 'Transpose'],
#  ['ReduceMean', 'ReduceMean', 'Concat'],
#  ['Concat', 'Mul', 'Transpose'],
#  ['Mul', 'ReduceProd', 'Transpose', 'Conv'],
#  ['Transpose', 'Conv', 'Squeeze', 'Transpose'],
#  ['Transpose', 'Round', 'LeakyRelu'],
#  ['Mul', 'Mul', 'Abs'],
#  ['Mul', 'Reshape', 'Mul', 'ReduceMin'],
#  ['Reshape', 'Conv', 'Sigmoid'],
#  ['Add', 'Concat', 'Unsqueeze'],
#  ['Sigmoid', 'Mul', 'Add'],
#  ['Conv', 'Transpose', 'ReduceSum', 'Concat'],
#  ['Transpose', 'Conv', 'Min'],
#  ['Floor', 'Concat', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'Min'],
#  ['Mul', 'Max', 'Softmax'],
#  ['ReduceMax', 'Neg', 'Min', 'Max', 'Gather'],
#  ['Ceil', 'Concat', 'Concat'],
#  ['Conv', 'Conv', 'ReduceMax'],
#  ['ReduceProd', 'Min', 'Max', 'Gather'],
#  ['Mul', 'Min', 'Floor'],
#  ['Reshape', 'Mul', 'Add', 'Reshape'],
#  ['Slice', 'Min', 'Max', 'Gather'],
#  ['Floor', 'Transpose', 'Concat', 'Transpose'],
#  ['ConvTranspose', 'Reshape', 'Transpose', 'ConvTranspose'],
#  ['Mul', 'Mul', 'Max'],
#  ['Transpose', 'ConvTranspose', 'Transpose', 'ConvTranspose'],
#  ['Round', 'Concat', 'Slice'],
#  ['Transpose', 'DepthToSpace', 'Transpose'],
#  ['ReduceMean', 'Reshape', 'Conv', 'Transpose'],
#  ['Min', 'Reshape', 'Conv'],
#  ['Transpose', 'Concat', 'Concat'],
#  ['Reshape', 'Conv', 'Conv', 'ReduceMax'],
#  ['Conv', 'Transpose', 'ReduceSum'],
#  ['Max', 'Concat', 'Concat'],
#  ['Mul', 'Mul', 'Round'],
#  ['Conv', 'Conv', 'Abs'],
#  ['Neg', 'Mul', 'Mul', 'Add'],
#  ['Mul', 'Add', 'Concat', 'Transpose'],
#  ['Squeeze', 'Transpose', 'Atan'],
#  ['Atan', 'Concat', 'Add'],
#  ['Reshape', 'Conv', 'ReduceMean'],
#  ['Tan', 'Transpose', 'Conv', 'Conv'],
#  ['Reshape', 'Conv', 'Conv', 'Reshape'],
#  ['Conv', 'Conv', 'Relu'],
#  ['Concat', 'Round', 'Cast'],
#  ['Mul', 'Mul', 'ReduceMax'],
#  ['Transpose', 'Conv', 'ReduceMax'],
#  ['ArgMax', 'Abs', 'Min'],
#  ['Neg', 'Reshape', 'Conv'],
#  ['Div', 'Concat', 'Mul'],
#  ['Concat', 'Div', 'Concat'],
#  ['Squeeze', 'Cos', 'Concat'],
#  ['Neg', 'Floor', 'MatMul'],
#  ['Add', 'Mul', 'Add', 'Sigmoid'],
#  ['Transpose', 'Conv', 'LeakyRelu'],
#  ['Gather', 'Mul', 'Add'],
#  ['Mul', 'Add', 'Squeeze'],
#  ['Reshape', 'Reshape', 'ConvTranspose'],
#  ['Min', 'Max', 'Gather', 'Concat', 'Concat'],
#  ['Sub', 'Mul', 'Mul'],
#  ['Squeeze', 'Transpose', 'Conv', 'Reshape'],
#  ['Conv', 'Conv', 'Reshape', 'Mul'],
#  ['Squeeze', 'Mul', 'Add'],
#  ['ReduceMean', 'Concat', 'Concat'],
#  ['Or', 'And', 'And', 'Not'],
#  ['Mul', 'Mul', 'MatMul'],
#  ['Transpose', 'Cos', 'Ceil'],
#  ['Reshape', 'Reshape', 'Conv', 'Add'],
#  ['Reshape', 'Transpose', 'ConvTranspose'],
#  ['Max', 'Transpose', 'Concat'],
#  ['Reshape', 'Sub', 'Reshape'],
#  ['Min', 'Min', 'Max', 'Gather'],
#  ['Concat', 'Concat', 'Ceil'],
#  ['Transpose', 'ConvTranspose', 'Reshape', 'Conv'],
#  ['Concat', 'Div', 'LeakyRelu'],
#  ['ReduceSum', 'Concat', 'Max'],
#  ['Mul', 'Concat', 'Add'],
#  ['Atan', 'Concat', 'Relu'],
#  ['Cast', 'Add', 'Mul'],
#  ['Reshape', 'ConvTranspose', 'Reshape', 'Transpose'],
#  ['Conv', 'Sigmoid', 'Reshape'],
#  ['Conv', 'Reshape', 'Reshape', 'Conv'],
#  ['Transpose', 'BatchNormalization', 'Transpose', 'ConvTranspose'],
#  ['Max', 'Reshape', 'MatMul', 'Reshape'],
#  ['Min', 'Div', 'Mul'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceMean'],
#  ['Reshape', 'Sub', 'Concat'],
#  ['MatMul', 'Reshape', 'Sub'],
#  ['Slice', 'Slice', 'Reshape'],
#  ['ReverseSequence', 'Reshape', 'ReduceSum'],
#  ['Not', 'Cast', 'Mul', 'Add'],
#  ['Concat', 'ReduceProd', 'Mul'],
#  ['Reshape', 'Mul', 'Concat'],
#  ['Unsqueeze', 'Reshape', 'ReverseSequence', 'Squeeze'],
#  ['Round', 'Mul', 'Add', 'ArgMax'],
#  ['DepthToSpace', 'Slice', 'Reshape', 'Conv'],
#  ['SpaceToDepth', 'Reshape', 'Conv', 'Conv'],
#  ['Reshape', 'Conv', 'Reshape', 'Conv'],
#  ['Conv', 'Conv', 'Reshape', 'Transpose'],
#  ['Concat', 'Sigmoid', 'Softmax'],
#  ['Conv', 'Relu', 'Conv'],
#  ['MatMul', 'Cast', 'Cast'],
#  ['Reshape', 'MatMul', 'Reshape', 'Slice'],
#  ['Conv', 'ReduceProd', 'ReduceMin'],
#  ['Reshape', 'MatMul', 'Reshape', 'Concat'],
#  ['Add', 'Div', 'Cast'],
#  ['Max', 'ReduceMin', 'Min'],
#  ['Min', 'Reshape', 'Concat'],
#  ['Reshape', 'MatMul', 'Reshape', 'Sub'],
#  ['Mul', 'Transpose', 'Erf', 'Add', 'Mul'],
#  ['Conv', 'ReduceMin', 'Concat'],
#  ['Mul', 'Add', 'LeakyRelu'],
#  ['Reshape', 'MatMul', 'Mul'],
#  ['SpaceToDepth', 'Transpose', 'Conv'],
#  ['ReduceMin', 'Concat', 'Transpose'],
#  ['Transpose', 'Tan', 'Transpose', 'Conv'],
#  ['Atan', 'Transpose', 'Conv'],
#  ['Concat', 'Tan', 'ReduceMean'],
#  ['ReduceMean', 'Mul', 'Softmax'],
#  ['ArgMax', 'Add', 'Concat'],
#  ['Min', 'Max', 'Gather', 'Add'],
#  ['Mul', 'Mul', 'Atan'],
#  ['Transpose', 'Conv', 'ArgMax', 'Transpose'],
#  ['Conv', 'Sub', 'Transpose'],
#  ['MatMul', 'Min', 'Max'],
#  ['Mul', 'Transpose', 'ConvTranspose'],
#  ['Reshape', 'Sub', 'Reshape', 'Conv'],
#  ['Reshape', 'Conv', 'Concat', 'Reshape'],
#  ['Concat', 'Round', 'ReduceSum'],
#  ['Round', 'Concat', 'Transpose'],
#  ['Add', 'Mul', 'ReduceSum'],
#  ['Atan', 'Mul', 'Mul'],
#  ['ConvTranspose', 'Reshape', 'Transpose'],
#  ['ReduceMin', 'Transpose', 'Mul'],
#  ['Or', 'And', 'Or'],
#  ['Concat', 'Transpose', 'Conv'],
#  ['Max', 'Min', 'Concat'],
#  ['ConvTranspose', 'ConvTranspose', 'Reshape'],
#  ['Softmax', 'Reshape', 'Conv'],
#  ['Mul', 'Mul', 'Concat', 'Sigmoid'],
#  ['Reshape', 'MatMul', 'Reshape', 'LeakyRelu'],
#  ['Transpose', 'Conv', 'Transpose', 'Atan'],
#  ['Neg', 'Max', 'Min', 'Concat'],
#  ['Add', 'Transpose', 'ConvTranspose'],
#  ['LeakyRelu', 'Min', 'Max'],
#  ['Mul', 'Transpose', 'Conv', 'Transpose'],
#  ['Concat', 'MatMul', 'ReduceProd'],
#  ['Conv', 'ReduceMax', 'Reshape'],
#  ['ReduceProd', 'Add', 'ArgMax'],
#  ['Transpose', 'Mul', 'Add'],
#  ['MatMul', 'Concat', 'Softmax'],
#  ['Conv', 'LRN', 'Concat'],
#  ['Softmax', 'Mul', 'Add'],
#  ['Concat', 'Cast', 'ReduceMax'],
#  ['Transpose', 'Concat', 'Min'],
#  ['Reshape', 'LRN', 'Reshape'],
#  ['Round', 'Reshape', 'Conv'],
#  ['Cos', 'ArgMax', 'Reshape'],
#  ['Min', 'Max', 'Reshape', 'Gather'],
#  ['Mul', 'Concat', 'Cast'],
#  ['Concat', 'MatMul', 'MatMul'],
#  ['Round', 'Concat', 'Cast', 'Abs'],
#  ['Mul', 'Mul', 'Ceil'],
#  ['Relu', 'ReverseSequence', 'Reshape'],
#  ['Neg', 'Max', 'Concat'],
#  ['Reshape', 'Reshape', 'MatMul', 'Reshape'],
#  ['Relu', 'Concat', 'Concat'],
#  ['ReduceMean', 'Sigmoid', 'Mul', 'Mul'],
#  ['Conv', 'Neg', 'Conv'],
#  ['Mul', 'Concat', 'LeakyRelu'],
#  ['Sigmoid', 'Concat', 'LeakyRelu'],
#  ['Slice', 'Reshape', 'ConvTranspose'],
#  ['Reshape', 'Mul', 'Concat', 'Round'],
#  ['DepthToSpace', 'Slice', 'Reshape', 'Transpose'],
#  ['Atan', 'MatMul', 'Concat'],
#  ['ConvTranspose', 'Conv', 'Transpose'],
#  ['Slice', 'Add', 'Sigmoid'],
#  ['Squeeze', 'Concat', 'Cos'],
#  ['Max', 'Reshape', 'DepthToSpace'],
#  ['Squeeze', 'Sigmoid', 'Concat'],
#  ['Concat', 'Concat', 'Div'],
#  ['Atan', 'Atan', 'Mul', 'Mul'],
#  ['Conv', 'DepthToSpace', 'Conv'],
#  ['Conv', 'Relu', 'Conv', 'Reshape'],
#  ['Min', 'Max', 'Cast', 'Max'],
#  ['Conv', 'Reshape', 'Div', 'Reshape', 'Conv', 'Reshape'],
#  ['Concat', 'Concat', 'Round'],
#  ['Concat', 'Concat', 'Min'],
#  ['Mul', 'ReduceProd', 'Transpose'],
#  ['Max', 'Concat', 'Concat', 'MatMul'],
#  ['Concat', 'Reshape', 'ConvTranspose'],
#  ['Sub', 'ArgMax', 'Min'],
#  ['Mul', 'Concat', 'Concat'],
#  ['Max', 'Max', 'Concat'],
#  ['Gather', 'Concat', 'MatMul'],
#  ['Mul', 'ReverseSequence', 'Reshape'],
#  ['Add', 'ReduceMin', 'Transpose'],
#  ['Mul', 'Reshape', 'MatMul'],
#  ['ReduceMean', 'Reshape', 'ConvTranspose'],
#  ['Reshape', 'Floor', 'Reshape'],
#  ['Floor', 'Concat', 'MatMul'],
#  ['Transpose', 'Atan', 'ReduceMin'],
#  ['Add', 'Concat', 'Cast'],
#  ['LeakyRelu', 'Concat', 'ReduceMax'],
#  ['Reshape', 'Conv', 'Conv', 'DepthToSpace'],
#  ['Concat', 'Transpose', 'DepthToSpace'],
#  ['Min', 'Max', 'Floor'],
#  ['Transpose', 'Min', 'Max'],
#  ['Reshape', 'Conv', 'Conv', 'Relu'],
#  ['Squeeze', 'Sub', 'Concat'],
#  ['LeakyRelu', 'Reshape', 'Transpose', 'Conv'],
#  ['Mul', 'Softmax', 'ReduceSum'],
#  ['Conv', 'Transpose', 'Tan'],
#  ['Conv', 'Transpose', 'Round'],
#  ['Min', 'Max', 'Cos', 'Atan'],
#  ['Min', 'Max', 'Round'],
#  ['Relu', 'Max', 'Concat'],
#  ['Concat', 'Concat', 'Neg'],
#  ['Max', 'MatMul', 'ReduceMean'],
#  ['Conv', 'Reshape', 'BatchNormalization'],
#  ['Mul', 'Add', 'Ceil', 'Concat'],
#  ['Abs', 'Floor', 'Softmax'],
#  ['Min', 'Max', 'Gather', 'Abs'],
#  ['Mul', 'Add', 'ReduceProd'],
#  ['Reshape', 'Transpose', 'Conv', 'ArgMax'],
#  ['Sigmoid', 'Add', 'Concat'],
#  ['ReverseSequence', 'Reshape', 'ReverseSequence', 'Transpose'],
#  ['Concat', 'ReduceProd', 'Mul', 'Add'],
#  ['LeakyRelu', 'Max', 'Softmax'],
#  ['Reshape', 'Sub', 'Mul'],
#  ['Conv', 'LRN', 'Concat', 'Transpose'],
#  ['Transpose', 'Conv', 'Concat', 'Transpose'],
#  ['Max', 'Add', 'Min'],
#  ['Sigmoid', 'Transpose', 'ConvTranspose'],
#  ['ReduceSum', 'Mul', 'Add'],
#  ['Reshape', 'Conv', 'Relu', 'Reshape'],
#  ['MatMul', 'Concat', 'MatMul', 'Reshape'],
#  ['Sigmoid', 'Max', 'Min', 'Max'],
#  ['Transpose', 'ConvTranspose', 'Reshape', 'ConvTranspose'],
#  ['Atan', 'Add', 'Min', 'Max'],
#  ['Reshape', 'ConvTranspose', 'ConvTranspose'],
#  ['Min', 'Ceil', 'Cast'],
#  ['Max', 'Concat', 'LeakyRelu'],
#  ['Mul', 'Add', 'Sub'],
#  ['Squeeze', 'Mul', 'Ceil'],
#  ['Transpose', 'Transpose', 'ConvTranspose', 'Conv'],
#  ['Transpose', 'Transpose', 'ConvTranspose'],
#  ['Reshape', 'MatMul', 'Reshape', 'Conv'],
#  ['Erf', 'Add', 'Mul', 'Transpose'],
#  ['Add', 'Cast', 'Min', 'Max'],
#  ['Mul', 'Ceil', 'Round'],
#  ['Conv', 'Transpose', 'ConvTranspose'],
#  ['Mul', 'Reshape', 'Mul'],
#  ['Floor', 'Reshape', 'Conv', 'Conv'],
#  ['ArgMax', 'ReduceProd', 'Cast'],
#  ['Reshape', 'Conv', 'Relu', 'Min'],
#  ['Reshape', 'Conv', 'LeakyRelu', 'Transpose'],
#  ['Conv', 'Mul', 'Reshape'],
#  ['Max', 'Softmax', 'Concat'],
#  ['Atan', 'Mul', 'Add', 'Mul'],
#  ['Mul', 'Add', 'Concat', 'Concat', 'Cos'],
#  ['Min', 'Max', 'Gather', 'Transpose'],
#  ['Conv', 'Sigmoid', 'Transpose'],
#  ['Conv', 'Reshape', 'Atan'],
#  ['Mul', 'Add', 'Neg'],
#  ['ConvTranspose', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'Transpose', 'Mul', 'Add'],
#  ['Transpose', 'Conv', 'ReduceMean', 'Reshape'],
#  ['Or', 'And', 'And'],
#  ['Add', 'Concat', 'LeakyRelu'],
#  ['Transpose', 'BatchNormalization', 'Transpose'],
#  ['Concat', 'Max', 'Min'],
#  ['Add', 'Ceil', 'Concat'],
#  ['Floor', 'Reshape', 'Conv'],
#  ['ReduceSum', 'Reshape', 'Conv', 'Conv'],
#  ['Concat', 'Transpose', 'Floor'],
#  ['Reshape', 'MatMul', 'Reshape', 'Relu'],
#  ['Floor', 'Transpose', 'Concat'],
#  ['Reshape', 'ConvTranspose', 'Softmax', 'Softmax'],
#  ['Softmax', 'Relu', 'Reshape'],
#  ['Mul', 'Mul', 'Squeeze'],
#  ['Reshape', 'Conv', 'Conv', 'ReduceMean'],
#  ['Reshape', 'Sub', 'Transpose'],
#  ['Concat', 'Cast', 'Max'],
#  ['Reshape', 'Conv', 'Min', 'Max'],
#  ['Mul', 'Add', 'Tan'],
#  ['Min', 'Max', 'Sigmoid'],
#  ['Reshape', 'Gather', 'Mul'],
#  ['Relu', 'Transpose', 'Conv'],
#  ['ReduceProd', 'Reshape', 'SpaceToDepth'],
#  ['Conv', 'Relu', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'Neg'],
#  ['Squeeze', 'ReduceSum', 'Min'],
#  ['Conv', 'Conv', 'Reshape', 'Conv'],
#  ['Transpose', 'Conv', 'ReduceMean'],
#  ['Add', 'Concat', 'ReduceSum'],
#  ['Reshape', 'Conv', 'Sigmoid', 'Transpose'],
#  ['Unsqueeze', 'Mul', 'Add'],
#  ['Concat', 'Mul', 'Reshape'],
#  ['Conv', 'Neg', 'Reshape'],
#  ['Mul', 'Add', 'Min', 'Max'],
#  ['Squeeze', 'Cos', 'Reshape', 'Conv'],
#  ['Transpose', 'Floor', 'Transpose'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMin'],
#  ['Reshape', 'Conv', 'LeakyRelu', 'Reshape'],
#  ['ConvTranspose', 'Concat', 'Conv'],
#  ['Add', 'Mul', 'Neg'],
#  ['Concat', 'Sigmoid', 'LeakyRelu'],
#  ['ConvTranspose', 'Reshape', 'Transpose', 'Conv'],
#  ['Transpose', 'ReverseSequence', 'Transpose', 'Round'],
#  ['Min', 'Div', 'Softmax'],
#  ['Add', 'Mul', 'Add', 'Relu'],
#  ['Conv', 'Conv', 'ConvTranspose', 'Reshape'],
#  ['Reshape', 'ArgMax', 'ReduceMax'],
#  ['ReduceProd', 'Mul', 'Add', 'Mul'],
#  ['BatchNormalization', 'Transpose', 'ConvTranspose'],
#  ['Atan', 'Concat', 'Min'],
#  ['Mul', 'Add', 'Reshape', 'Reshape', 'Conv'],
#  ['Add', 'Concat', 'Max'],
#  ['Concat', 'Transpose', 'Concat'],
#  ['Floor', 'Mul', 'Add'],
#  ['Concat', 'Transpose', 'LRN', 'Transpose'],
#  ['Conv', 'SpaceToDepth', 'DepthToSpace'],
#  ['Transpose', 'Conv', 'Conv', 'Reshape'],
#  ['Min', 'Transpose', 'Conv'],
#  ['Transpose', 'Min', 'Max', 'Gather'],
#  ['Conv', 'Conv', 'Squeeze'],
#  ['Conv', 'Softmax', 'Transpose'],
#  ['Min', 'Max', 'Relu'],
#  ['Concat', 'Concat', 'Abs'],
#  ['Concat', 'Reshape', 'Conv', 'Conv'],
#  ['Reshape', 'ReduceProd', 'Concat'],
#  ['Transpose', 'Conv', 'ConvTranspose', 'Reshape'],
#  ['ReverseSequence', 'Transpose', 'Mul'],
#  ['MatMul', 'Concat', 'Add'],
#  ['Sub', 'Atan', 'Mul'],
#  ['Concat', 'Sub', 'Mul'],
#  ['ArgMax', 'Reshape', 'Cast'],
#  ['Transpose', 'Conv', 'Conv', 'Concat'],
#  ['Transpose', 'Concat', 'Conv', 'Conv'],
#  ['Concat', 'Relu', 'Reshape'],
#  ['Min', 'Max', 'Unsqueeze'],
#  ['Reshape', 'Transpose', 'Sub'],
#  ['Reshape', 'Reshape', 'Conv', 'Conv'],
#  ['And', 'Or', 'And'],
#  ['Transpose', 'Conv', 'ConvTranspose', 'Conv'],
#  ['Cos', 'Concat', 'Unsqueeze'],
#  ['ReduceMin', 'Reshape', 'Conv'],
#  ['MatMul', 'Concat', 'ReduceSum'],
#  ['Mul', 'Add', 'Sigmoid', 'Atan'],
#  ['Conv', 'Concat', 'Transpose'],
#  ['Squeeze', 'Reshape', 'Concat', 'MatMul'],
#  ['Transpose', 'Tan', 'Transpose'],
#  ['Concat', 'Concat', 'Sigmoid'],
#  ['ReduceMax', 'Concat', 'Concat'],
#  ['Transpose', 'Conv', 'Concat', 'Conv'],
#  ['ReduceProd', 'Concat', 'Add'],
#  ['Transpose', 'Tan', 'Max', 'Round'],
#  ['Concat', 'Mul', 'Add', 'Reshape'],
#  ['Transpose', 'LRN', 'ConvTranspose'],
#  ['Concat', 'Transpose', 'ConvTranspose'],
#  ['Neg', 'Mul', 'Add', 'Max'],
#  ['Add', 'ReduceMax', 'Tan'],
#  ['Round', 'Reshape', 'Conv', 'Reshape'],
#  ['Add', 'Mul', 'Add', 'ReduceMax'],
#  ['Floor', 'Min', 'Max'],
#  ['Mul', 'Mul', 'Mul', 'Add'],
#  ['Transpose', 'Mul', 'Mul'],
#  ['Reshape', 'ConvTranspose', 'Softmax'],
#  ['Gather', 'Concat', 'Concat'],
#  ['Gather', 'Reshape', 'ReverseSequence'],
#  ['Transpose', 'Conv', 'Reshape', 'Gather'],
#  ['Max', 'ReduceMin', 'Concat'],
#  ['ReduceMax', 'Reshape', 'Max'],
#  ['MatMul', 'Reshape', 'Reshape'],
#  ['Transpose', 'Conv', 'Transpose', 'BatchNormalization'],
#  ['Mul', 'Transpose', 'Mul', 'Transpose'],
#  ['Reshape', 'Conv', 'Relu', 'Conv'],
#  ['Add', 'Concat', 'Neg', 'ReduceMean'],
#  ['Atan', 'Reshape', 'Conv'],
#  ['Unsqueeze', 'Transpose', 'Add'],
#  ['ReduceProd', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Gather', 'Reshape', 'Conv'],
#  ['Min', 'Max', 'ReduceMean'],
#  ['ConvTranspose', 'Reshape', 'Conv', 'Concat'],
#  ['Sub', 'LeakyRelu', 'Transpose'],
#  ['Floor', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Conv', 'Reshape', 'BatchNormalization', 'Reshape', 'Conv'],
#  ['Add', 'ReduceMin', 'Concat'],
#  ['Concat', 'Concat', 'ReduceSum'],
#  ['Concat', 'Concat', 'Reshape'],
#  ['Conv', 'LeakyRelu', 'Conv', 'Transpose'],
#  ['Atan', 'Concat', 'Div'],
#  ['Abs', 'Reshape', 'MatMul', 'Reshape'],
#  ['DepthToSpace', 'Conv', 'ConvTranspose'],
#  ['Transpose', 'Concat', 'LRN', 'Transpose'],
#  ['Transpose', 'Concat', 'ReduceMin', 'Transpose'],
#  ['Reshape', 'Conv', 'ArgMax'],
#  ['Mul', 'Add', 'ArgMax'],
#  ['Concat', 'Min', 'Concat'],
#  ['Reshape', 'Conv', 'Neg'],
#  ['Concat', 'Concat', 'Transpose'],
#  ['Min', 'Max', 'Concat'],
#  ['Transpose', 'Ceil', 'Transpose'],
#  ['Conv', 'Sub', 'Reshape'],
#  ['Transpose', 'Concat', 'LeakyRelu'],
#  ['Relu', 'ReverseSequence', 'Reshape', 'ReverseSequence'],
#  ['Abs', 'Min', 'Max'],
#  ['Transpose', 'Conv', 'Sub'],
#  ['Squeeze', 'Sub', 'Add'],
#  ['Mul', 'Add', 'ReduceMin'],
#  ['Cast', 'Cast', 'Cast'],
#  ['Reshape', 'Conv', 'Squeeze'],
#  ['ReverseSequence', 'Reshape', 'Conv'],
#  ['ReduceSum', 'Concat', 'Concat'],
#  ['Concat', 'Tan', 'Add'],
#  ['MatMul', 'Reshape', 'MatMul'],
#  ['DepthToSpace', 'Conv', 'Transpose'],
#  ['ReduceMean', 'Sigmoid', 'Mul'],
#  ['Concat', 'Concat', 'Concat', 'Slice'],
#  ['Concat', 'Concat', 'Softmax'],
#  ['Cos', 'Concat', 'Concat', 'MatMul'],
#  ['ReduceMin', 'Transpose', 'Softmax'],
#  ['Cos', 'Slice', 'Mul'],
#  ['Reshape', 'Conv', 'Relu'],
#  ['Reshape', 'MatMul', 'Reshape', 'Tan'],
#  ['Sub', 'Reshape', 'Conv', 'Conv'],
#  ['Tan', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Concat', 'Transpose', 'Reshape'],
#  ['Reshape', 'Concat', 'Concat'],
#  ['MatMul', 'Concat', 'Sigmoid'],
#  ['Reshape', 'Conv', 'Sub'],
#  ['Concat', 'MatMul', 'Reshape'],
#  ['Max', 'MatMul', 'ReduceMean', 'Concat'],
#  ['Mul', 'Mul', 'Sigmoid'],
#  ['Ceil', 'Reshape', 'Conv'],
#  ['Abs', 'Add', 'Transpose'],
#  ['Add', 'Tan', 'Round'],
#  ['Transpose', 'DepthToSpace', 'Reshape'],
#  ['Max', 'Shape', 'Gather'],
#  ['Squeeze', 'ArgMax', 'Min', 'Max'],
#  ['Reshape', 'Conv', 'Squeeze', 'Reshape'],
#  ['Conv', 'Relu', 'Transpose'],
#  ['Cast', 'Min', 'Reshape'],
#  ['Transpose', 'Conv', 'Reshape', 'Transpose'],
#  ['Softmax', 'Conv', 'Reshape'],
#  ['Mul', 'Add', 'Cast', 'ReduceMin'],
#  ['Round', 'Concat', 'Cast'],
#  ['Div', 'Concat', 'Abs'],
#  ['ConvTranspose', 'Conv', 'Conv'],
#  ['Transpose', 'ConvTranspose', 'Transpose', 'Conv', 'Transpose'],
#  ['Reshape', 'Transpose', 'Conv', 'SpaceToDepth'],
#  ['Conv', 'Reshape', 'Mul', 'ReduceProd'],
#  ['Sub', 'Reshape', 'Conv', 'Reshape'],
#  ['LRN', 'Transpose', 'Cos'],
#  ['Reshape', 'Conv', 'ReduceMin', 'Concat'],
#  ['Round', 'Reshape', 'Conv', 'Transpose'],
#  ['Reshape', 'Transpose', 'Conv', 'Conv'],
#  ['Concat', 'Concat', 'Relu'],
#  ['Concat', 'Max', 'LeakyRelu'],
#  ['Transpose', 'Conv', 'Relu'],
#  ['Slice', 'Cast', 'Add'],
#  ['Squeeze', 'Unsqueeze', 'Reshape'],
#  ['Reshape', 'Min', 'Relu'],
#  ['Transpose', 'Conv', 'Cast', 'Transpose'],
#  ['Min', 'Max', 'Sub', 'Reshape'],
#  ['Min', 'Max', 'Cast'],
#  ['Reshape', 'Conv', 'Mul'],
#  ['Conv', 'Reshape', 'Transpose', 'Conv'],
#  ['Mul', 'Max', 'Ceil'],
#  ['Floor', 'ArgMax', 'Min'],
#  ['ReduceMean', 'Reshape', 'Concat'],
#  ['Atan', 'Atan', 'Reshape'],
#  ['Conv', 'ConvTranspose', 'Conv'],
#  ['Mul', 'Max', 'Min'],
#  ['ReduceProd', 'Cos', 'Ceil'],
#  ['Transpose', 'Conv', 'ReduceMin'],
#  ['ReverseSequence', 'Transpose', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'Sigmoid'],
#  ['Concat', 'Cast', 'Abs']]

# %%
filtered = list(
    filter(
        lambda x: (len(x) > 2),
        detokenize_seqs(token_node_type_dict, reduced_sequences),
    )
)
len(filtered)
# Out:
# 865

# %%
filtered_ops = set()
for filt in filtered:
    filtered_ops = filtered_ops.union(filt)
filtered_ops
# Out:
# {'Abs',
#  'Add',
#  'And',
#  'ArgMax',
#  'Atan',
#  'BatchNormalization',
#  'Cast',
#  'Ceil',
#  'Concat',
#  'Conv',
#  'ConvTranspose',
#  'Cos',
#  'DepthToSpace',
#  'Div',
#  'Erf',
#  'Expand',
#  'Floor',
#  'Gather',
#  'GlobalAveragePool',
#  'Greater',
#  'LRN',
#  'LeakyRelu',
#  'MatMul',
#  'Max',
#  'Min',
#  'Mul',
#  'Neg',
#  'Not',
#  'Or',
#  'ReduceMax',
#  'ReduceMean',
#  'ReduceMin',
#  'ReduceProd',
#  'ReduceSum',
#  'Relu',
#  'Reshape',
#  'ReverseSequence',
#  'Round',
#  'Shape',
#  'Sigmoid',
#  'Slice',
#  'Softmax',
#  'SpaceToDepth',
#  'Squeeze',
#  'Sub',
#  'Tan',
#  'Transpose',
#  'Unsqueeze'}

# %% [markdown]
# ### Find Unique Sequence Distribution by Pairs

# %%
tokenized_filtered = tokenize_seqs(mismatched_seq['node_type_token_dict'], filtered)

# %%
sequence_counts_by_pair = {}
for i, (pair, sequences) in enumerate(mismatched_seq['results'].items()):
    a, b = pair.split(",")
    unq_seq = set(sequences)
    unq_seq_stripped = set()
    for seq in unq_seq:
        new_seq = seq.strip(mismatched_seq['node_type_token_dict']['input'])
        new_seq = new_seq.strip(mismatched_seq['node_type_token_dict']['output'])
        if len(new_seq) > 2:
            unq_seq_stripped.add(new_seq)
    
    for filt_seq in tokenized_filtered:
        if filt_seq in unq_seq_stripped:
            if a not in sequence_counts_by_pair:
                sequence_counts_by_pair[a] = set([filt_seq])
            else:
                sequence_counts_by_pair[a] |= set([filt_seq])
            if b not in sequence_counts_by_pair:
                sequence_counts_by_pair[b] = set([filt_seq])
            else:
                sequence_counts_by_pair[b] |= set([filt_seq])
        else:
            if a not in sequence_counts_by_pair:
                sequence_counts_by_pair[a] = set()
            if b not in sequence_counts_by_pair:
                sequence_counts_by_pair[b] = set()
filtered_sorted_pairs = dict(sorted({key: len(val) for key, val in sequence_counts_by_pair.items()}.items(), key=lambda x: x[1], reverse=True))
filtered_sorted_pairs
# Out:
# {'71': 55,
#  '29': 52,
#  '64': 51,
#  '82': 46,
#  '196': 45,
#  '208': 45,
#  '50': 43,
#  '77': 37,
#  '140': 36,
#  '166': 36,
#  '32': 35,
#  '2': 33,
#  '193': 33,
#  '144': 32,
#  '164': 32,
#  '69': 31,
#  '156': 29,
#  '216': 29,
#  '1': 28,
#  '41': 28,
#  '60': 28,
#  '46': 27,
#  '91': 27,
#  '211': 27,
#  '72': 26,
#  '94': 26,
#  '118': 26,
#  '151': 26,
#  '126': 25,
#  '133': 25,
#  '161': 25,
#  '28': 24,
#  '70': 24,
#  '183': 24,
#  '201': 24,
#  '15': 21,
#  '90': 21,
#  '112': 21,
#  '136': 21,
#  '182': 21,
#  '88': 20,
#  '56': 19,
#  '86': 19,
#  '96': 19,
#  '202': 19,
#  '35': 18,
#  '37': 18,
#  '203': 18,
#  '212': 18,
#  '38': 17,
#  '117': 17,
#  '129': 17,
#  '13': 16,
#  '100': 16,
#  '121': 16,
#  '157': 16,
#  '30': 15,
#  '102': 15,
#  '109': 15,
#  '51': 14,
#  '53': 14,
#  '79': 14,
#  '101': 14,
#  '128': 14,
#  '172': 14,
#  '173': 14,
#  '174': 14,
#  '27': 13,
#  '52': 13,
#  '58': 13,
#  '76': 13,
#  '85': 13,
#  '186': 13,
#  '21': 12,
#  '55': 12,
#  '113': 12,
#  '127': 12,
#  '146': 12,
#  '209': 12,
#  '0': 11,
#  '99': 11,
#  '124': 11,
#  '131': 11,
#  '162': 11,
#  '170': 11,
#  '190': 11,
#  '197': 11,
#  '199': 11,
#  '213': 11,
#  '78': 10,
#  '103': 10,
#  '125': 10,
#  '200': 10,
#  '214': 10,
#  '4': 9,
#  '44': 9,
#  '141': 9,
#  '198': 9,
#  '3': 8,
#  '7': 8,
#  '8': 8,
#  '19': 8,
#  '39': 8,
#  '54': 8,
#  '63': 8,
#  '115': 8,
#  '120': 8,
#  '138': 8,
#  '142': 8,
#  '154': 8,
#  '163': 8,
#  '169': 8,
#  '188': 8,
#  '10': 7,
#  '36': 7,
#  '57': 7,
#  '84': 7,
#  '95': 7,
#  '108': 7,
#  '123': 7,
#  '168': 7,
#  '175': 7,
#  '177': 7,
#  '218': 7,
#  '219': 7,
#  '12': 6,
#  '80': 6,
#  '152': 6,
#  '153': 6,
#  '176': 6,
#  '189': 6,
#  '6': 5,
#  '16': 5,
#  '26': 5,
#  '31': 5,
#  '47': 5,
#  '59': 5,
#  '97': 5,
#  '110': 5,
#  '122': 5,
#  '145': 5,
#  '155': 5,
#  '160': 5,
#  '178': 5,
#  '181': 5,
#  '206': 5,
#  '5': 4,
#  '9': 4,
#  '23': 4,
#  '40': 4,
#  '45': 4,
#  '62': 4,
#  '68': 4,
#  '106': 4,
#  '114': 4,
#  '135': 4,
#  '149': 4,
#  '150': 4,
#  '159': 4,
#  '165': 4,
#  '167': 4,
#  '180': 4,
#  '187': 4,
#  '195': 4,
#  '205': 4,
#  '207': 4,
#  '210': 4,
#  '215': 4,
#  '217': 4,
#  '14': 3,
#  '20': 3,
#  '24': 3,
#  '34': 3,
#  '43': 3,
#  '61': 3,
#  '66': 3,
#  '67': 3,
#  '73': 3,
#  '74': 3,
#  '75': 3,
#  '81': 3,
#  '93': 3,
#  '107': 3,
#  '116': 3,
#  '119': 3,
#  '134': 3,
#  '137': 3,
#  '147': 3,
#  '148': 3,
#  '179': 3,
#  '185': 3,
#  '191': 3,
#  '42': 2,
#  '65': 2,
#  '87': 2,
#  '89': 2,
#  '92': 2,
#  '98': 2,
#  '104': 2,
#  '130': 2,
#  '139': 2,
#  '143': 2,
#  '171': 2,
#  '11': 1,
#  '17': 1,
#  '18': 1,
#  '33': 1,
#  '48': 1,
#  '49': 1,
#  '83': 1,
#  '111': 1,
#  '132': 1,
#  '158': 1,
#  '192': 1,
#  '194': 1,
#  '204': 1,
#  '22': 0,
#  '25': 0,
#  '105': 0,
#  '184': 0}

# %%
len(sequence_counts_by_pair)
# Out:
# 220

# %% [markdown]
# ## Mismatched-Test Sequences

# %%
(
    unique_test_mismatched_sequences,
    unique_test_mismatched_sequences_decoded,
    total_test_mismatched_sequences,
) = get_unq_sequences(mismatched_test)
# Out:
# Total Sequences: 5,481, Total Unique Sequences: 35, Total Paths Compared: 0

# %%
len(recursive_submatching(unique_test_mismatched_sequences, len(unique_test_mismatched_sequences)))
# Out:
# 35
# 35

# %% [markdown]
# ### Create New Tokenizers and Calculate Non-Overlapping

# %%
node_type_token_dict, token_node_type_dict = create_tokenizers(
    mismatched_test["node_type_token_dict"], mismatched_seq["node_type_token_dict"]
)

# %%
mismatched_sequences = set(tokenize_seqs(node_type_token_dict, unique_mismatched_sequences_decoded))
mismatched_test_sequences = set(tokenize_seqs(node_type_token_dict, unique_test_mismatched_sequences_decoded))

# %% [markdown]
# #### Nonoverlapping

# %%
len(mismatched_sequences)
# Out:
# 2155

# %%
len(mismatched_test_sequences)
# Out:
# 35

# %%
len(mismatched_sequences - mismatched_test_sequences)
# Out:
# 2135

# %%
seqs =  mismatched_sequences - mismatched_test_sequences
len(seqs)
# Out:
# 2135

# %%
reduced_sequences = recursive_submatching(seqs, len(seqs))
# Out:
# 1255
# 1129
# 1106
# 1102
# 1102

# %%
list(
    filter(
        lambda x: (len(x) > 2) and ("input" not in x) and ("output" not in x),
        detokenize_seqs(token_node_type_dict, reduced_sequences),
    )
)
# Out:
# [['Neg', 'Mul', 'Add'],
#  ['ReduceSum', 'Mul', 'Add', 'Concat'],
#  ['Reshape', 'Tan', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceSum'],
#  ['Transpose', 'Conv', 'Cast'],
#  ['Min', 'MatMul', 'Concat'],
#  ['Max', 'Reshape', 'Conv'],
#  ['ReduceSum', 'Concat', 'Div'],
#  ['Sigmoid', 'Mul', 'Add'],
#  ['ReduceMax', 'Min', 'Max'],
#  ['Round', 'Mul', 'Add'],
#  ['Transpose', 'Concat', 'Concat'],
#  ['ReduceProd', 'Reshape', 'SpaceToDepth'],
#  ['Tan', 'Reshape', 'ConvTranspose'],
#  ['Reshape', 'Slice', 'Transpose', 'Conv'],
#  ['Max', 'Shape', 'Gather'],
#  ['Conv', 'Reshape', 'Atan'],
#  ['Tan', 'Round', 'Floor'],
#  ['Transpose', 'Conv', 'ReduceMax', 'Transpose'],
#  ['Transpose', 'Conv', 'Neg'],
#  ['Transpose', 'Min', 'Max'],
#  ['Min', 'Max', 'Tan', 'Sub'],
#  ['Relu', 'Concat', 'Concat'],
#  ['Concat', 'Concat', 'Cos'],
#  ['ConvTranspose', 'Max', 'Conv'],
#  ['Conv', 'ReduceProd', 'Reshape'],
#  ['And', 'And', 'Not'],
#  ['Reshape', 'MatMul', 'Reshape', 'Tan'],
#  ['Conv', 'ReduceMax', 'Reshape'],
#  ['Max', 'Conv', 'Transpose'],
#  ['Relu', 'Tan', 'Concat'],
#  ['Sigmoid', 'Sigmoid', 'Add'],
#  ['Transpose', 'Conv', 'Transpose', 'Round'],
#  ['Max', 'Max', 'ReduceMin'],
#  ['ArgMax', 'Abs', 'Min'],
#  ['Reshape', 'Conv', 'Sub', 'Reshape'],
#  ['Conv', 'Transpose', 'Floor'],
#  ['Reshape', 'ReduceProd', 'Concat'],
#  ['Min', 'Max', 'Gather', 'Unsqueeze'],
#  ['Reshape', 'Conv', 'LRN', 'Transpose'],
#  ['Squeeze', 'Cos', 'Reshape', 'Conv'],
#  ['Reshape', 'DepthToSpace', 'Transpose', 'Reshape'],
#  ['Concat', 'Mul', 'Add'],
#  ['MatMul', 'Reshape', 'Concat'],
#  ['Mul', 'Add', 'Transpose'],
#  ['Concat', 'Round', 'ReduceSum'],
#  ['Reshape', 'Conv', 'Transpose', 'Cos'],
#  ['ReduceSum', 'ReduceMean', 'Concat'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceMean'],
#  ['Conv', 'Reshape', 'ReduceSum'],
#  ['Add', 'ReduceMax', 'Tan'],
#  ['Mul', 'Add', 'Min'],
#  ['Mul', 'Add', 'ReduceMin'],
#  ['Reshape', 'Mul', 'Add'],
#  ['Reshape', 'Reshape', 'MatMul', 'Reshape'],
#  ['Transpose', 'Conv', 'Transpose', 'Reshape'],
#  ['Concat', 'LRN', 'Transpose'],
#  ['Squeeze', 'Cos', 'Concat'],
#  ['MatMul', 'Reshape', 'MatMul'],
#  ['Reshape', 'Sub', 'Reshape'],
#  ['Neg', 'Reshape', 'Conv', 'Transpose'],
#  ['ArgMax', 'Add', 'Concat'],
#  ['Reshape', 'MatMul', 'Reshape'],
#  ['Min', 'Max', 'ReduceProd'],
#  ['Transpose', 'DepthToSpace', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'Concat'],
#  ['Slice', 'Add', 'Sigmoid'],
#  ['Squeeze', 'Mul', 'Ceil'],
#  ['Conv', 'Neg', 'Conv'],
#  ['Mul', 'Reshape', 'Mul', 'ReduceMin'],
#  ['Min', 'Max', 'Concat'],
#  ['Reshape', 'ConvTranspose', 'Mul', 'Reshape'],
#  ['Reshape', 'Conv', 'Sub', 'Transpose'],
#  ['Mul', 'Cast', 'Min'],
#  ['Softmax', 'Reshape', 'Conv'],
#  ['Mul', 'Add', 'ReduceMean'],
#  ['MatMul', 'Concat', 'MatMul', 'Reshape'],
#  ['ConvTranspose', 'Reshape', 'Transpose', 'ConvTranspose'],
#  ['Squeeze', 'ReduceSum', 'Min'],
#  ['Transpose', 'ReverseSequence', 'Transpose', 'ReverseSequence', 'Transpose'],
#  ['Reshape', 'Conv', 'ReduceMean'],
#  ['Conv', 'Transpose', 'Transpose', 'Conv'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMean'],
#  ['Conv', 'Conv', 'ConvTranspose', 'Reshape'],
#  ['Reshape', 'DepthToSpace', 'Slice'],
#  ['ReduceMean', 'Mul', 'Add'],
#  ['Conv', 'Conv', 'ReduceMax'],
#  ['Mul', 'ReduceProd', 'Transpose'],
#  ['Gather', 'Reshape', 'Transpose'],
#  ['Min', 'Max', 'Cast'],
#  ['ReverseSequence', 'Squeeze', 'Unsqueeze'],
#  ['And', 'Or', 'And'],
#  ['Max', 'Concat', 'Max'],
#  ['Relu', 'Reshape', 'MatMul', 'Reshape'],
#  ['Reshape', 'Transpose', 'ConvTranspose'],
#  ['ReduceMax', 'Reshape', 'Conv', 'Conv'],
#  ['Reshape', 'Conv', 'Conv', 'Conv'],
#  ['ReduceProd', 'Mul', 'Mul'],
#  ['Min', 'Max', 'Gather', 'Floor'],
#  ['LeakyRelu', 'Concat', 'ReduceMean'],
#  ['Transpose', 'LRN', 'Reshape'],
#  ['Concat', 'Transpose', 'Mul', 'Add'],
#  ['Reshape', 'Conv', 'Reshape'],
#  ['Conv', 'Reshape', 'ConvTranspose'],
#  ['Add', 'Mul', 'Mul'],
#  ['Concat', 'Atan', 'Concat'],
#  ['Gather', 'Expand', 'ReverseSequence'],
#  ['Reshape', 'Mul', 'Reshape'],
#  ['ReverseSequence', 'Squeeze', 'Mul'],
#  ['Reshape', 'Concat', 'Mul', 'Reshape'],
#  ['Concat', 'MatMul', 'Mul'],
#  ['Concat', 'Concat', 'Abs'],
#  ['Add', 'Concat', 'Neg'],
#  ['Mul', 'Add', 'Softmax'],
#  ['Mul', 'Add', 'Transpose', 'Mul', 'Add'],
#  ['Min', 'Max', 'Abs', 'Mul'],
#  ['Mul', 'Mul', 'Tan'],
#  ['Neg', 'Min', 'Max'],
#  ['Transpose', 'Floor', 'Transpose'],
#  ['Reshape', 'ConvTranspose', 'Conv', 'Conv'],
#  ['Transpose', 'ReverseSequence', 'Transpose', 'Round'],
#  ['Reshape', 'Concat', 'Min'],
#  ['Ceil', 'Reshape', 'MatMul', 'Reshape'],
#  ['ReduceMean', 'Reshape', 'Concat'],
#  ['Slice', 'Transpose', 'Conv'],
#  ['Floor', 'Concat', 'Reshape'],
#  ['Concat', 'Concat', 'Cast'],
#  ['MatMul', 'Concat', 'Concat'],
#  ['Mul', 'Abs', 'Max'],
#  ['Reshape', 'Reshape', 'Conv'],
#  ['Reshape', 'ConvTranspose', 'Reshape', 'Transpose'],
#  ['Reshape', 'ConvTranspose', 'Softmax'],
#  ['Max', 'ReduceMin', 'Min'],
#  ['Concat', 'Concat', 'Reshape'],
#  ['ReduceSum', 'Mul', 'Mul'],
#  ['Transpose', 'Conv', 'Conv', 'ConvTranspose'],
#  ['Concat', 'Sigmoid', 'MatMul'],
#  ['Reshape', 'MatMul', 'Mul'],
#  ['MatMul', 'Cast', 'Cast'],
#  ['ReduceProd', 'Concat', 'Add'],
#  ['Mul', 'Add', 'Concat', 'Transpose'],
#  ['Concat', 'Concat', 'Softmax'],
#  ['ConvTranspose', 'Reshape', 'Transpose'],
#  ['ArgMax', 'Min', 'Max'],
#  ['Transpose', 'Conv', 'ReduceMean', 'Reshape'],
#  ['Reshape', 'Concat', 'Transpose'],
#  ['Reshape', 'Conv', 'Min'],
#  ['Neg', 'Mul', 'Mul'],
#  ['Gather', 'Slice', 'Concat'],
#  ['Conv', 'LeakyRelu', 'Conv'],
#  ['Slice', 'Reshape', 'ConvTranspose'],
#  ['Reshape', 'Conv', 'ReduceMin'],
#  ['Reshape', 'MatMul', 'Reshape', 'Cos'],
#  ['Add', 'Mul', 'Ceil'],
#  ['Reshape', 'Mul', 'Softmax'],
#  ['Conv', 'DepthToSpace', 'Conv'],
#  ['ConvTranspose', 'Reshape', 'Reshape'],
#  ['Min', 'Max', 'Gather', 'Sigmoid'],
#  ['Concat', 'Concat', 'Relu'],
#  ['Reshape', 'ArgMax', 'ReduceMax'],
#  ['BatchNormalization', 'Reshape', 'Conv'],
#  ['Reshape', 'Conv', 'Conv', 'Squeeze'],
#  ['Conv', 'Conv', 'Transpose', 'Transpose'],
#  ['ReduceMin', 'Transpose', 'Softmax'],
#  ['ConvTranspose', 'Relu', 'Transpose'],
#  ['Conv', 'Add', 'Transpose'],
#  ['ReverseSequence', 'Transpose', 'Mul'],
#  ['Reshape', 'Conv', 'Relu', 'Min'],
#  ['ReduceMean', 'Reshape', 'Conv'],
#  ['Conv', 'Transpose', 'ReduceSum', 'Concat'],
#  ['Min', 'Div', 'Mul'],
#  ['Unsqueeze', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Div', 'LeakyRelu'],
#  ['Mul', 'Mul', 'ArgMax'],
#  ['Add', 'Mul', 'ReduceSum'],
#  ['Conv', 'Reshape', 'Div'],
#  ['Max', 'Concat', 'Concat'],
#  ['Squeeze', 'Sub', 'Add'],
#  ['Transpose', 'Mul', 'Add', 'Concat'],
#  ['ReduceMean', 'Transpose', 'Conv'],
#  ['MatMul', 'ReduceMean', 'Concat'],
#  ['Floor', 'Reshape', 'Conv'],
#  ['Concat', 'Neg', 'ReduceMean'],
#  ['Mul', 'Mul', 'Atan'],
#  ['Sigmoid', 'Concat', 'Div'],
#  ['Min', 'Max', 'Abs'],
#  ['Reshape', 'Conv', 'Reshape', 'Conv'],
#  ['Concat', 'Sub', 'Ceil'],
#  ['Ceil', 'Cast', 'Min'],
#  ['SpaceToDepth', 'Transpose', 'Conv'],
#  ['MatMul', 'Reshape', 'Reshape'],
#  ['Min', 'Max', 'Conv'],
#  ['Transpose', 'Min', 'Reshape'],
#  ['Mul', 'Add', 'Cos'],
#  ['Erf', 'Add', 'Mul'],
#  ['ArgMax', 'Mul', 'Add'],
#  ['Mul', 'Mul', 'Round'],
#  ['Concat', 'Concat', 'Max'],
#  ['Mul', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Mul', 'Add', 'Reshape'],
#  ['ReverseSequence', 'Transpose', 'ReverseSequence'],
#  ['Atan', 'Min', 'Max'],
#  ['Conv', 'Conv', 'Mul'],
#  ['Transpose', 'Conv', 'Concat', 'Conv'],
#  ['Conv', 'Concat', 'Transpose'],
#  ['Cos', 'Concat', 'Concat'],
#  ['Reshape', 'Conv', 'Reshape', 'Mul'],
#  ['Atan', 'Cast', 'Cast'],
#  ['ReduceMean', 'Sigmoid', 'Mul', 'Mul'],
#  ['Mul', 'Mul', 'Concat', 'Concat'],
#  ['Min', 'Transpose', 'Conv'],
#  ['Round', 'Mul', 'Add', 'ArgMax'],
#  ['Cast', 'Cast', 'Cast'],
#  ['Gather', 'Transpose', 'Conv'],
#  ['ReduceSum', 'Reshape', 'Conv', 'Conv'],
#  ['Reshape', 'Conv', 'Sigmoid'],
#  ['Transpose', 'Conv', 'LeakyRelu'],
#  ['Reshape', 'ConvTranspose', 'Concat'],
#  ['Floor', 'Min', 'Max'],
#  ['Gather', 'Reshape', 'ConvTranspose'],
#  ['ReduceMax', 'Concat', 'LeakyRelu'],
#  ['Min', 'Max', 'Mul'],
#  ['LeakyRelu', 'Concat', 'Slice'],
#  ['Transpose', 'ConvTranspose', 'Reshape', 'Conv'],
#  ['Reshape', 'Conv', 'Transpose', 'Round'],
#  ['Conv', 'ReduceMean', 'Reshape'],
#  ['ReduceMin', 'Reshape', 'ConvTranspose'],
#  ['Max', 'Reshape', 'MatMul', 'Reshape'],
#  ['Transpose', 'ConvTranspose', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Cast', 'Concat'],
#  ['Gather', 'Mul', 'Add'],
#  ['Cast', 'Min', 'Max'],
#  ['Softmax', 'Concat', 'Mul'],
#  ['ReduceMax', 'Min', 'Max', 'Gather'],
#  ['Concat', 'Concat', 'Mul'],
#  ['Conv', 'Conv', 'Reshape', 'Atan'],
#  ['Mul', 'Max', 'Min'],
#  ['ReduceMin', 'Transpose', 'Mul'],
#  ['Mul', 'Concat', 'LeakyRelu'],
#  ['Min', 'Min', 'LeakyRelu'],
#  ['Conv', 'SpaceToDepth', 'DepthToSpace'],
#  ['Reshape', 'Min', 'Relu'],
#  ['Mul', 'Add', 'Sigmoid', 'Atan'],
#  ['Conv', 'Reshape', 'Mul', 'Reshape'],
#  ['Reshape', 'Mul', 'Transpose'],
#  ['Conv', 'Softmax', 'Reshape'],
#  ['Max', 'Mul', 'Mul'],
#  ['Reshape', 'Concat', 'Mul'],
#  ['Reshape', 'Conv', 'LeakyRelu', 'Reshape'],
#  ['Unsqueeze', 'Reshape', 'Conv'],
#  ['Conv', 'Mul', 'Transpose', 'Mul'],
#  ['Reshape', 'Sub', 'Transpose'],
#  ['Reshape', 'ReduceSum', 'Reshape'],
#  ['Reshape', 'ReverseSequence', 'Reshape', 'Conv'],
#  ['Squeeze', 'Min', 'Concat'],
#  ['Conv', 'Conv', 'Transpose', 'Reshape'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceMin'],
#  ['Mul', 'Mul', 'Reshape', 'Concat'],
#  ['Reshape', 'Concat', 'ReduceSum'],
#  ['Concat', 'Transpose', 'Conv'],
#  ['MatMul', 'Mul', 'Mul'],
#  ['Concat', 'MatMul', 'ReduceProd'],
#  ['Concat', 'Concat', 'Slice'],
#  ['Min', 'Round', 'Reshape'],
#  ['Concat', 'ReduceProd', 'Mul', 'Add'],
#  ['Transpose', 'Conv', 'DepthToSpace'],
#  ['Conv', 'Conv', 'LRN'],
#  ['ReduceProd', 'Add', 'ArgMax'],
#  ['Max', 'Concat', 'Mul'],
#  ['Unsqueeze', 'Mul', 'Add'],
#  ['Mul', 'Add', 'Round'],
#  ['ReduceMean', 'Concat', 'Concat'],
#  ['Add', 'Concat', 'Unsqueeze'],
#  ['Reshape', 'Reshape', 'Reshape'],
#  ['Ceil', 'Concat', 'Transpose'],
#  ['Concat', 'Min', 'Concat'],
#  ['Atan', 'Transpose', 'Conv'],
#  ['Max', 'ReduceProd', 'Min'],
#  ['Mul', 'Mul', 'Reshape'],
#  ['Cast', 'Cast', 'Mul', 'Add'],
#  ['Transpose', 'Conv', 'Sub'],
#  ['Conv', 'ReduceProd', 'ReduceMin'],
#  ['Max', 'MatMul', 'ReduceMean'],
#  ['Transpose', 'DepthToSpace', 'Conv'],
#  ['Ceil', 'Concat', 'Transpose', 'Concat'],
#  ['Transpose', 'LRN', 'Transpose'],
#  ['MatMul', 'Concat', 'Softmax'],
#  ['Concat', 'Concat', 'MatMul'],
#  ['ReduceProd', 'Min', 'Max'],
#  ['Mul', 'Mul', 'Concat', 'Sigmoid'],
#  ['Transpose', 'Tan', 'Max', 'Round'],
#  ['Atan', 'Concat', 'Min'],
#  ['Transpose', 'BatchNormalization', 'Transpose'],
#  ['MatMul', 'Min', 'Max'],
#  ['Slice', 'Reshape', 'Conv'],
#  ['Max', 'Tan', 'Div'],
#  ['Concat', 'Reshape', 'Conv', 'Conv'],
#  ['Add', 'Mul', 'Add', 'ReduceMax'],
#  ['Reshape', 'DepthToSpace', 'Transpose'],
#  ['Reshape', 'Round', 'Reshape'],
#  ['Relu', 'Min', 'Max'],
#  ['Div', 'Min', 'Max'],
#  ['MatMul', 'Add', 'Min'],
#  ['Mul', 'Mul', 'Cast'],
#  ['Reshape', 'Concat', 'ConvTranspose'],
#  ['Min', 'Min', 'Max', 'Gather'],
#  ['Transpose', 'Round', 'LeakyRelu'],
#  ['Conv', 'LRN', 'Transpose'],
#  ['Tan', 'Reshape', 'Conv'],
#  ['Reshape', 'Cos', 'Reshape'],
#  ['MatMul', 'Concat', 'ReduceSum'],
#  ['Concat', 'ReverseSequence', 'Transpose'],
#  ['Reshape', 'Conv', 'Relu', 'Conv'],
#  ['Reshape', 'MatMul', 'Reshape', 'Neg'],
#  ['Min', 'Max', 'Transpose'],
#  ['Round', 'Concat', 'Concat'],
#  ['Conv', 'Conv', 'Sub'],
#  ['ConvTranspose', 'Conv', 'Conv'],
#  ['Concat', 'Min', 'Max'],
#  ['Conv', 'Reshape', 'Conv'],
#  ['Reshape', 'Conv', 'Sub'],
#  ['Transpose', 'Round', 'Concat'],
#  ['Concat', 'Max', 'LeakyRelu'],
#  ['Reshape', 'MatMul', 'Reshape', 'Reshape'],
#  ['Softmax', 'Abs', 'Softmax'],
#  ['Floor', 'Cast', 'Max'],
#  ['Floor', 'Concat', 'Reshape', 'Conv'],
#  ['ArgMax', 'Reshape', 'Cast'],
#  ['Cos', 'Min', 'Max'],
#  ['Concat', 'Softmax', 'Abs'],
#  ['Gather', 'Reshape', 'ReverseSequence'],
#  ['Concat', 'Concat', 'Transpose'],
#  ['Conv', 'ConvTranspose', 'Conv'],
#  ['Neg', 'Reshape', 'Conv', 'LeakyRelu'],
#  ['Add', 'Ceil', 'Concat'],
#  ['Max', 'Add', 'Mul'],
#  ['Reshape', 'MatMul', 'Reshape', 'Conv'],
#  ['Div', 'Concat', 'Abs'],
#  ['Reshape', 'Concat', 'MatMul'],
#  ['Conv', 'Transpose', 'Transpose'],
#  ['Sub', 'LeakyRelu', 'Transpose'],
#  ['Transpose', 'Transpose', 'ConvTranspose'],
#  ['Squeeze', 'Transpose', 'Conv'],
#  ['Slice', 'Max', 'Round'],
#  ['ReduceMax', 'Concat', 'Concat'],
#  ['Atan', 'Mul', 'Mul'],
#  ['Min', 'Reshape', 'Transpose', 'Conv'],
#  ['Concat', 'Reshape', 'Conv'],
#  ['MatMul', 'Concat', 'ReduceMean'],
#  ['DepthToSpace', 'Conv', 'Transpose'],
#  ['ReverseSequence', 'Reshape', 'ReverseSequence'],
#  ['Add', 'Cast', 'Min', 'Max'],
#  ['LeakyRelu', 'Cast', 'Min', 'Max'],
#  ['Reshape', 'MatMul', 'Reshape', 'Slice'],
#  ['Max', 'MatMul', 'ReduceMean', 'Concat'],
#  ['Mul', 'Cast', 'Cast'],
#  ['Min', 'Max', 'Add'],
#  ['Tan', 'Transpose', 'Conv', 'Conv'],
#  ['Add', 'Round', 'LeakyRelu'],
#  ['Concat', 'Transpose', 'LRN', 'Transpose'],
#  ['ReduceMean', 'ReduceMean', 'Concat'],
#  ['Abs', 'Min', 'Max'],
#  ['Mul', 'Min', 'Floor'],
#  ['Max', 'Transpose', 'Reshape'],
#  ['Mul', 'Mul', 'Div'],
#  ['Slice', 'Mul', 'Add'],
#  ['MatMul', 'Reshape', 'Transpose'],
#  ['Cast', 'Gather', 'Min', 'Max'],
#  ['Transpose', 'Conv', 'Conv', 'Reshape'],
#  ['Transpose', 'Mul', 'Reshape'],
#  ['Mul', 'Reshape', 'MatMul'],
#  ['Mul', 'Mul', 'Mul', 'Min'],
#  ['Transpose', 'Conv', 'ConvTranspose', 'Reshape'],
#  ['Reshape', 'ConvTranspose', 'Reshape'],
#  ['Max', 'Concat', 'Mul', 'Add'],
#  ['Mul', 'Add', 'Concat'],
#  ['Conv', 'Cast', 'Transpose'],
#  ['Conv', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Mul', 'Mul', 'Squeeze'],
#  ['Sub', 'ArgMax', 'Cast'],
#  ['Conv', 'Relu', 'Min'],
#  ['Reshape', 'Conv', 'ReduceProd'],
#  ['Min', 'Max', 'Reshape', 'Gather'],
#  ['Concat', 'Concat', 'Mul', 'Add'],
#  ['Concat', 'Transpose', 'ConvTranspose'],
#  ['Reshape', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Squeeze', 'Mul', 'Add'],
#  ['ReverseSequence', 'Squeeze', 'Div'],
#  ['Mul', 'Reshape', 'Concat'],
#  ['Sigmoid', 'Concat', 'LeakyRelu'],
#  ['Reshape', 'Mul', 'Mul'],
#  ['Conv', 'Transpose', 'Mul'],
#  ['Transpose', 'Atan', 'ReduceMin'],
#  ['Reshape', 'Reshape', 'Transpose', 'Conv'],
#  ['Concat', 'Concat', 'ReduceSum'],
#  ['Transpose', 'Transpose', 'Conv', 'Transpose'],
#  ['ReverseSequence', 'Transpose', 'Min'],
#  ['Reshape', 'Conv', 'Max'],
#  ['Min', 'Max', 'Shape'],
#  ['ConvTranspose', 'SpaceToDepth', 'Transpose'],
#  ['Floor', 'Mul', 'Add'],
#  ['Conv', 'Conv', 'ReduceMin'],
#  ['Min', 'Max', 'Gather', 'Transpose'],
#  ['Mul', 'ReverseSequence', 'Reshape', 'ReverseSequence'],
#  ['Transpose', 'Ceil', 'Transpose'],
#  ['Mul', 'Reshape', 'Mul'],
#  ['MatMul', 'Mul', 'Add', 'Concat'],
#  ['Div', 'Mul', 'Add'],
#  ['ReduceMin', 'Min', 'Max'],
#  ['Reshape', 'Transpose', 'Sub'],
#  ['Conv', 'SpaceToDepth', 'Transpose'],
#  ['ReduceMin', 'Concat', 'Transpose'],
#  ['Reshape', 'Transpose', 'Conv'],
#  ['Conv', 'Mul', 'Reshape'],
#  ['Concat', 'MatMul', 'Reshape'],
#  ['Neg', 'Mul', 'Add', 'Max'],
#  ['Mul', 'Add', 'ReduceProd', 'Min'],
#  ['Squeeze', 'Sigmoid', 'Concat'],
#  ['ReverseSequence', 'Reshape', 'ReverseSequence', 'Reshape'],
#  ['Mul', 'Concat', 'Concat'],
#  ['Mul', 'Add', 'Reshape'],
#  ['Concat', 'Mul', 'Transpose', 'Mul'],
#  ['SpaceToDepth', 'Reshape', 'Conv', 'Conv'],
#  ['Sub', 'Atan', 'Mul'],
#  ['Mul', 'Add', 'ReduceProd'],
#  ['ReduceMin', 'Reshape', 'Conv'],
#  ['Add', 'Mul', 'Max'],
#  ['Abs', 'Mul', 'Mul'],
#  ['Concat', 'Transpose', 'Concat'],
#  ['Atan', 'MatMul', 'Concat'],
#  ['Reshape', 'Conv', 'Mul', 'Transpose'],
#  ['Mul', 'Min', 'Max', 'Gather'],
#  ['Floor', 'Concat', 'MatMul'],
#  ['Transpose', 'Conv', 'Concat'],
#  ['Conv', 'Conv', 'Conv', 'Reshape'],
#  ['Abs', 'Mul', 'Add'],
#  ['Cos', 'Concat', 'Concat', 'MatMul'],
#  ['Concat', 'Mul', 'Mul'],
#  ['Min', 'Max', 'Gather', 'Round'],
#  ['Max', 'Concat', 'LeakyRelu'],
#  ['Reshape', 'Conv', 'ArgMax'],
#  ['Max', 'Max', 'Concat'],
#  ['Reshape', 'Transpose', 'Conv', 'ArgMax'],
#  ['Concat', 'Concat', 'Ceil'],
#  ['Mul', 'Add', 'Min', 'Max'],
#  ['Reshape', 'Transpose', 'Conv', 'SpaceToDepth'],
#  ['Cos', 'Concat', 'Unsqueeze'],
#  ['LeakyRelu', 'Min', 'Max', 'Mul'],
#  ['Neg', 'Relu', 'Min'],
#  ['ReverseSequence', 'Transpose', 'Reshape'],
#  ['Add', 'Concat', 'Max'],
#  ['Shape', 'Gather', 'Expand'],
#  ['Conv', 'Transpose', 'Tan'],
#  ['Reshape', 'Reshape', 'Conv', 'Add'],
#  ['MatMul', 'Concat', 'MatMul'],
#  ['Concat', 'Min', 'Abs'],
#  ['Concat', 'Div', 'Concat'],
#  ['Conv', 'Reshape', 'Gather'],
#  ['Reshape', 'Mul', 'Concat', 'Round'],
#  ['ReduceProd', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Tan', 'ReduceMean'],
#  ['Transpose', 'ConvTranspose', 'Transpose'],
#  ['BatchNormalization', 'Transpose', 'Conv'],
#  ['ReduceMean', 'Reshape', 'Conv', 'Conv'],
#  ['Mul', 'Reshape', 'Mul', 'Reshape'],
#  ['ReduceMin', 'Reshape', 'Conv', 'Relu'],
#  ['Reshape', 'Conv', 'LeakyRelu', 'Transpose'],
#  ['Concat', 'ReduceMean', 'Sigmoid'],
#  ['Squeeze', 'Reshape', 'Conv'],
#  ['Transpose', 'Cast', 'Transpose'],
#  ['Atan', 'Reshape', 'Conv', 'Reshape'],
#  ['ReduceMax', 'Reshape', 'Conv'],
#  ['Sub', 'ArgMax', 'Min'],
#  ['Conv', 'Sigmoid', 'Transpose'],
#  ['Max', 'Concat', 'Tan'],
#  ['Reshape', 'Conv', 'Squeeze', 'Reshape'],
#  ['Reshape', 'Sub', 'Min'],
#  ['Reshape', 'Conv', 'Softmax'],
#  ['Ceil', 'Mul', 'Add'],
#  ['Cast', 'Max', 'Mul'],
#  ['MatMul', 'Reshape', 'Sub'],
#  ['Conv', 'ReduceMin', 'Concat'],
#  ['Div', 'Reshape', 'MatMul', 'Reshape'],
#  ['Transpose', 'Concat', 'ReduceMin', 'Transpose'],
#  ['Conv', 'Neg', 'Reshape'],
#  ['Floor', 'Mul', 'Mul'],
#  ['Mul', 'Transpose', 'Mul', 'Transpose'],
#  ['Tan', 'Mul', 'Add'],
#  ['LeakyRelu', 'Reshape', 'ConvTranspose', 'Reshape'],
#  ['Max', 'Transpose', 'Concat'],
#  ['Sub', 'Concat', 'Mul'],
#  ['Concat', 'ReduceMin', 'Transpose'],
#  ['Conv', 'ConvTranspose', 'Reshape'],
#  ['Reshape', 'ConvTranspose', 'ConvTranspose', 'Reshape'],
#  ['Min', 'Max', 'Gather', 'Tan'],
#  ['Transpose', 'ReverseSequence', 'Transpose'],
#  ['Reshape', 'Reshape', 'Conv', 'Reshape'],
#  ['Or', 'And', 'Or'],
#  ['Reshape', 'Sub', 'Reshape', 'Conv'],
#  ['Reshape', 'Tan', 'Unsqueeze'],
#  ['Sub', 'Concat', 'Slice'],
#  ['Max', 'Min', 'Concat'],
#  ['Conv', 'Reshape', 'Mul'],
#  ['Mul', 'Add', 'Neg'],
#  ['Or', 'And', 'And'],
#  ['Mul', 'Concat', 'Sigmoid'],
#  ['Transpose', 'SpaceToDepth', 'Transpose'],
#  ['Conv', 'LRN', 'Reshape'],
#  ['Relu', 'Transpose', 'Conv'],
#  ['Cos', 'Mul', 'Mul'],
#  ['Min', 'Max', 'ReduceMax'],
#  ['Conv', 'Reshape', 'BatchNormalization', 'Reshape', 'Conv', 'Reshape'],
#  ['Squeeze', 'Concat', 'Cos'],
#  ['Concat', 'ReduceMean', 'Mul'],
#  ['Cast', 'Min', 'Max', 'Reshape'],
#  ['Conv', 'Transpose', 'BatchNormalization'],
#  ['Gather', 'Concat', 'MatMul'],
#  ['Concat', 'Relu', 'Reshape'],
#  ['Add', 'Reshape', 'Conv'],
#  ['Add', 'Concat', 'ReduceSum'],
#  ['Mul', 'Min', 'Max'],
#  ['SpaceToDepth', 'Conv', 'Reshape'],
#  ['Min', 'Max', 'Cos', 'Atan'],
#  ['Squeeze', 'Mul', 'Add', 'Reshape'],
#  ['Concat', 'Conv', 'Transpose'],
#  ['Unsqueeze', 'Reshape', 'ReverseSequence', 'Squeeze'],
#  ['BatchNormalization', 'Transpose', 'ConvTranspose'],
#  ['ConvTranspose', 'Reshape', 'ConvTranspose'],
#  ['Conv', 'Transpose', 'Round'],
#  ['Neg', 'Max', 'Concat'],
#  ['ConvTranspose', 'Conv', 'Reshape'],
#  ['ReduceSum', 'Reshape', 'Conv'],
#  ['Cos', 'Mul', 'Add'],
#  ['Add', 'Concat', 'Neg', 'ReduceMean'],
#  ['Reshape', 'MatMul', 'Reshape', 'Relu'],
#  ['Neg', 'Max', 'Min', 'Concat'],
#  ['Mul', 'Mul', 'Max'],
#  ['Transpose', 'Conv', 'Transpose'],
#  ['Cos', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'Mul', 'Transpose'],
#  ['Concat', 'Transpose', 'Conv', 'Conv'],
#  ['Reshape', 'Conv', 'Mul'],
#  ['Concat', 'Transpose', 'DepthToSpace'],
#  ['Relu', 'Mul', 'Add'],
#  ['Min', 'Max', 'Tan'],
#  ['Add', 'Mul', 'Concat'],
#  ['Cos', 'ArgMax', 'Reshape'],
#  ['ReduceMax', 'Transpose', 'DepthToSpace'],
#  ['ReduceProd', 'Min', 'Max', 'Gather'],
#  ['Slice', 'Concat', 'Softmax'],
#  ['Reshape', 'Conv', 'Softmax', 'Reshape'],
#  ['Mul', 'Add', 'Mul'],
#  ['Cos', 'Slice', 'Mul'],
#  ['Cast', 'Mul', 'Add', 'Concat'],
#  ['Reshape', 'Concat', 'Softmax'],
#  ['Min', 'Max', 'Div'],
#  ['Transpose', 'Conv', 'Reshape', 'Transpose'],
#  ['Sigmoid', 'Reshape', 'Conv'],
#  ['Mul', 'Transpose', 'Mul'],
#  ['Mul', 'Add', 'ArgMax'],
#  ['Div', 'Concat', 'Mul'],
#  ['Erf', 'Add', 'Mul', 'Tan'],
#  ['Conv', 'Conv', 'Reshape'],
#  ['Min', 'Max', 'Squeeze'],
#  ['MatMul', 'Concat', 'Floor'],
#  ['LeakyRelu', 'ReduceProd', 'Transpose'],
#  ['Mul', 'Add', 'Tan'],
#  ['Cast', 'Add', 'Min'],
#  ['Reshape', 'Conv', 'Reshape', 'Ceil'],
#  ['Reshape', 'Conv', 'SpaceToDepth'],
#  ['Reshape', 'Sub', 'Mul'],
#  ['Conv', 'Reshape', 'Tan'],
#  ['Transpose', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Conv', 'Conv', 'Sub', 'Reshape'],
#  ['Concat', 'Concat', 'Div'],
#  ['Add', 'Concat', 'Div'],
#  ['Atan', 'Concat', 'Relu'],
#  ['Mul', 'Add', 'LeakyRelu'],
#  ['Atan', 'Concat', 'Sigmoid'],
#  ['Squeeze', 'ArgMax', 'Min', 'Max'],
#  ['Mul', 'Add', 'Atan'],
#  ['Round', 'Min', 'Max'],
#  ['Unsqueeze', 'Transpose', 'Add'],
#  ['LeakyRelu', 'Cast', 'Min'],
#  ['Atan', 'Add', 'Min', 'Max'],
#  ['Transpose', 'Conv', 'ReduceMax'],
#  ['Round', 'Reshape', 'ConvTranspose'],
#  ['LeakyRelu', 'Min', 'Max'],
#  ['ReduceMean', 'Mul', 'Softmax'],
#  ['Gather', 'Reshape', 'Transpose', 'Conv'],
#  ['Slice', 'Min', 'Max', 'Gather'],
#  ['Erf', 'Add', 'Mul', 'Unsqueeze'],
#  ['Min', 'Max', 'Transpose', 'Conv'],
#  ['Mul', 'Min', 'Concat'],
#  ['Min', 'Max', 'Softmax'],
#  ['Mul', 'Reshape', 'Sub'],
#  ['Reshape', 'Transpose', 'Conv', 'Conv'],
#  ['Conv', 'ReduceMin', 'Transpose'],
#  ['Conv', 'Conv', 'Conv', 'Transpose'],
#  ['Reshape', 'Conv', 'Cast'],
#  ['Relu', 'Concat', 'Max'],
#  ['ReverseSequence', 'Transpose', 'Shape'],
#  ['Reshape', 'Conv', 'Neg', 'Reshape'],
#  ['Conv', 'Concat', 'Reshape'],
#  ['Sigmoid', 'Add', 'Concat'],
#  ['Round', 'Reshape', 'Conv', 'Transpose'],
#  ['Reshape', 'Floor', 'Reshape'],
#  ['Conv', 'Conv', 'Reshape', 'Conv'],
#  ['Conv', 'Conv', 'SpaceToDepth'],
#  ['Transpose', 'DepthToSpace', 'Transpose'],
#  ['Add', 'Transpose', 'ConvTranspose'],
#  ['Reshape', 'Conv', 'Conv', 'Relu'],
#  ['Slice', 'Concat', 'Mul', 'Add'],
#  ['Add', 'Concat', 'Sigmoid'],
#  ['Floor', 'Transpose', 'Concat'],
#  ['Conv', 'Relu', 'Conv', 'Reshape'],
#  ['Mul', 'Add', 'Sigmoid'],
#  ['Reshape', 'ConvTranspose', 'Softmax', 'Softmax'],
#  ['Conv', 'Squeeze', 'Transpose'],
#  ['Reshape', 'Conv', 'Concat', 'Reshape'],
#  ['Conv', 'Reshape', 'Reshape'],
#  ['Reshape', 'ReverseSequence', 'Transpose'],
#  ['Slice', 'Reshape', 'Conv', 'Transpose'],
#  ['Add', 'Min', 'Max'],
#  ['Max', 'Transpose', 'Conv'],
#  ['Reshape', 'Conv', 'Transpose', 'BatchNormalization'],
#  ['Add', 'Concat', 'Cast'],
#  ['Reshape', 'Conv', 'ReduceMax'],
#  ['ReduceMean', 'Sigmoid', 'Mul'],
#  ['Min', 'Max', 'Cast', 'Max'],
#  ['ReduceMean', 'Reshape', 'Conv', 'Transpose'],
#  ['Concat', 'Concat', 'Neg'],
#  ['Concat', 'Softmax', 'Concat'],
#  ['ConvTranspose', 'Conv', 'Conv', 'Reshape'],
#  ['DepthToSpace', 'LeakyRelu', 'Reshape'],
#  ['LeakyRelu', 'Concat', 'ReduceProd'],
#  ['Abs', 'Min', 'Max', 'Gather'],
#  ['Add', 'Sub', 'Cos'],
#  ['Abs', 'Add', 'Transpose'],
#  ['Mul', 'Mul', 'Abs'],
#  ['Reshape', 'Conv', 'Add', 'Transpose'],
#  ['Conv', 'DepthToSpace', 'LeakyRelu'],
#  ['Reshape', 'Conv', 'Conv', 'Sub'],
#  ['Neg', 'Mul', 'Mul', 'Add'],
#  ['LeakyRelu', 'Max', 'Softmax'],
#  ['Sub', 'Reshape', 'Conv', 'Conv'],
#  ['ReduceMean', 'Reshape', 'ConvTranspose'],
#  ['Add', 'Mul', 'Neg'],
#  ['DepthToSpace', 'Slice', 'Reshape'],
#  ['ReduceSum', 'Min', 'Max', 'Gather'],
#  ['Transpose', 'Cos', 'Ceil'],
#  ['Min', 'Max', 'Sub'],
#  ['Relu', 'ReverseSequence', 'Reshape', 'ReverseSequence'],
#  ['Floor', 'Reshape', 'Conv', 'Transpose'],
#  ['Transpose', 'DepthToSpace', 'Conv', 'Transpose'],
#  ['Floor', 'Concat', 'Tan'],
#  ['Reshape', 'Conv', 'LRN'],
#  ['ReduceSum', 'ReduceMax', 'Concat'],
#  ['Atan', 'Atan', 'Mul'],
#  ['Min', 'Ceil', 'Cast'],
#  ['Reshape', 'Conv', 'ReduceMin', 'Concat'],
#  ['Concat', 'Div', 'Sigmoid'],
#  ['ReduceMax', 'Reshape', 'Max'],
#  ['Concat', 'Reshape', 'Slice'],
#  ['Atan', 'Atan', 'Reshape'],
#  ['GlobalAveragePool', 'Squeeze', 'Expand'],
#  ['Conv', 'Transpose', 'Reshape', 'Transpose'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMax'],
#  ['Conv', 'Reshape', 'Cos'],
#  ['Conv', 'Transpose', 'ReverseSequence', 'Transpose'],
#  ['ConvTranspose', 'Conv', 'Transpose'],
#  ['Conv', 'Conv', 'Transpose', 'ReduceSum'],
#  ['MatMul', 'Concat', 'Sub'],
#  ['Conv', 'ArgMax', 'Transpose'],
#  ['Min', 'Max', 'Reshape'],
#  ['Mul', 'Add', 'Reshape', 'Reshape', 'Conv'],
#  ['Mul', 'Mul', 'Min'],
#  ['Conv', 'Sigmoid', 'Reshape'],
#  ['Mul', 'Add', 'Slice'],
#  ['MatMul', 'Concat', 'ReduceMin'],
#  ['Conv', 'Reshape', 'BatchNormalization'],
#  ['Transpose', 'Transpose', 'ConvTranspose', 'Conv'],
#  ['Reshape', 'LRN', 'Reshape'],
#  ['Mul', 'Max', 'Ceil'],
#  ['Mul', 'Mul', 'Concat'],
#  ['Transpose', 'Conv', 'ArgMax'],
#  ['Atan', 'Concat', 'Reshape'],
#  ['Abs', 'Concat', 'Mul'],
#  ['Tan', 'Transpose', 'Conv'],
#  ['Min', 'Reshape', 'Conv'],
#  ['Mul', 'MatMul', 'Min'],
#  ['Conv', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Cast', 'Max'],
#  ['Mul', 'Add', 'Cast'],
#  ['Concat', 'Concat', 'Slice', 'Concat'],
#  ['Slice', 'Mul', 'Mul'],
#  ['Transpose', 'Conv', 'ConvTranspose'],
#  ['Conv', 'LeakyRelu', 'Conv', 'Transpose'],
#  ['Mul', 'Add', 'Squeeze'],
#  ['Transpose', 'Conv', 'Reshape', 'Gather'],
#  ['Slice', 'Cast', 'Add'],
#  ['Transpose', 'SpaceToDepth', 'Reshape'],
#  ['Slice', 'Reshape', 'MatMul'],
#  ['Squeeze', 'Reshape', 'Concat'],
#  ['Reshape', 'Conv', 'Conv'],
#  ['Mul', 'Add', 'MatMul'],
#  ['Add', 'ReduceMin', 'Transpose'],
#  ['Max', 'Concat', 'Concat', 'MatMul'],
#  ['DepthToSpace', 'Conv', 'ConvTranspose'],
#  ['Transpose', 'Conv', 'Squeeze', 'Transpose'],
#  ['Reshape', 'Conv', 'Neg'],
#  ['Reshape', 'Conv', 'Reshape', 'BatchNormalization'],
#  ['LRN', 'Transpose', 'Reshape'],
#  ['Transpose', 'Conv', 'Min', 'Transpose'],
#  ['Transpose', 'Concat', 'LRN', 'Transpose'],
#  ['Transpose', 'Conv', 'Reshape'],
#  ['Reshape', 'ConvTranspose', 'Max'],
#  ['Min', 'Max', 'Gather', 'Sub'],
#  ['Sub', 'Slice', 'Transpose'],
#  ['Squeeze', 'Transpose', 'Conv', 'Reshape'],
#  ['Transpose', 'Conv', 'LRN', 'Reshape'],
#  ['Transpose', 'Tan', 'Transpose'],
#  ['Round', 'Reshape', 'Conv', 'Reshape'],
#  ['Mul', 'Mul', 'Mul'],
#  ['Floor', 'Reshape', 'Conv', 'Conv'],
#  ['Reshape', 'Sub', 'Concat'],
#  ['ReduceSum', 'Mul', 'Add'],
#  ['MatMul', 'Reshape', 'Squeeze'],
#  ['ConvTranspose', 'Reshape', 'Gather'],
#  ['Slice', 'Concat', 'Sub'],
#  ['Transpose', 'Concat', 'Min'],
#  ['Add', 'Mul', 'Add', 'Sigmoid'],
#  ['Transpose', 'Conv', 'ReduceMean'],
#  ['Add', 'Mul', 'Sigmoid'],
#  ['Mul', 'Mul', 'ReduceMax'],
#  ['LeakyRelu', 'Reshape', 'Conv'],
#  ['Mul', 'Max', 'Softmax'],
#  ['Concat', 'Reshape', 'ConvTranspose'],
#  ['MatMul', 'Concat', 'Sigmoid'],
#  ['Conv', 'Min', 'Max'],
#  ['Transpose', 'Min', 'Max', 'Gather'],
#  ['LeakyRelu', 'Reshape', 'ConvTranspose'],
#  ['Conv', 'Conv', 'ConvTranspose'],
#  ['Tan', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Softmax', 'Relu', 'Reshape'],
#  ['Transpose', 'Reshape', 'MatMul', 'Reshape'],
#  ['Mul', 'Mul', 'Mul', 'Add'],
#  ['Reshape', 'Round', 'Mul'],
#  ['Conv', 'LeakyRelu', 'Transpose'],
#  ['Conv', 'Conv', 'Transpose'],
#  ['Sub', 'Reshape', 'Conv'],
#  ['Reshape', 'ConvTranspose', 'Transpose'],
#  ['Conv', 'LRN', 'Concat', 'Transpose'],
#  ['MatMul', 'Concat', 'Add'],
#  ['Reshape', 'Conv', 'Reshape', 'Gather'],
#  ['Concat', 'Mul', 'Reshape'],
#  ['LeakyRelu', 'Concat', 'MatMul'],
#  ['Conv', 'Conv', 'Abs'],
#  ['Add', 'Concat', 'LeakyRelu'],
#  ['Max', 'Min', 'Max'],
#  ['Add', 'Mul', 'ReduceMin'],
#  ['Min', 'Max', 'Unsqueeze'],
#  ['Concat', 'Sigmoid', 'Softmax'],
#  ['Reshape', 'Transpose', 'Min'],
#  ['Reshape', 'ConvTranspose', 'Conv'],
#  ['Transpose', 'Conv', 'ReduceMin'],
#  ['ReverseSequence', 'Reshape', 'Conv'],
#  ['Conv', 'Conv', 'Reshape', 'ConvTranspose'],
#  ['Transpose', 'Conv', 'ReduceMax', 'Reshape'],
#  ['Atan', 'Mul', 'Mul', 'Reshape'],
#  ['Transpose', 'Conv', 'LRN'],
#  ['Mul', 'Mul', 'MatMul'],
#  ['Mul', 'Mul', 'LeakyRelu'],
#  ['Conv', 'Reshape', 'Floor'],
#  ['Slice', 'Min', 'Max'],
#  ['Conv', 'Mul', 'Transpose'],
#  ['Min', 'Reshape', 'Concat', 'Reshape'],
#  ['Min', 'Reshape', 'Concat'],
#  ['Conv', 'Softmax', 'Transpose'],
#  ['ReverseSequence', 'Reshape', 'ReduceSum'],
#  ['Abs', 'Reshape', 'Conv'],
#  ['Ceil', 'Concat', 'Relu'],
#  ['Concat', 'Sub', 'Mul'],
#  ['Reshape', 'Conv', 'ConvTranspose'],
#  ['Mul', 'Add', 'ReduceMax'],
#  ['Max', 'MatMul', 'Concat'],
#  ['ReduceMax', 'Concat', 'Reshape'],
#  ['Min', 'Max', 'Gather'],
#  ['Conv', 'Transpose', 'DepthToSpace', 'Slice'],
#  ['Softmax', 'Conv', 'Reshape'],
#  ['Reshape', 'Transpose', 'Reshape', 'Slice'],
#  ['Conv', 'Sub', 'ConvTranspose'],
#  ['ReverseSequence', 'Reshape', 'ReverseSequence', 'Transpose'],
#  ['Reshape', 'Conv', 'Conv', 'ReduceMax'],
#  ['Reshape', 'Slice', 'Reshape'],
#  ['Min', 'Max', 'Gather', 'ArgMax'],
#  ['ReduceMin', 'Mul', 'Mul'],
#  ['Round', 'Concat', 'Cast', 'Abs'],
#  ['Relu', 'Max', 'Concat'],
#  ['Max', 'Round', 'Neg'],
#  ['Atan', 'Mul', 'Add'],
#  ['Add', 'Mul', 'Add'],
#  ['Reshape', 'Conv', 'Sigmoid', 'Reshape'],
#  ['Max', 'Softmax', 'Concat'],
#  ['Conv', 'Transpose', 'Ceil'],
#  ['Reshape', 'Conv', 'Relu', 'Reshape'],
#  ['Concat', 'Transpose', 'Floor'],
#  ['Softmax', 'Reshape', 'Conv', 'Reshape'],
#  ['Min', 'Max', 'Gather', 'Add'],
#  ['Conv', 'Conv', 'ReduceProd'],
#  ['LeakyRelu', 'Concat', 'ReduceMax'],
#  ['Conv', 'Sub', 'Transpose'],
#  ['Transpose', 'Conv', 'Transpose', 'Atan'],
#  ['Concat', 'Slice', 'Concat'],
#  ['Transpose', 'Mul', 'Mul'],
#  ['Mul', 'Concat', 'Cast'],
#  ['Concat', 'MatMul', 'Sub'],
#  ['Transpose', 'ConvTranspose', 'Conv'],
#  ['Min', 'Max', 'Max'],
#  ['Transpose', 'Conv', 'Squeeze'],
#  ['Reshape', 'MatMul', 'Reshape', 'ConvTranspose'],
#  ['Mul', 'Add', 'Relu'],
#  ['Conv', 'Relu', 'Transpose'],
#  ['ReduceMax', 'Mul', 'Add'],
#  ['Min', 'Max', 'ReduceMean'],
#  ['Min', 'Min', 'Cast'],
#  ['Reshape', 'ConvTranspose', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'Sigmoid', 'LeakyRelu'],
#  ['Conv', 'Shape', 'Gather'],
#  ['Reshape', 'Conv', 'LeakyRelu'],
#  ['Transpose', 'Mul', 'Add'],
#  ['Transpose', 'Concat', 'Transpose'],
#  ['Reshape', 'Conv', 'Reshape', 'Cos'],
#  ['Concat', 'Cos', 'Max'],
#  ['LeakyRelu', 'Mul', 'Mul'],
#  ['ReduceMean', 'Transpose', 'ConvTranspose'],
#  ['DepthToSpace', 'Slice', 'Reshape', 'Transpose'],
#  ['Conv', 'Abs', 'Transpose'],
#  ['Reshape', 'Concat', 'Reshape'],
#  ['Atan', 'Concat', 'Tan'],
#  ['Round', 'Concat', 'Reshape'],
#  ['Softmax', 'Min', 'Max'],
#  ['Conv', 'Conv', 'Conv'],
#  ['Mul', 'Concat', 'Reshape'],
#  ['Transpose', 'LRN', 'ConvTranspose'],
#  ['Conv', 'Relu', 'Reshape'],
#  ['Min', 'Max', 'Round'],
#  ['Reshape', 'MatMul', 'Reshape', 'LeakyRelu'],
#  ['ReduceProd', 'Mul', 'Add'],
#  ['Reshape', 'Transpose', 'Conv', 'ReduceMin'],
#  ['Transpose', 'Concat', 'LeakyRelu'],
#  ['Reshape', 'Conv', 'Conv', 'Transpose'],
#  ['Max', 'Add', 'Min'],
#  ['Gather', 'Mul', 'Mul'],
#  ['Sigmoid', 'Transpose', 'ConvTranspose'],
#  ['Add', 'ReduceMin', 'Concat'],
#  ['Concat', 'Concat', 'Sigmoid'],
#  ['ReduceMin', 'Transpose', 'Atan', 'Tan'],
#  ['Slice', 'Round', 'ReduceMax'],
#  ['Min', 'Max', 'Gather', 'Softmax'],
#  ['Reshape', 'Concat', 'Conv', 'Conv'],
#  ['ConvTranspose', 'Concat', 'Conv'],
#  ['Transpose', 'ConvTranspose', 'Transpose', 'Conv', 'Transpose'],
#  ['Floor', 'Transpose', 'Concat', 'Transpose'],
#  ['MatMul', 'Mul', 'Add'],
#  ['Ceil', 'Concat', 'Concat'],
#  ['Reshape', 'Gather', 'Mul'],
#  ['Reshape', 'Conv', 'Conv', 'ReduceMean'],
#  ['Div', 'Min', 'Max', 'Concat'],
#  ['Conv', 'Min', 'Transpose'],
#  ['Reshape', 'ConvTranspose', 'Conv', 'Reshape'],
#  ['Mul', 'Mul', 'Add', 'Mul'],
#  ['Floor', 'ArgMax', 'Min'],
#  ['MatMul', 'ReduceMean', 'Mul'],
#  ['ArgMax', 'ReduceProd', 'Cast'],
#  ['Reshape', 'Conv', 'Conv', 'Abs'],
#  ['Min', 'Div', 'Softmax'],
#  ['Min', 'Max', 'ReduceMin'],
#  ['Reshape', 'Transpose', 'Min', 'Transpose'],
#  ['Floor', 'Transpose', 'ConvTranspose', 'Reshape'],
#  ['Atan', 'MatMul', 'Concat', 'Floor'],
#  ['Min', 'Max', 'Mul', 'Add'],
#  ['ReduceProd', 'Cos', 'Ceil'],
#  ['Reshape', 'Conv', 'Transpose'],
#  ['Gather', 'Min', 'Max'],
#  ['Concat', 'Concat', 'Concat'],
#  ['Sigmoid', 'Max', 'Min', 'Max'],
#  ['Min', 'Max', 'ReverseSequence'],
#  ['Reshape', 'Conv', 'Softmax', 'Transpose'],
#  ['Sigmoid', 'Atan', 'Mul'],
#  ['Cast', 'Add', 'Max'],
#  ['Atan', 'Reshape', 'Conv'],
#  ['Conv', 'DepthToSpace', 'Reshape'],
#  ['Min', 'Max', 'Floor'],
#  ['Mul', 'Concat', 'Round'],
#  ['Mul', 'Mul', 'Sigmoid'],
#  ['Conv', 'Conv', 'Reshape', 'Reshape'],
#  ['Transpose', 'Conv', 'Mul', 'Transpose'],
#  ['MatMul', 'Reshape', 'MatMul', 'Reshape'],
#  ['Transpose', 'Max', 'Concat'],
#  ['Conv', 'Conv', 'LeakyRelu'],
#  ['Concat', 'Concat', 'Min', 'Max'],
#  ['Reshape', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'Conv', 'Conv'],
#  ['Add', 'Tan', 'Round'],
#  ['Transpose', 'BatchNormalization', 'Transpose', 'ConvTranspose'],
#  ['Concat', 'Round', 'Cast'],
#  ['Transpose', 'Conv', 'Transpose', 'BatchNormalization'],
#  ['Reshape', 'MatMul', 'Reshape', 'ReduceMax'],
#  ['Transpose', 'Conv', 'ConvTranspose', 'Conv'],
#  ['Sub', 'Min', 'Max'],
#  ['Reshape', 'MatMul', 'Reshape', 'Sigmoid'],
#  ['Conv', 'LRN', 'Concat'],
#  ['Mul', 'Add', 'Ceil'],
#  ['Transpose', 'Tan', 'Transpose', 'Conv'],
#  ['Reshape', 'Conv', 'Conv', 'DepthToSpace'],
#  ['Concat', 'Mul', 'Add', 'Concat'],
#  ['Min', 'Max', 'Gather', 'Abs'],
#  ['Mul', 'Mul', 'ReduceProd'],
#  ['Conv', 'Reshape', 'Conv', 'Conv'],
#  ['Transpose', 'Conv', 'ReduceProd'],
#  ['ReduceProd', 'Transpose', 'ConvTranspose', 'Transpose'],
#  ['Conv', 'Neg', 'Reshape', 'Conv'],
#  ['Mul', 'ReverseSequence', 'Reshape'],
#  ['ReduceProd', 'Transpose', 'Conv'],
#  ['Transpose', 'Mul', 'Concat'],
#  ['Squeeze', 'Unsqueeze', 'Reshape'],
#  ['Mul', 'Reshape', 'Conv'],
#  ['Conv', 'Reshape', 'Unsqueeze'],
#  ['Transpose', 'Concat', 'Conv'],
#  ['Reshape', 'Concat', 'Concat'],
#  ['Cast', 'Min', 'Reshape'],
#  ['Squeeze', 'Sub', 'Concat'],
#  ['Mul', 'ReduceProd', 'Transpose', 'Conv'],
#  ['Transpose', 'Conv', 'Cast', 'Transpose'],
#  ['Neg', 'Floor', 'MatMul'],
#  ['Concat', 'Mul', 'Concat'],
#  ['Add', 'Concat', 'Concat'],
#  ['Reshape', 'Conv', 'Conv', 'Min', 'Max'],
#  ['Add', 'Div', 'Cast'],
#  ['Transpose', 'ConvTranspose', 'Reshape', 'ConvTranspose'],
#  ['Concat', 'MatMul', 'Concat'],
#  ['Atan', 'Concat', 'Div'],
#  ['Round', 'Concat', 'Slice'],
#  ['Expand', 'ReverseSequence', 'Transpose'],
#  ['Add', 'Mul', 'Add', 'Relu'],
#  ['Gather', 'Reshape', 'Conv'],
#  ['ReduceMin', 'Mul', 'Add'],
#  ['Min', 'Max', 'Gather', 'Relu'],
#  ['Conv', 'Sub', 'Reshape'],
#  ['Abs', 'Floor', 'Softmax'],
#  ['Conv', 'Concat', 'Conv'],
#  ['Concat', 'Atan', 'ReduceMean'],
#  ['Atan', 'Atan', 'Mul', 'Mul'],
#  ['Atan', 'Concat', 'Ceil'],
#  ['Unsqueeze', 'Transpose', 'Conv'],
#  ['ReduceSum', 'Concat', 'Concat'],
#  ['Floor', 'Transpose', 'ConvTranspose'],
#  ['ConvTranspose', 'Reshape', 'Conv'],
#  ['Abs', 'Reshape', 'MatMul', 'Reshape'],
#  ['And', 'Cast', 'Mul', 'Add'],
#  ['Squeeze', 'Reshape', 'Concat', 'MatMul'],
#  ['Transpose', 'Transpose', 'Conv'],
#  ['And', 'Not', 'And'],
#  ['Conv', 'Reshape', 'Transpose'],
#  ['Mul', 'Concat', 'Add'],
#  ['Concat', 'Tan', 'Add'],
#  ['Mul', 'Reshape', 'Reshape'],
#  ['Round', 'Reshape', 'Conv'],
#  ['Mul', 'Add', 'Mul', 'Add'],
#  ['Max', 'Reshape', 'DepthToSpace'],
#  ['Mul', 'Mul', 'Relu'],
#  ['Relu', 'ReverseSequence', 'Reshape'],
#  ['Mul', 'Add', 'Cast', 'ReduceMin'],
#  ['ReduceMin', 'Atan', 'Concat'],
#  ['Sigmoid', 'Unsqueeze', 'Reshape'],
#  ['ReverseSequence', 'Transpose', 'Round'],
#  ['Min', 'Max', 'ArgMax'],
#  ['Mul', 'Ceil', 'Round'],
#  ['And', 'And', 'Not', 'And'],
#  ['Mul', 'Softmax', 'ReduceSum'],
#  ['Conv', 'Transpose', 'BatchNormalization', 'Transpose'],
#  ['Floor', 'Transpose', 'Conv'],
#  ['Round', 'Mul', 'Mul'],
#  ['SpaceToDepth', 'Conv', 'Conv'],
#  ['Min', 'Mul', 'Add'],
#  ['ReduceProd', 'Max', 'Concat'],
#  ['Transpose', 'Concat', 'Conv', 'Conv'],
#  ['ArgMax', 'Min', 'Max', 'Gather'],
#  ['Reshape', 'Conv', 'Squeeze'],
#  ['Or', 'And', 'And', 'Not'],
#  ['Reshape', 'Mul', 'Concat'],
#  ['Mul', 'Add', 'Transpose', 'ConvTranspose'],
#  ['Mul', 'Mul', 'Ceil'],
#  ['Cast', 'Add', 'Mul'],
#  ['Reshape', 'MatMul', 'Reshape', 'Min'],
#  ['ReduceMin', 'Reshape', 'Conv', 'Reshape'],
#  ['Mul', 'Mul', 'Min', 'Max'],
#  ['Min', 'Transpose', 'LRN', 'Transpose'],
#  ['Reshape', 'ReverseSequence', 'Reshape'],
#  ...]
